# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.1)

# %%
import requests
from bs4 import BeautifulSoup
import time

EVENT_URL = "https://aclanthology.org/events/acl-2020/"

def get_paper_links():
    response = requests.get(EVENT_URL)
    soup = BeautifulSoup(response.content, 'html.parser')
    links = soup.find_all('a', href=True)

    paper_links = []
    for link in links:
        href = link['href']
        if href.startswith("/2020.acl-main.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)
    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    links = get_paper_links()
    print(f"Found {len(links)} ACL 2020 main papers.")

    with open("acl_2020_main_abstracts.txt", "w", encoding="utf-8") as f:
        for i, url in enumerate(links, 1):
            print(f"[{i}/{len(links)}] Fetching abstract from {url}")
            abstract = extract_abstract(url)
            if abstract:
                f.write(f"URL: {url}\n")
                f.write(f"Abstract: {abstract}\n")
                f.write("="*80 + "\n")
            else:
                print(f"No abstract found for: {url}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# Found 779 ACL 2020 main papers.
# [1/779] Fetching abstract from https://aclanthology.org/2020.acl-main.0/
# ⚠️ No abstract found for: https://aclanthology.org/2020.acl-main.0/
# [2/779] Fetching abstract from https://aclanthology.org/2020.acl-main.1/
# [3/779] Fetching abstract from https://aclanthology.org/2020.acl-main.10/
# [4/779] Fetching abstract from https://aclanthology.org/2020.acl-main.100/
# [5/779] Fetching abstract from https://aclanthology.org/2020.acl-main.101/
# [6/779] Fetching abstract from https://aclanthology.org/2020.acl-main.102/
# [7/779] Fetching abstract from https://aclanthology.org/2020.acl-main.103/
# [8/779] Fetching abstract from https://aclanthology.org/2020.acl-main.104/
# [9/779] Fetching abstract from https://aclanthology.org/2020.acl-main.105/
# [10/779] Fetching abstract from https://aclanthology.org/2020.acl-main.106/
# [11/779] Fetching abstract from https://aclanthology.org/2020.acl-main.107/
# [12/779] Fetching abstract from https://aclanthology.org/2020.acl-main.108/
# [13/779] Fetching abstract from https://aclanthology.org/2020.acl-main.109/
# [14/779] Fetching abstract from https://aclanthology.org/2020.acl-main.11/
# [15/779] Fetching abstract from https://aclanthology.org/2020.acl-main.110/
# [16/779] Fetching abstract from https://aclanthology.org/2020.acl-main.111/
# [17/779] Fetching abstract from https://aclanthology.org/2020.acl-main.112/
# [18/779] Fetching abstract from https://aclanthology.org/2020.acl-main.113/
# [19/779] Fetching abstract from https://aclanthology.org/2020.acl-main.114/
# [20/779] Fetching abstract from https://aclanthology.org/2020.acl-main.115/
# [21/779] Fetching abstract from https://aclanthology.org/2020.acl-main.116/
# [22/779] Fetching abstract from https://aclanthology.org/2020.acl-main.117/
# [23/779] Fetching abstract from https://aclanthology.org/2020.acl-main.118/
# [24/779] Fetching abstract from https://aclanthology.org/2020.acl-main.119/
# [25/779] Fetching abstract from https://aclanthology.org/2020.acl-main.12/
# [26/779] Fetching abstract from https://aclanthology.org/2020.acl-main.120/
# [27/779] Fetching abstract from https://aclanthology.org/2020.acl-main.121/
# [28/779] Fetching abstract from https://aclanthology.org/2020.acl-main.122/
# [29/779] Fetching abstract from https://aclanthology.org/2020.acl-main.123/
# [30/779] Fetching abstract from https://aclanthology.org/2020.acl-main.124/
# [31/779] Fetching abstract from https://aclanthology.org/2020.acl-main.125/
# [32/779] Fetching abstract from https://aclanthology.org/2020.acl-main.126/
# [33/779] Fetching abstract from https://aclanthology.org/2020.acl-main.127/
# [34/779] Fetching abstract from https://aclanthology.org/2020.acl-main.128/
# [35/779] Fetching abstract from https://aclanthology.org/2020.acl-main.129/
# [36/779] Fetching abstract from https://aclanthology.org/2020.acl-main.13/
# [37/779] Fetching abstract from https://aclanthology.org/2020.acl-main.130/
# [38/779] Fetching abstract from https://aclanthology.org/2020.acl-main.131/
# [39/779] Fetching abstract from https://aclanthology.org/2020.acl-main.132/
# [40/779] Fetching abstract from https://aclanthology.org/2020.acl-main.133/
# [41/779] Fetching abstract from https://aclanthology.org/2020.acl-main.134/
# [42/779] Fetching abstract from https://aclanthology.org/2020.acl-main.135/
# [43/779] Fetching abstract from https://aclanthology.org/2020.acl-main.136/
# [44/779] Fetching abstract from https://aclanthology.org/2020.acl-main.137/
# [45/779] Fetching abstract from https://aclanthology.org/2020.acl-main.138/
# [46/779] Fetching abstract from https://aclanthology.org/2020.acl-main.139/
# [47/779] Fetching abstract from https://aclanthology.org/2020.acl-main.14/
# [48/779] Fetching abstract from https://aclanthology.org/2020.acl-main.140/
# [49/779] Fetching abstract from https://aclanthology.org/2020.acl-main.141/
# [50/779] Fetching abstract from https://aclanthology.org/2020.acl-main.142/
# [51/779] Fetching abstract from https://aclanthology.org/2020.acl-main.143/
# [52/779] Fetching abstract from https://aclanthology.org/2020.acl-main.144/
# [53/779] Fetching abstract from https://aclanthology.org/2020.acl-main.145/
# [54/779] Fetching abstract from https://aclanthology.org/2020.acl-main.146/
# [55/779] Fetching abstract from https://aclanthology.org/2020.acl-main.147/
# [56/779] Fetching abstract from https://aclanthology.org/2020.acl-main.148/
# [57/779] Fetching abstract from https://aclanthology.org/2020.acl-main.149/
# [58/779] Fetching abstract from https://aclanthology.org/2020.acl-main.15/
# [59/779] Fetching abstract from https://aclanthology.org/2020.acl-main.150/
# [60/779] Fetching abstract from https://aclanthology.org/2020.acl-main.151/
# [61/779] Fetching abstract from https://aclanthology.org/2020.acl-main.152/
# [62/779] Fetching abstract from https://aclanthology.org/2020.acl-main.153/
# [63/779] Fetching abstract from https://aclanthology.org/2020.acl-main.154/
# [64/779] Fetching abstract from https://aclanthology.org/2020.acl-main.155/
# [65/779] Fetching abstract from https://aclanthology.org/2020.acl-main.156/
# [66/779] Fetching abstract from https://aclanthology.org/2020.acl-main.157/
# [67/779] Fetching abstract from https://aclanthology.org/2020.acl-main.158/
# [68/779] Fetching abstract from https://aclanthology.org/2020.acl-main.159/
# [69/779] Fetching abstract from https://aclanthology.org/2020.acl-main.16/
# [70/779] Fetching abstract from https://aclanthology.org/2020.acl-main.160/
# [71/779] Fetching abstract from https://aclanthology.org/2020.acl-main.161/
# [72/779] Fetching abstract from https://aclanthology.org/2020.acl-main.162/
# [73/779] Fetching abstract from https://aclanthology.org/2020.acl-main.163/
# [74/779] Fetching abstract from https://aclanthology.org/2020.acl-main.164/
# [75/779] Fetching abstract from https://aclanthology.org/2020.acl-main.165/
# [76/779] Fetching abstract from https://aclanthology.org/2020.acl-main.166/
# [77/779] Fetching abstract from https://aclanthology.org/2020.acl-main.167/
# [78/779] Fetching abstract from https://aclanthology.org/2020.acl-main.168/
# [79/779] Fetching abstract from https://aclanthology.org/2020.acl-main.169/
# [80/779] Fetching abstract from https://aclanthology.org/2020.acl-main.17/
# [81/779] Fetching abstract from https://aclanthology.org/2020.acl-main.170/
# [82/779] Fetching abstract from https://aclanthology.org/2020.acl-main.171/
# [83/779] Fetching abstract from https://aclanthology.org/2020.acl-main.172/
# [84/779] Fetching abstract from https://aclanthology.org/2020.acl-main.173/
# [85/779] Fetching abstract from https://aclanthology.org/2020.acl-main.174/
# [86/779] Fetching abstract from https://aclanthology.org/2020.acl-main.175/
# [87/779] Fetching abstract from https://aclanthology.org/2020.acl-main.176/
# [88/779] Fetching abstract from https://aclanthology.org/2020.acl-main.177/
# [89/779] Fetching abstract from https://aclanthology.org/2020.acl-main.178/
# [90/779] Fetching abstract from https://aclanthology.org/2020.acl-main.179/
# [91/779] Fetching abstract from https://aclanthology.org/2020.acl-main.18/
# [92/779] Fetching abstract from https://aclanthology.org/2020.acl-main.180/
# [93/779] Fetching abstract from https://aclanthology.org/2020.acl-main.181/
# [94/779] Fetching abstract from https://aclanthology.org/2020.acl-main.182/
# [95/779] Fetching abstract from https://aclanthology.org/2020.acl-main.183/
# [96/779] Fetching abstract from https://aclanthology.org/2020.acl-main.184/
# [97/779] Fetching abstract from https://aclanthology.org/2020.acl-main.185/
# [98/779] Fetching abstract from https://aclanthology.org/2020.acl-main.186/
# [99/779] Fetching abstract from https://aclanthology.org/2020.acl-main.187/
# [100/779] Fetching abstract from https://aclanthology.org/2020.acl-main.188/
# [101/779] Fetching abstract from https://aclanthology.org/2020.acl-main.189/
# [102/779] Fetching abstract from https://aclanthology.org/2020.acl-main.19/
# [103/779] Fetching abstract from https://aclanthology.org/2020.acl-main.190/
# [104/779] Fetching abstract from https://aclanthology.org/2020.acl-main.191/
# [105/779] Fetching abstract from https://aclanthology.org/2020.acl-main.192/
# [106/779] Fetching abstract from https://aclanthology.org/2020.acl-main.193/
# [107/779] Fetching abstract from https://aclanthology.org/2020.acl-main.194/
# [108/779] Fetching abstract from https://aclanthology.org/2020.acl-main.195/
# [109/779] Fetching abstract from https://aclanthology.org/2020.acl-main.196/
# [110/779] Fetching abstract from https://aclanthology.org/2020.acl-main.197/
# [111/779] Fetching abstract from https://aclanthology.org/2020.acl-main.198/
# [112/779] Fetching abstract from https://aclanthology.org/2020.acl-main.199/
# [113/779] Fetching abstract from https://aclanthology.org/2020.acl-main.2/
# [114/779] Fetching abstract from https://aclanthology.org/2020.acl-main.20/
# [115/779] Fetching abstract from https://aclanthology.org/2020.acl-main.200/
# [116/779] Fetching abstract from https://aclanthology.org/2020.acl-main.201/
# [117/779] Fetching abstract from https://aclanthology.org/2020.acl-main.202/
# [118/779] Fetching abstract from https://aclanthology.org/2020.acl-main.203/
# [119/779] Fetching abstract from https://aclanthology.org/2020.acl-main.204/
# [120/779] Fetching abstract from https://aclanthology.org/2020.acl-main.205/
# [121/779] Fetching abstract from https://aclanthology.org/2020.acl-main.206/
# [122/779] Fetching abstract from https://aclanthology.org/2020.acl-main.207/
# [123/779] Fetching abstract from https://aclanthology.org/2020.acl-main.208/
# [124/779] Fetching abstract from https://aclanthology.org/2020.acl-main.209/
# [125/779] Fetching abstract from https://aclanthology.org/2020.acl-main.21/
# [126/779] Fetching abstract from https://aclanthology.org/2020.acl-main.210/
# [127/779] Fetching abstract from https://aclanthology.org/2020.acl-main.211/
# [128/779] Fetching abstract from https://aclanthology.org/2020.acl-main.212/
# [129/779] Fetching abstract from https://aclanthology.org/2020.acl-main.213/
# [130/779] Fetching abstract from https://aclanthology.org/2020.acl-main.214/
# [131/779] Fetching abstract from https://aclanthology.org/2020.acl-main.215/
# [132/779] Fetching abstract from https://aclanthology.org/2020.acl-main.216/
# [133/779] Fetching abstract from https://aclanthology.org/2020.acl-main.217/
# [134/779] Fetching abstract from https://aclanthology.org/2020.acl-main.218/
# [135/779] Fetching abstract from https://aclanthology.org/2020.acl-main.219/
# [136/779] Fetching abstract from https://aclanthology.org/2020.acl-main.22/
# [137/779] Fetching abstract from https://aclanthology.org/2020.acl-main.220/
# [138/779] Fetching abstract from https://aclanthology.org/2020.acl-main.221/
# [139/779] Fetching abstract from https://aclanthology.org/2020.acl-main.222/
# [140/779] Fetching abstract from https://aclanthology.org/2020.acl-main.223/
# [141/779] Fetching abstract from https://aclanthology.org/2020.acl-main.224/
# [142/779] Fetching abstract from https://aclanthology.org/2020.acl-main.225/
# [143/779] Fetching abstract from https://aclanthology.org/2020.acl-main.226/
# [144/779] Fetching abstract from https://aclanthology.org/2020.acl-main.227/
# [145/779] Fetching abstract from https://aclanthology.org/2020.acl-main.228/
# [146/779] Fetching abstract from https://aclanthology.org/2020.acl-main.229/
# [147/779] Fetching abstract from https://aclanthology.org/2020.acl-main.23/
# [148/779] Fetching abstract from https://aclanthology.org/2020.acl-main.230/
# [149/779] Fetching abstract from https://aclanthology.org/2020.acl-main.231/
# [150/779] Fetching abstract from https://aclanthology.org/2020.acl-main.232/
# [151/779] Fetching abstract from https://aclanthology.org/2020.acl-main.233/
# [152/779] Fetching abstract from https://aclanthology.org/2020.acl-main.234/
# [153/779] Fetching abstract from https://aclanthology.org/2020.acl-main.235/
# [154/779] Fetching abstract from https://aclanthology.org/2020.acl-main.236/
# [155/779] Fetching abstract from https://aclanthology.org/2020.acl-main.237/
# [156/779] Fetching abstract from https://aclanthology.org/2020.acl-main.238/
# [157/779] Fetching abstract from https://aclanthology.org/2020.acl-main.239/
# [158/779] Fetching abstract from https://aclanthology.org/2020.acl-main.24/
# [159/779] Fetching abstract from https://aclanthology.org/2020.acl-main.240/
# [160/779] Fetching abstract from https://aclanthology.org/2020.acl-main.241/
# [161/779] Fetching abstract from https://aclanthology.org/2020.acl-main.242/
# [162/779] Fetching abstract from https://aclanthology.org/2020.acl-main.243/
# [163/779] Fetching abstract from https://aclanthology.org/2020.acl-main.244/
# [164/779] Fetching abstract from https://aclanthology.org/2020.acl-main.245/
# [165/779] Fetching abstract from https://aclanthology.org/2020.acl-main.246/
# [166/779] Fetching abstract from https://aclanthology.org/2020.acl-main.247/
# [167/779] Fetching abstract from https://aclanthology.org/2020.acl-main.248/
# [168/779] Fetching abstract from https://aclanthology.org/2020.acl-main.249/
# [169/779] Fetching abstract from https://aclanthology.org/2020.acl-main.25/
# [170/779] Fetching abstract from https://aclanthology.org/2020.acl-main.250/
# [171/779] Fetching abstract from https://aclanthology.org/2020.acl-main.251/
# [172/779] Fetching abstract from https://aclanthology.org/2020.acl-main.252/
# [173/779] Fetching abstract from https://aclanthology.org/2020.acl-main.253/
# [174/779] Fetching abstract from https://aclanthology.org/2020.acl-main.254/
# [175/779] Fetching abstract from https://aclanthology.org/2020.acl-main.255/
# [176/779] Fetching abstract from https://aclanthology.org/2020.acl-main.256/
# [177/779] Fetching abstract from https://aclanthology.org/2020.acl-main.257/
# [178/779] Fetching abstract from https://aclanthology.org/2020.acl-main.258/
# [179/779] Fetching abstract from https://aclanthology.org/2020.acl-main.259/
# [180/779] Fetching abstract from https://aclanthology.org/2020.acl-main.26/
# [181/779] Fetching abstract from https://aclanthology.org/2020.acl-main.260/
# [182/779] Fetching abstract from https://aclanthology.org/2020.acl-main.261/
# [183/779] Fetching abstract from https://aclanthology.org/2020.acl-main.262/
# [184/779] Fetching abstract from https://aclanthology.org/2020.acl-main.263/
# [185/779] Fetching abstract from https://aclanthology.org/2020.acl-main.264/
# [186/779] Fetching abstract from https://aclanthology.org/2020.acl-main.265/
# [187/779] Fetching abstract from https://aclanthology.org/2020.acl-main.266/
# [188/779] Fetching abstract from https://aclanthology.org/2020.acl-main.267/
# [189/779] Fetching abstract from https://aclanthology.org/2020.acl-main.268/
# [190/779] Fetching abstract from https://aclanthology.org/2020.acl-main.269/
# [191/779] Fetching abstract from https://aclanthology.org/2020.acl-main.27/
# [192/779] Fetching abstract from https://aclanthology.org/2020.acl-main.270/
# [193/779] Fetching abstract from https://aclanthology.org/2020.acl-main.271/
# [194/779] Fetching abstract from https://aclanthology.org/2020.acl-main.272/
# [195/779] Fetching abstract from https://aclanthology.org/2020.acl-main.273/
# [196/779] Fetching abstract from https://aclanthology.org/2020.acl-main.274/
# [197/779] Fetching abstract from https://aclanthology.org/2020.acl-main.275/
# [198/779] Fetching abstract from https://aclanthology.org/2020.acl-main.276/
# [199/779] Fetching abstract from https://aclanthology.org/2020.acl-main.277/
# [200/779] Fetching abstract from https://aclanthology.org/2020.acl-main.278/
# [201/779] Fetching abstract from https://aclanthology.org/2020.acl-main.279/
# [202/779] Fetching abstract from https://aclanthology.org/2020.acl-main.28/
# [203/779] Fetching abstract from https://aclanthology.org/2020.acl-main.280/
# [204/779] Fetching abstract from https://aclanthology.org/2020.acl-main.281/
# [205/779] Fetching abstract from https://aclanthology.org/2020.acl-main.282/
# [206/779] Fetching abstract from https://aclanthology.org/2020.acl-main.283/
# [207/779] Fetching abstract from https://aclanthology.org/2020.acl-main.284/
# [208/779] Fetching abstract from https://aclanthology.org/2020.acl-main.285/
# [209/779] Fetching abstract from https://aclanthology.org/2020.acl-main.286/
# [210/779] Fetching abstract from https://aclanthology.org/2020.acl-main.287/
# [211/779] Fetching abstract from https://aclanthology.org/2020.acl-main.288/
# [212/779] Fetching abstract from https://aclanthology.org/2020.acl-main.289/
# [213/779] Fetching abstract from https://aclanthology.org/2020.acl-main.29/
# [214/779] Fetching abstract from https://aclanthology.org/2020.acl-main.290/
# [215/779] Fetching abstract from https://aclanthology.org/2020.acl-main.291/
# [216/779] Fetching abstract from https://aclanthology.org/2020.acl-main.292/
# [217/779] Fetching abstract from https://aclanthology.org/2020.acl-main.293/
# [218/779] Fetching abstract from https://aclanthology.org/2020.acl-main.294/
# [219/779] Fetching abstract from https://aclanthology.org/2020.acl-main.295/
# [220/779] Fetching abstract from https://aclanthology.org/2020.acl-main.296/
# [221/779] Fetching abstract from https://aclanthology.org/2020.acl-main.297/
# [222/779] Fetching abstract from https://aclanthology.org/2020.acl-main.298/
# [223/779] Fetching abstract from https://aclanthology.org/2020.acl-main.299/
# [224/779] Fetching abstract from https://aclanthology.org/2020.acl-main.3/
# [225/779] Fetching abstract from https://aclanthology.org/2020.acl-main.30/
# [226/779] Fetching abstract from https://aclanthology.org/2020.acl-main.300/
# [227/779] Fetching abstract from https://aclanthology.org/2020.acl-main.301/
# [228/779] Fetching abstract from https://aclanthology.org/2020.acl-main.302/
# [229/779] Fetching abstract from https://aclanthology.org/2020.acl-main.303/
# [230/779] Fetching abstract from https://aclanthology.org/2020.acl-main.304/
# [231/779] Fetching abstract from https://aclanthology.org/2020.acl-main.305/
# [232/779] Fetching abstract from https://aclanthology.org/2020.acl-main.306/
# [233/779] Fetching abstract from https://aclanthology.org/2020.acl-main.307/
# [234/779] Fetching abstract from https://aclanthology.org/2020.acl-main.308/
# [235/779] Fetching abstract from https://aclanthology.org/2020.acl-main.309/
# [236/779] Fetching abstract from https://aclanthology.org/2020.acl-main.31/
# [237/779] Fetching abstract from https://aclanthology.org/2020.acl-main.310/
# [238/779] Fetching abstract from https://aclanthology.org/2020.acl-main.311/
# [239/779] Fetching abstract from https://aclanthology.org/2020.acl-main.312/
# [240/779] Fetching abstract from https://aclanthology.org/2020.acl-main.313/
# [241/779] Fetching abstract from https://aclanthology.org/2020.acl-main.314/
# [242/779] Fetching abstract from https://aclanthology.org/2020.acl-main.315/
# [243/779] Fetching abstract from https://aclanthology.org/2020.acl-main.316/
# [244/779] Fetching abstract from https://aclanthology.org/2020.acl-main.317/
# [245/779] Fetching abstract from https://aclanthology.org/2020.acl-main.318/
# [246/779] Fetching abstract from https://aclanthology.org/2020.acl-main.319/
# [247/779] Fetching abstract from https://aclanthology.org/2020.acl-main.32/
# [248/779] Fetching abstract from https://aclanthology.org/2020.acl-main.320/
# [249/779] Fetching abstract from https://aclanthology.org/2020.acl-main.321/
# [250/779] Fetching abstract from https://aclanthology.org/2020.acl-main.322/
# [251/779] Fetching abstract from https://aclanthology.org/2020.acl-main.323/
# [252/779] Fetching abstract from https://aclanthology.org/2020.acl-main.324/
# [253/779] Fetching abstract from https://aclanthology.org/2020.acl-main.325/
# [254/779] Fetching abstract from https://aclanthology.org/2020.acl-main.326/
# [255/779] Fetching abstract from https://aclanthology.org/2020.acl-main.327/
# [256/779] Fetching abstract from https://aclanthology.org/2020.acl-main.328/
# [257/779] Fetching abstract from https://aclanthology.org/2020.acl-main.329/
# [258/779] Fetching abstract from https://aclanthology.org/2020.acl-main.33/
# [259/779] Fetching abstract from https://aclanthology.org/2020.acl-main.330/
# [260/779] Fetching abstract from https://aclanthology.org/2020.acl-main.331/
# [261/779] Fetching abstract from https://aclanthology.org/2020.acl-main.332/
# [262/779] Fetching abstract from https://aclanthology.org/2020.acl-main.333/
# [263/779] Fetching abstract from https://aclanthology.org/2020.acl-main.334/
# [264/779] Fetching abstract from https://aclanthology.org/2020.acl-main.335/
# [265/779] Fetching abstract from https://aclanthology.org/2020.acl-main.336/
# [266/779] Fetching abstract from https://aclanthology.org/2020.acl-main.337/
# [267/779] Fetching abstract from https://aclanthology.org/2020.acl-main.338/
# [268/779] Fetching abstract from https://aclanthology.org/2020.acl-main.339/
# [269/779] Fetching abstract from https://aclanthology.org/2020.acl-main.34/
# [270/779] Fetching abstract from https://aclanthology.org/2020.acl-main.340/
# [271/779] Fetching abstract from https://aclanthology.org/2020.acl-main.341/
# [272/779] Fetching abstract from https://aclanthology.org/2020.acl-main.342/
# [273/779] Fetching abstract from https://aclanthology.org/2020.acl-main.343/
# [274/779] Fetching abstract from https://aclanthology.org/2020.acl-main.344/
# [275/779] Fetching abstract from https://aclanthology.org/2020.acl-main.345/
# [276/779] Fetching abstract from https://aclanthology.org/2020.acl-main.346/
# [277/779] Fetching abstract from https://aclanthology.org/2020.acl-main.347/
# [278/779] Fetching abstract from https://aclanthology.org/2020.acl-main.348/
# [279/779] Fetching abstract from https://aclanthology.org/2020.acl-main.349/
# [280/779] Fetching abstract from https://aclanthology.org/2020.acl-main.35/
# [281/779] Fetching abstract from https://aclanthology.org/2020.acl-main.350/
# [282/779] Fetching abstract from https://aclanthology.org/2020.acl-main.351/
# [283/779] Fetching abstract from https://aclanthology.org/2020.acl-main.352/
# [284/779] Fetching abstract from https://aclanthology.org/2020.acl-main.353/
# [285/779] Fetching abstract from https://aclanthology.org/2020.acl-main.354/
# [286/779] Fetching abstract from https://aclanthology.org/2020.acl-main.355/
# [287/779] Fetching abstract from https://aclanthology.org/2020.acl-main.356/
# [288/779] Fetching abstract from https://aclanthology.org/2020.acl-main.357/
# [289/779] Fetching abstract from https://aclanthology.org/2020.acl-main.358/
# [290/779] Fetching abstract from https://aclanthology.org/2020.acl-main.359/
# [291/779] Fetching abstract from https://aclanthology.org/2020.acl-main.36/
# [292/779] Fetching abstract from https://aclanthology.org/2020.acl-main.360/
# [293/779] Fetching abstract from https://aclanthology.org/2020.acl-main.361/
# [294/779] Fetching abstract from https://aclanthology.org/2020.acl-main.362/
# [295/779] Fetching abstract from https://aclanthology.org/2020.acl-main.363/
# [296/779] Fetching abstract from https://aclanthology.org/2020.acl-main.364/
# [297/779] Fetching abstract from https://aclanthology.org/2020.acl-main.365/
# [298/779] Fetching abstract from https://aclanthology.org/2020.acl-main.366/
# [299/779] Fetching abstract from https://aclanthology.org/2020.acl-main.367/
# [300/779] Fetching abstract from https://aclanthology.org/2020.acl-main.368/
# [301/779] Fetching abstract from https://aclanthology.org/2020.acl-main.369/
# [302/779] Fetching abstract from https://aclanthology.org/2020.acl-main.37/
# [303/779] Fetching abstract from https://aclanthology.org/2020.acl-main.370/
# [304/779] Fetching abstract from https://aclanthology.org/2020.acl-main.371/
# [305/779] Fetching abstract from https://aclanthology.org/2020.acl-main.372/
# [306/779] Fetching abstract from https://aclanthology.org/2020.acl-main.373/
# [307/779] Fetching abstract from https://aclanthology.org/2020.acl-main.374/
# [308/779] Fetching abstract from https://aclanthology.org/2020.acl-main.375/
# [309/779] Fetching abstract from https://aclanthology.org/2020.acl-main.376/
# [310/779] Fetching abstract from https://aclanthology.org/2020.acl-main.377/
# [311/779] Fetching abstract from https://aclanthology.org/2020.acl-main.378/
# [312/779] Fetching abstract from https://aclanthology.org/2020.acl-main.379/
# [313/779] Fetching abstract from https://aclanthology.org/2020.acl-main.38/
# [314/779] Fetching abstract from https://aclanthology.org/2020.acl-main.380/
# [315/779] Fetching abstract from https://aclanthology.org/2020.acl-main.381/
# [316/779] Fetching abstract from https://aclanthology.org/2020.acl-main.382/
# [317/779] Fetching abstract from https://aclanthology.org/2020.acl-main.383/
# [318/779] Fetching abstract from https://aclanthology.org/2020.acl-main.384/
# [319/779] Fetching abstract from https://aclanthology.org/2020.acl-main.385/
# [320/779] Fetching abstract from https://aclanthology.org/2020.acl-main.386/
# [321/779] Fetching abstract from https://aclanthology.org/2020.acl-main.387/
# [322/779] Fetching abstract from https://aclanthology.org/2020.acl-main.388/
# [323/779] Fetching abstract from https://aclanthology.org/2020.acl-main.389/
# [324/779] Fetching abstract from https://aclanthology.org/2020.acl-main.39/
# [325/779] Fetching abstract from https://aclanthology.org/2020.acl-main.390/
# [326/779] Fetching abstract from https://aclanthology.org/2020.acl-main.391/
# [327/779] Fetching abstract from https://aclanthology.org/2020.acl-main.392/
# [328/779] Fetching abstract from https://aclanthology.org/2020.acl-main.393/
# [329/779] Fetching abstract from https://aclanthology.org/2020.acl-main.394/
# [330/779] Fetching abstract from https://aclanthology.org/2020.acl-main.395/
# [331/779] Fetching abstract from https://aclanthology.org/2020.acl-main.396/
# [332/779] Fetching abstract from https://aclanthology.org/2020.acl-main.397/
# [333/779] Fetching abstract from https://aclanthology.org/2020.acl-main.398/
# [334/779] Fetching abstract from https://aclanthology.org/2020.acl-main.399/
# [335/779] Fetching abstract from https://aclanthology.org/2020.acl-main.4/
# [336/779] Fetching abstract from https://aclanthology.org/2020.acl-main.40/
# [337/779] Fetching abstract from https://aclanthology.org/2020.acl-main.400/
# [338/779] Fetching abstract from https://aclanthology.org/2020.acl-main.401/
# [339/779] Fetching abstract from https://aclanthology.org/2020.acl-main.402/
# [340/779] Fetching abstract from https://aclanthology.org/2020.acl-main.403/
# [341/779] Fetching abstract from https://aclanthology.org/2020.acl-main.404/
# [342/779] Fetching abstract from https://aclanthology.org/2020.acl-main.405/
# [343/779] Fetching abstract from https://aclanthology.org/2020.acl-main.406/
# [344/779] Fetching abstract from https://aclanthology.org/2020.acl-main.407/
# [345/779] Fetching abstract from https://aclanthology.org/2020.acl-main.408/
# [346/779] Fetching abstract from https://aclanthology.org/2020.acl-main.409/
# [347/779] Fetching abstract from https://aclanthology.org/2020.acl-main.41/
# [348/779] Fetching abstract from https://aclanthology.org/2020.acl-main.410/
# [349/779] Fetching abstract from https://aclanthology.org/2020.acl-main.411/
# [350/779] Fetching abstract from https://aclanthology.org/2020.acl-main.412/
# [351/779] Fetching abstract from https://aclanthology.org/2020.acl-main.413/
# [352/779] Fetching abstract from https://aclanthology.org/2020.acl-main.414/
# [353/779] Fetching abstract from https://aclanthology.org/2020.acl-main.415/
# [354/779] Fetching abstract from https://aclanthology.org/2020.acl-main.416/
# [355/779] Fetching abstract from https://aclanthology.org/2020.acl-main.417/
# [356/779] Fetching abstract from https://aclanthology.org/2020.acl-main.418/
# [357/779] Fetching abstract from https://aclanthology.org/2020.acl-main.419/
# [358/779] Fetching abstract from https://aclanthology.org/2020.acl-main.42/
# [359/779] Fetching abstract from https://aclanthology.org/2020.acl-main.420/
# [360/779] Fetching abstract from https://aclanthology.org/2020.acl-main.421/
# [361/779] Fetching abstract from https://aclanthology.org/2020.acl-main.422/
# [362/779] Fetching abstract from https://aclanthology.org/2020.acl-main.423/
# [363/779] Fetching abstract from https://aclanthology.org/2020.acl-main.424/
# [364/779] Fetching abstract from https://aclanthology.org/2020.acl-main.425/
# [365/779] Fetching abstract from https://aclanthology.org/2020.acl-main.426/
# [366/779] Fetching abstract from https://aclanthology.org/2020.acl-main.427/
# [367/779] Fetching abstract from https://aclanthology.org/2020.acl-main.428/
# [368/779] Fetching abstract from https://aclanthology.org/2020.acl-main.429/
# [369/779] Fetching abstract from https://aclanthology.org/2020.acl-main.43/
# [370/779] Fetching abstract from https://aclanthology.org/2020.acl-main.430/
# [371/779] Fetching abstract from https://aclanthology.org/2020.acl-main.431/
# [372/779] Fetching abstract from https://aclanthology.org/2020.acl-main.432/
# [373/779] Fetching abstract from https://aclanthology.org/2020.acl-main.433/
# [374/779] Fetching abstract from https://aclanthology.org/2020.acl-main.434/
# [375/779] Fetching abstract from https://aclanthology.org/2020.acl-main.435/
# [376/779] Fetching abstract from https://aclanthology.org/2020.acl-main.436/
# [377/779] Fetching abstract from https://aclanthology.org/2020.acl-main.437/
# [378/779] Fetching abstract from https://aclanthology.org/2020.acl-main.438/
# [379/779] Fetching abstract from https://aclanthology.org/2020.acl-main.439/
# [380/779] Fetching abstract from https://aclanthology.org/2020.acl-main.44/
# [381/779] Fetching abstract from https://aclanthology.org/2020.acl-main.440/
# [382/779] Fetching abstract from https://aclanthology.org/2020.acl-main.441/
# [383/779] Fetching abstract from https://aclanthology.org/2020.acl-main.442/
# [384/779] Fetching abstract from https://aclanthology.org/2020.acl-main.443/
# [385/779] Fetching abstract from https://aclanthology.org/2020.acl-main.444/
# [386/779] Fetching abstract from https://aclanthology.org/2020.acl-main.445/
# [387/779] Fetching abstract from https://aclanthology.org/2020.acl-main.446/
# [388/779] Fetching abstract from https://aclanthology.org/2020.acl-main.447/
# [389/779] Fetching abstract from https://aclanthology.org/2020.acl-main.448/
# [390/779] Fetching abstract from https://aclanthology.org/2020.acl-main.449/
# [391/779] Fetching abstract from https://aclanthology.org/2020.acl-main.45/
# [392/779] Fetching abstract from https://aclanthology.org/2020.acl-main.450/
# [393/779] Fetching abstract from https://aclanthology.org/2020.acl-main.451/
# [394/779] Fetching abstract from https://aclanthology.org/2020.acl-main.452/
# [395/779] Fetching abstract from https://aclanthology.org/2020.acl-main.453/
# [396/779] Fetching abstract from https://aclanthology.org/2020.acl-main.454/
# [397/779] Fetching abstract from https://aclanthology.org/2020.acl-main.455/
# [398/779] Fetching abstract from https://aclanthology.org/2020.acl-main.456/
# [399/779] Fetching abstract from https://aclanthology.org/2020.acl-main.457/
# [400/779] Fetching abstract from https://aclanthology.org/2020.acl-main.458/
# [401/779] Fetching abstract from https://aclanthology.org/2020.acl-main.459/
# [402/779] Fetching abstract from https://aclanthology.org/2020.acl-main.46/
# [403/779] Fetching abstract from https://aclanthology.org/2020.acl-main.460/
# [404/779] Fetching abstract from https://aclanthology.org/2020.acl-main.461/
# [405/779] Fetching abstract from https://aclanthology.org/2020.acl-main.462/
# [406/779] Fetching abstract from https://aclanthology.org/2020.acl-main.463/
# [407/779] Fetching abstract from https://aclanthology.org/2020.acl-main.464/
# [408/779] Fetching abstract from https://aclanthology.org/2020.acl-main.465/
# [409/779] Fetching abstract from https://aclanthology.org/2020.acl-main.466/
# [410/779] Fetching abstract from https://aclanthology.org/2020.acl-main.467/
# [411/779] Fetching abstract from https://aclanthology.org/2020.acl-main.468/
# [412/779] Fetching abstract from https://aclanthology.org/2020.acl-main.469/
# [413/779] Fetching abstract from https://aclanthology.org/2020.acl-main.47/
# [414/779] Fetching abstract from https://aclanthology.org/2020.acl-main.470/
# [415/779] Fetching abstract from https://aclanthology.org/2020.acl-main.471/
# [416/779] Fetching abstract from https://aclanthology.org/2020.acl-main.472/
# [417/779] Fetching abstract from https://aclanthology.org/2020.acl-main.473/
# [418/779] Fetching abstract from https://aclanthology.org/2020.acl-main.474/
# [419/779] Fetching abstract from https://aclanthology.org/2020.acl-main.475/
# [420/779] Fetching abstract from https://aclanthology.org/2020.acl-main.476/
# [421/779] Fetching abstract from https://aclanthology.org/2020.acl-main.477/
# [422/779] Fetching abstract from https://aclanthology.org/2020.acl-main.478/
# [423/779] Fetching abstract from https://aclanthology.org/2020.acl-main.479/
# [424/779] Fetching abstract from https://aclanthology.org/2020.acl-main.48/
# [425/779] Fetching abstract from https://aclanthology.org/2020.acl-main.480/
# [426/779] Fetching abstract from https://aclanthology.org/2020.acl-main.481/
# [427/779] Fetching abstract from https://aclanthology.org/2020.acl-main.482/
# [428/779] Fetching abstract from https://aclanthology.org/2020.acl-main.483/
# [429/779] Fetching abstract from https://aclanthology.org/2020.acl-main.484/
# [430/779] Fetching abstract from https://aclanthology.org/2020.acl-main.485/
# [431/779] Fetching abstract from https://aclanthology.org/2020.acl-main.486/
# [432/779] Fetching abstract from https://aclanthology.org/2020.acl-main.487/
# [433/779] Fetching abstract from https://aclanthology.org/2020.acl-main.488/
# [434/779] Fetching abstract from https://aclanthology.org/2020.acl-main.489/
# [435/779] Fetching abstract from https://aclanthology.org/2020.acl-main.49/
# [436/779] Fetching abstract from https://aclanthology.org/2020.acl-main.490/
# [437/779] Fetching abstract from https://aclanthology.org/2020.acl-main.491/
# [438/779] Fetching abstract from https://aclanthology.org/2020.acl-main.492/
# [439/779] Fetching abstract from https://aclanthology.org/2020.acl-main.493/
# [440/779] Fetching abstract from https://aclanthology.org/2020.acl-main.494/
# [441/779] Fetching abstract from https://aclanthology.org/2020.acl-main.495/
# [442/779] Fetching abstract from https://aclanthology.org/2020.acl-main.496/
# [443/779] Fetching abstract from https://aclanthology.org/2020.acl-main.497/
# [444/779] Fetching abstract from https://aclanthology.org/2020.acl-main.498/
# [445/779] Fetching abstract from https://aclanthology.org/2020.acl-main.499/
# [446/779] Fetching abstract from https://aclanthology.org/2020.acl-main.5/
# [447/779] Fetching abstract from https://aclanthology.org/2020.acl-main.50/
# [448/779] Fetching abstract from https://aclanthology.org/2020.acl-main.500/
# [449/779] Fetching abstract from https://aclanthology.org/2020.acl-main.501/
# [450/779] Fetching abstract from https://aclanthology.org/2020.acl-main.502/
# [451/779] Fetching abstract from https://aclanthology.org/2020.acl-main.503/
# [452/779] Fetching abstract from https://aclanthology.org/2020.acl-main.504/
# [453/779] Fetching abstract from https://aclanthology.org/2020.acl-main.505/
# [454/779] Fetching abstract from https://aclanthology.org/2020.acl-main.506/
# [455/779] Fetching abstract from https://aclanthology.org/2020.acl-main.507/
# [456/779] Fetching abstract from https://aclanthology.org/2020.acl-main.508/
# [457/779] Fetching abstract from https://aclanthology.org/2020.acl-main.509/
# [458/779] Fetching abstract from https://aclanthology.org/2020.acl-main.51/
# [459/779] Fetching abstract from https://aclanthology.org/2020.acl-main.510/
# [460/779] Fetching abstract from https://aclanthology.org/2020.acl-main.511/
# [461/779] Fetching abstract from https://aclanthology.org/2020.acl-main.512/
# [462/779] Fetching abstract from https://aclanthology.org/2020.acl-main.513/
# [463/779] Fetching abstract from https://aclanthology.org/2020.acl-main.514/
# [464/779] Fetching abstract from https://aclanthology.org/2020.acl-main.515/
# [465/779] Fetching abstract from https://aclanthology.org/2020.acl-main.516/
# [466/779] Fetching abstract from https://aclanthology.org/2020.acl-main.517/
# [467/779] Fetching abstract from https://aclanthology.org/2020.acl-main.518/
# [468/779] Fetching abstract from https://aclanthology.org/2020.acl-main.519/
# [469/779] Fetching abstract from https://aclanthology.org/2020.acl-main.52/
# [470/779] Fetching abstract from https://aclanthology.org/2020.acl-main.520/
# [471/779] Fetching abstract from https://aclanthology.org/2020.acl-main.521/
# [472/779] Fetching abstract from https://aclanthology.org/2020.acl-main.522/
# [473/779] Fetching abstract from https://aclanthology.org/2020.acl-main.523/
# [474/779] Fetching abstract from https://aclanthology.org/2020.acl-main.524/
# [475/779] Fetching abstract from https://aclanthology.org/2020.acl-main.525/
# [476/779] Fetching abstract from https://aclanthology.org/2020.acl-main.526/
# [477/779] Fetching abstract from https://aclanthology.org/2020.acl-main.527/
# [478/779] Fetching abstract from https://aclanthology.org/2020.acl-main.528/
# [479/779] Fetching abstract from https://aclanthology.org/2020.acl-main.529/
# [480/779] Fetching abstract from https://aclanthology.org/2020.acl-main.53/
# [481/779] Fetching abstract from https://aclanthology.org/2020.acl-main.530/
# [482/779] Fetching abstract from https://aclanthology.org/2020.acl-main.531/
# [483/779] Fetching abstract from https://aclanthology.org/2020.acl-main.532/
# [484/779] Fetching abstract from https://aclanthology.org/2020.acl-main.533/
# [485/779] Fetching abstract from https://aclanthology.org/2020.acl-main.534/
# [486/779] Fetching abstract from https://aclanthology.org/2020.acl-main.535/
# [487/779] Fetching abstract from https://aclanthology.org/2020.acl-main.536/
# [488/779] Fetching abstract from https://aclanthology.org/2020.acl-main.537/
# [489/779] Fetching abstract from https://aclanthology.org/2020.acl-main.538/
# [490/779] Fetching abstract from https://aclanthology.org/2020.acl-main.539/
# [491/779] Fetching abstract from https://aclanthology.org/2020.acl-main.54/
# [492/779] Fetching abstract from https://aclanthology.org/2020.acl-main.540/
# [493/779] Fetching abstract from https://aclanthology.org/2020.acl-main.541/
# [494/779] Fetching abstract from https://aclanthology.org/2020.acl-main.542/
# [495/779] Fetching abstract from https://aclanthology.org/2020.acl-main.543/
# [496/779] Fetching abstract from https://aclanthology.org/2020.acl-main.544/
# [497/779] Fetching abstract from https://aclanthology.org/2020.acl-main.545/
# [498/779] Fetching abstract from https://aclanthology.org/2020.acl-main.546/
# [499/779] Fetching abstract from https://aclanthology.org/2020.acl-main.547/
# [500/779] Fetching abstract from https://aclanthology.org/2020.acl-main.548/
# [501/779] Fetching abstract from https://aclanthology.org/2020.acl-main.549/
# [502/779] Fetching abstract from https://aclanthology.org/2020.acl-main.55/
# [503/779] Fetching abstract from https://aclanthology.org/2020.acl-main.550/
# [504/779] Fetching abstract from https://aclanthology.org/2020.acl-main.551/
# [505/779] Fetching abstract from https://aclanthology.org/2020.acl-main.552/
# [506/779] Fetching abstract from https://aclanthology.org/2020.acl-main.553/
# [507/779] Fetching abstract from https://aclanthology.org/2020.acl-main.554/
# [508/779] Fetching abstract from https://aclanthology.org/2020.acl-main.555/
# [509/779] Fetching abstract from https://aclanthology.org/2020.acl-main.556/
# [510/779] Fetching abstract from https://aclanthology.org/2020.acl-main.557/
# [511/779] Fetching abstract from https://aclanthology.org/2020.acl-main.558/
# [512/779] Fetching abstract from https://aclanthology.org/2020.acl-main.559/
# [513/779] Fetching abstract from https://aclanthology.org/2020.acl-main.56/
# [514/779] Fetching abstract from https://aclanthology.org/2020.acl-main.560/
# [515/779] Fetching abstract from https://aclanthology.org/2020.acl-main.561/
# [516/779] Fetching abstract from https://aclanthology.org/2020.acl-main.562/
# [517/779] Fetching abstract from https://aclanthology.org/2020.acl-main.563/
# [518/779] Fetching abstract from https://aclanthology.org/2020.acl-main.564/
# [519/779] Fetching abstract from https://aclanthology.org/2020.acl-main.565/
# [520/779] Fetching abstract from https://aclanthology.org/2020.acl-main.566/
# [521/779] Fetching abstract from https://aclanthology.org/2020.acl-main.567/
# [522/779] Fetching abstract from https://aclanthology.org/2020.acl-main.568/
# [523/779] Fetching abstract from https://aclanthology.org/2020.acl-main.569/
# [524/779] Fetching abstract from https://aclanthology.org/2020.acl-main.57/
# [525/779] Fetching abstract from https://aclanthology.org/2020.acl-main.570/
# [526/779] Fetching abstract from https://aclanthology.org/2020.acl-main.571/
# [527/779] Fetching abstract from https://aclanthology.org/2020.acl-main.572/
# [528/779] Fetching abstract from https://aclanthology.org/2020.acl-main.573/
# [529/779] Fetching abstract from https://aclanthology.org/2020.acl-main.574/
# [530/779] Fetching abstract from https://aclanthology.org/2020.acl-main.575/
# [531/779] Fetching abstract from https://aclanthology.org/2020.acl-main.576/
# [532/779] Fetching abstract from https://aclanthology.org/2020.acl-main.577/
# [533/779] Fetching abstract from https://aclanthology.org/2020.acl-main.578/
# [534/779] Fetching abstract from https://aclanthology.org/2020.acl-main.579/
# [535/779] Fetching abstract from https://aclanthology.org/2020.acl-main.58/
# [536/779] Fetching abstract from https://aclanthology.org/2020.acl-main.580/
# [537/779] Fetching abstract from https://aclanthology.org/2020.acl-main.581/
# [538/779] Fetching abstract from https://aclanthology.org/2020.acl-main.582/
# [539/779] Fetching abstract from https://aclanthology.org/2020.acl-main.583/
# [540/779] Fetching abstract from https://aclanthology.org/2020.acl-main.584/
# [541/779] Fetching abstract from https://aclanthology.org/2020.acl-main.585/
# [542/779] Fetching abstract from https://aclanthology.org/2020.acl-main.586/
# [543/779] Fetching abstract from https://aclanthology.org/2020.acl-main.587/
# [544/779] Fetching abstract from https://aclanthology.org/2020.acl-main.588/
# [545/779] Fetching abstract from https://aclanthology.org/2020.acl-main.589/
# [546/779] Fetching abstract from https://aclanthology.org/2020.acl-main.59/
# [547/779] Fetching abstract from https://aclanthology.org/2020.acl-main.590/
# [548/779] Fetching abstract from https://aclanthology.org/2020.acl-main.591/
# [549/779] Fetching abstract from https://aclanthology.org/2020.acl-main.592/
# [550/779] Fetching abstract from https://aclanthology.org/2020.acl-main.593/
# [551/779] Fetching abstract from https://aclanthology.org/2020.acl-main.594/
# [552/779] Fetching abstract from https://aclanthology.org/2020.acl-main.595/
# [553/779] Fetching abstract from https://aclanthology.org/2020.acl-main.596/
# [554/779] Fetching abstract from https://aclanthology.org/2020.acl-main.597/
# [555/779] Fetching abstract from https://aclanthology.org/2020.acl-main.598/
# [556/779] Fetching abstract from https://aclanthology.org/2020.acl-main.599/
# [557/779] Fetching abstract from https://aclanthology.org/2020.acl-main.6/
# [558/779] Fetching abstract from https://aclanthology.org/2020.acl-main.60/
# [559/779] Fetching abstract from https://aclanthology.org/2020.acl-main.600/
# [560/779] Fetching abstract from https://aclanthology.org/2020.acl-main.601/
# [561/779] Fetching abstract from https://aclanthology.org/2020.acl-main.602/
# [562/779] Fetching abstract from https://aclanthology.org/2020.acl-main.603/
# [563/779] Fetching abstract from https://aclanthology.org/2020.acl-main.604/
# [564/779] Fetching abstract from https://aclanthology.org/2020.acl-main.605/
# [565/779] Fetching abstract from https://aclanthology.org/2020.acl-main.606/
# [566/779] Fetching abstract from https://aclanthology.org/2020.acl-main.607/
# [567/779] Fetching abstract from https://aclanthology.org/2020.acl-main.608/
# [568/779] Fetching abstract from https://aclanthology.org/2020.acl-main.609/
# [569/779] Fetching abstract from https://aclanthology.org/2020.acl-main.61/
# [570/779] Fetching abstract from https://aclanthology.org/2020.acl-main.610/
# [571/779] Fetching abstract from https://aclanthology.org/2020.acl-main.611/
# [572/779] Fetching abstract from https://aclanthology.org/2020.acl-main.612/
# [573/779] Fetching abstract from https://aclanthology.org/2020.acl-main.613/
# [574/779] Fetching abstract from https://aclanthology.org/2020.acl-main.614/
# [575/779] Fetching abstract from https://aclanthology.org/2020.acl-main.615/
# [576/779] Fetching abstract from https://aclanthology.org/2020.acl-main.616/
# [577/779] Fetching abstract from https://aclanthology.org/2020.acl-main.617/
# [578/779] Fetching abstract from https://aclanthology.org/2020.acl-main.618/
# [579/779] Fetching abstract from https://aclanthology.org/2020.acl-main.619/
# [580/779] Fetching abstract from https://aclanthology.org/2020.acl-main.62/
# [581/779] Fetching abstract from https://aclanthology.org/2020.acl-main.620/
# [582/779] Fetching abstract from https://aclanthology.org/2020.acl-main.621/
# [583/779] Fetching abstract from https://aclanthology.org/2020.acl-main.622/
# [584/779] Fetching abstract from https://aclanthology.org/2020.acl-main.623/
# [585/779] Fetching abstract from https://aclanthology.org/2020.acl-main.624/
# [586/779] Fetching abstract from https://aclanthology.org/2020.acl-main.625/
# [587/779] Fetching abstract from https://aclanthology.org/2020.acl-main.626/
# [588/779] Fetching abstract from https://aclanthology.org/2020.acl-main.627/
# [589/779] Fetching abstract from https://aclanthology.org/2020.acl-main.628/
# [590/779] Fetching abstract from https://aclanthology.org/2020.acl-main.629/
# [591/779] Fetching abstract from https://aclanthology.org/2020.acl-main.63/
# [592/779] Fetching abstract from https://aclanthology.org/2020.acl-main.630/
# [593/779] Fetching abstract from https://aclanthology.org/2020.acl-main.631/
# [594/779] Fetching abstract from https://aclanthology.org/2020.acl-main.632/
# [595/779] Fetching abstract from https://aclanthology.org/2020.acl-main.633/
# [596/779] Fetching abstract from https://aclanthology.org/2020.acl-main.634/
# [597/779] Fetching abstract from https://aclanthology.org/2020.acl-main.635/
# [598/779] Fetching abstract from https://aclanthology.org/2020.acl-main.636/
# [599/779] Fetching abstract from https://aclanthology.org/2020.acl-main.637/
# [600/779] Fetching abstract from https://aclanthology.org/2020.acl-main.638/
# [601/779] Fetching abstract from https://aclanthology.org/2020.acl-main.639/
# [602/779] Fetching abstract from https://aclanthology.org/2020.acl-main.64/
# [603/779] Fetching abstract from https://aclanthology.org/2020.acl-main.640/
# [604/779] Fetching abstract from https://aclanthology.org/2020.acl-main.641/
# [605/779] Fetching abstract from https://aclanthology.org/2020.acl-main.642/
# [606/779] Fetching abstract from https://aclanthology.org/2020.acl-main.643/
# [607/779] Fetching abstract from https://aclanthology.org/2020.acl-main.644/
# [608/779] Fetching abstract from https://aclanthology.org/2020.acl-main.645/
# [609/779] Fetching abstract from https://aclanthology.org/2020.acl-main.646/
# [610/779] Fetching abstract from https://aclanthology.org/2020.acl-main.647/
# [611/779] Fetching abstract from https://aclanthology.org/2020.acl-main.648/
# [612/779] Fetching abstract from https://aclanthology.org/2020.acl-main.649/
# [613/779] Fetching abstract from https://aclanthology.org/2020.acl-main.65/
# [614/779] Fetching abstract from https://aclanthology.org/2020.acl-main.650/
# [615/779] Fetching abstract from https://aclanthology.org/2020.acl-main.651/
# [616/779] Fetching abstract from https://aclanthology.org/2020.acl-main.652/
# [617/779] Fetching abstract from https://aclanthology.org/2020.acl-main.653/
# [618/779] Fetching abstract from https://aclanthology.org/2020.acl-main.654/
# [619/779] Fetching abstract from https://aclanthology.org/2020.acl-main.655/
# [620/779] Fetching abstract from https://aclanthology.org/2020.acl-main.656/
# [621/779] Fetching abstract from https://aclanthology.org/2020.acl-main.657/
# [622/779] Fetching abstract from https://aclanthology.org/2020.acl-main.658/
# [623/779] Fetching abstract from https://aclanthology.org/2020.acl-main.659/
# [624/779] Fetching abstract from https://aclanthology.org/2020.acl-main.66/
# [625/779] Fetching abstract from https://aclanthology.org/2020.acl-main.660/
# [626/779] Fetching abstract from https://aclanthology.org/2020.acl-main.661/
# [627/779] Fetching abstract from https://aclanthology.org/2020.acl-main.662/
# [628/779] Fetching abstract from https://aclanthology.org/2020.acl-main.663/
# [629/779] Fetching abstract from https://aclanthology.org/2020.acl-main.664/
# [630/779] Fetching abstract from https://aclanthology.org/2020.acl-main.665/
# [631/779] Fetching abstract from https://aclanthology.org/2020.acl-main.666/
# [632/779] Fetching abstract from https://aclanthology.org/2020.acl-main.667/
# [633/779] Fetching abstract from https://aclanthology.org/2020.acl-main.668/
# [634/779] Fetching abstract from https://aclanthology.org/2020.acl-main.669/
# [635/779] Fetching abstract from https://aclanthology.org/2020.acl-main.67/
# [636/779] Fetching abstract from https://aclanthology.org/2020.acl-main.670/
# [637/779] Fetching abstract from https://aclanthology.org/2020.acl-main.671/
# [638/779] Fetching abstract from https://aclanthology.org/2020.acl-main.672/
# [639/779] Fetching abstract from https://aclanthology.org/2020.acl-main.673/
# [640/779] Fetching abstract from https://aclanthology.org/2020.acl-main.674/
# [641/779] Fetching abstract from https://aclanthology.org/2020.acl-main.675/
# [642/779] Fetching abstract from https://aclanthology.org/2020.acl-main.676/
# [643/779] Fetching abstract from https://aclanthology.org/2020.acl-main.677/
# [644/779] Fetching abstract from https://aclanthology.org/2020.acl-main.678/
# [645/779] Fetching abstract from https://aclanthology.org/2020.acl-main.679/
# [646/779] Fetching abstract from https://aclanthology.org/2020.acl-main.68/
# [647/779] Fetching abstract from https://aclanthology.org/2020.acl-main.680/
# [648/779] Fetching abstract from https://aclanthology.org/2020.acl-main.681/
# [649/779] Fetching abstract from https://aclanthology.org/2020.acl-main.682/
# [650/779] Fetching abstract from https://aclanthology.org/2020.acl-main.683/
# [651/779] Fetching abstract from https://aclanthology.org/2020.acl-main.684/
# [652/779] Fetching abstract from https://aclanthology.org/2020.acl-main.685/
# [653/779] Fetching abstract from https://aclanthology.org/2020.acl-main.686/
# [654/779] Fetching abstract from https://aclanthology.org/2020.acl-main.687/
# [655/779] Fetching abstract from https://aclanthology.org/2020.acl-main.688/
# [656/779] Fetching abstract from https://aclanthology.org/2020.acl-main.689/
# [657/779] Fetching abstract from https://aclanthology.org/2020.acl-main.69/
# [658/779] Fetching abstract from https://aclanthology.org/2020.acl-main.690/
# [659/779] Fetching abstract from https://aclanthology.org/2020.acl-main.691/
# [660/779] Fetching abstract from https://aclanthology.org/2020.acl-main.692/
# [661/779] Fetching abstract from https://aclanthology.org/2020.acl-main.693/
# [662/779] Fetching abstract from https://aclanthology.org/2020.acl-main.694/
# [663/779] Fetching abstract from https://aclanthology.org/2020.acl-main.695/
# [664/779] Fetching abstract from https://aclanthology.org/2020.acl-main.696/
# [665/779] Fetching abstract from https://aclanthology.org/2020.acl-main.697/
# [666/779] Fetching abstract from https://aclanthology.org/2020.acl-main.698/
# [667/779] Fetching abstract from https://aclanthology.org/2020.acl-main.699/
# [668/779] Fetching abstract from https://aclanthology.org/2020.acl-main.7/
# [669/779] Fetching abstract from https://aclanthology.org/2020.acl-main.70/
# [670/779] Fetching abstract from https://aclanthology.org/2020.acl-main.700/
# [671/779] Fetching abstract from https://aclanthology.org/2020.acl-main.701/
# [672/779] Fetching abstract from https://aclanthology.org/2020.acl-main.702/
# [673/779] Fetching abstract from https://aclanthology.org/2020.acl-main.703/
# [674/779] Fetching abstract from https://aclanthology.org/2020.acl-main.704/
# [675/779] Fetching abstract from https://aclanthology.org/2020.acl-main.705/
# [676/779] Fetching abstract from https://aclanthology.org/2020.acl-main.706/
# [677/779] Fetching abstract from https://aclanthology.org/2020.acl-main.707/
# [678/779] Fetching abstract from https://aclanthology.org/2020.acl-main.708/
# [679/779] Fetching abstract from https://aclanthology.org/2020.acl-main.709/
# [680/779] Fetching abstract from https://aclanthology.org/2020.acl-main.71/
# [681/779] Fetching abstract from https://aclanthology.org/2020.acl-main.710/
# [682/779] Fetching abstract from https://aclanthology.org/2020.acl-main.711/
# [683/779] Fetching abstract from https://aclanthology.org/2020.acl-main.712/
# [684/779] Fetching abstract from https://aclanthology.org/2020.acl-main.713/
# [685/779] Fetching abstract from https://aclanthology.org/2020.acl-main.714/
# [686/779] Fetching abstract from https://aclanthology.org/2020.acl-main.715/
# [687/779] Fetching abstract from https://aclanthology.org/2020.acl-main.716/
# [688/779] Fetching abstract from https://aclanthology.org/2020.acl-main.717/
# [689/779] Fetching abstract from https://aclanthology.org/2020.acl-main.718/
# [690/779] Fetching abstract from https://aclanthology.org/2020.acl-main.719/
# [691/779] Fetching abstract from https://aclanthology.org/2020.acl-main.72/
# [692/779] Fetching abstract from https://aclanthology.org/2020.acl-main.720/
# [693/779] Fetching abstract from https://aclanthology.org/2020.acl-main.721/
# [694/779] Fetching abstract from https://aclanthology.org/2020.acl-main.722/
# [695/779] Fetching abstract from https://aclanthology.org/2020.acl-main.723/
# [696/779] Fetching abstract from https://aclanthology.org/2020.acl-main.724/
# [697/779] Fetching abstract from https://aclanthology.org/2020.acl-main.725/
# [698/779] Fetching abstract from https://aclanthology.org/2020.acl-main.726/
# [699/779] Fetching abstract from https://aclanthology.org/2020.acl-main.727/
# [700/779] Fetching abstract from https://aclanthology.org/2020.acl-main.728/
# [701/779] Fetching abstract from https://aclanthology.org/2020.acl-main.729/
# [702/779] Fetching abstract from https://aclanthology.org/2020.acl-main.73/
# [703/779] Fetching abstract from https://aclanthology.org/2020.acl-main.730/
# [704/779] Fetching abstract from https://aclanthology.org/2020.acl-main.731/
# [705/779] Fetching abstract from https://aclanthology.org/2020.acl-main.732/
# [706/779] Fetching abstract from https://aclanthology.org/2020.acl-main.733/
# [707/779] Fetching abstract from https://aclanthology.org/2020.acl-main.734/
# [708/779] Fetching abstract from https://aclanthology.org/2020.acl-main.735/
# [709/779] Fetching abstract from https://aclanthology.org/2020.acl-main.736/
# [710/779] Fetching abstract from https://aclanthology.org/2020.acl-main.737/
# [711/779] Fetching abstract from https://aclanthology.org/2020.acl-main.738/
# [712/779] Fetching abstract from https://aclanthology.org/2020.acl-main.739/
# [713/779] Fetching abstract from https://aclanthology.org/2020.acl-main.74/
# [714/779] Fetching abstract from https://aclanthology.org/2020.acl-main.740/
# [715/779] Fetching abstract from https://aclanthology.org/2020.acl-main.741/
# [716/779] Fetching abstract from https://aclanthology.org/2020.acl-main.742/
# [717/779] Fetching abstract from https://aclanthology.org/2020.acl-main.743/
# [718/779] Fetching abstract from https://aclanthology.org/2020.acl-main.744/
# [719/779] Fetching abstract from https://aclanthology.org/2020.acl-main.745/
# [720/779] Fetching abstract from https://aclanthology.org/2020.acl-main.746/
# [721/779] Fetching abstract from https://aclanthology.org/2020.acl-main.747/
# [722/779] Fetching abstract from https://aclanthology.org/2020.acl-main.748/
# [723/779] Fetching abstract from https://aclanthology.org/2020.acl-main.749/
# [724/779] Fetching abstract from https://aclanthology.org/2020.acl-main.75/
# [725/779] Fetching abstract from https://aclanthology.org/2020.acl-main.750/
# [726/779] Fetching abstract from https://aclanthology.org/2020.acl-main.751/
# [727/779] Fetching abstract from https://aclanthology.org/2020.acl-main.752/
# [728/779] Fetching abstract from https://aclanthology.org/2020.acl-main.753/
# [729/779] Fetching abstract from https://aclanthology.org/2020.acl-main.754/
# [730/779] Fetching abstract from https://aclanthology.org/2020.acl-main.755/
# [731/779] Fetching abstract from https://aclanthology.org/2020.acl-main.756/
# [732/779] Fetching abstract from https://aclanthology.org/2020.acl-main.757/
# [733/779] Fetching abstract from https://aclanthology.org/2020.acl-main.758/
# [734/779] Fetching abstract from https://aclanthology.org/2020.acl-main.759/
# [735/779] Fetching abstract from https://aclanthology.org/2020.acl-main.76/
# [736/779] Fetching abstract from https://aclanthology.org/2020.acl-main.760/
# [737/779] Fetching abstract from https://aclanthology.org/2020.acl-main.761/
# [738/779] Fetching abstract from https://aclanthology.org/2020.acl-main.762/
# [739/779] Fetching abstract from https://aclanthology.org/2020.acl-main.763/
# [740/779] Fetching abstract from https://aclanthology.org/2020.acl-main.764/
# [741/779] Fetching abstract from https://aclanthology.org/2020.acl-main.765/
# [742/779] Fetching abstract from https://aclanthology.org/2020.acl-main.766/
# [743/779] Fetching abstract from https://aclanthology.org/2020.acl-main.767/
# [744/779] Fetching abstract from https://aclanthology.org/2020.acl-main.768/
# [745/779] Fetching abstract from https://aclanthology.org/2020.acl-main.769/
# [746/779] Fetching abstract from https://aclanthology.org/2020.acl-main.77/
# [747/779] Fetching abstract from https://aclanthology.org/2020.acl-main.770/
# [748/779] Fetching abstract from https://aclanthology.org/2020.acl-main.771/
# [749/779] Fetching abstract from https://aclanthology.org/2020.acl-main.772/
# [750/779] Fetching abstract from https://aclanthology.org/2020.acl-main.773/
# [751/779] Fetching abstract from https://aclanthology.org/2020.acl-main.774/
# [752/779] Fetching abstract from https://aclanthology.org/2020.acl-main.775/
# [753/779] Fetching abstract from https://aclanthology.org/2020.acl-main.776/
# [754/779] Fetching abstract from https://aclanthology.org/2020.acl-main.777/
# [755/779] Fetching abstract from https://aclanthology.org/2020.acl-main.778/
# [756/779] Fetching abstract from https://aclanthology.org/2020.acl-main.78/
# [757/779] Fetching abstract from https://aclanthology.org/2020.acl-main.79/
# [758/779] Fetching abstract from https://aclanthology.org/2020.acl-main.8/
# [759/779] Fetching abstract from https://aclanthology.org/2020.acl-main.80/
# [760/779] Fetching abstract from https://aclanthology.org/2020.acl-main.81/
# [761/779] Fetching abstract from https://aclanthology.org/2020.acl-main.82/
# [762/779] Fetching abstract from https://aclanthology.org/2020.acl-main.83/
# [763/779] Fetching abstract from https://aclanthology.org/2020.acl-main.84/
# [764/779] Fetching abstract from https://aclanthology.org/2020.acl-main.85/
# [765/779] Fetching abstract from https://aclanthology.org/2020.acl-main.86/
# [766/779] Fetching abstract from https://aclanthology.org/2020.acl-main.87/
# [767/779] Fetching abstract from https://aclanthology.org/2020.acl-main.88/
# [768/779] Fetching abstract from https://aclanthology.org/2020.acl-main.89/
# [769/779] Fetching abstract from https://aclanthology.org/2020.acl-main.9/
# [770/779] Fetching abstract from https://aclanthology.org/2020.acl-main.90/
# [771/779] Fetching abstract from https://aclanthology.org/2020.acl-main.91/
# [772/779] Fetching abstract from https://aclanthology.org/2020.acl-main.92/
# [773/779] Fetching abstract from https://aclanthology.org/2020.acl-main.93/
# [774/779] Fetching abstract from https://aclanthology.org/2020.acl-main.94/
# [775/779] Fetching abstract from https://aclanthology.org/2020.acl-main.95/
# [776/779] Fetching abstract from https://aclanthology.org/2020.acl-main.96/
# [777/779] Fetching abstract from https://aclanthology.org/2020.acl-main.97/
# [778/779] Fetching abstract from https://aclanthology.org/2020.acl-main.98/
# [779/779] Fetching abstract from https://aclanthology.org/2020.acl-main.99/

# %%
import requests
from bs4 import BeautifulSoup
import time

def get_paper_links(event, year):
    event_url = f"https://aclanthology.org/events/{event}-{year}/"
    response = requests.get(event_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    links = soup.find_all('a', href=True)

    paper_links = []
    for link in links:
        href = link['href']
        if href.startswith(f"/{year}.{event}-main.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)
    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    events = {'acl': range(2021, 2025), 'emnlp': range(2020, 2025), 'naacl': range(2020, 2025)}
    for event, years in events.items():
        for year in years:
            links = get_paper_links(event, year)
            print(f"Found {len(links)} {event.upper()} {year} main papers.")
            with open(f"{event}_{year}_main_abstracts.txt", "w", encoding="utf-8") as f:
                for i, url in enumerate(links, 1):
                    print(f"[{i}/{len(links)}] Fetching abstract from {url}")
                    abstract = extract_abstract(url)
                    if abstract:
                        f.write(f"URL: {url}\n")
                        f.write(f"Abstract: {abstract}\n")
                        f.write("="*80 + "\n")
                    else:
                        print(f"No abstract found for: {url}")
                    time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# [719/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.746/
# [720/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.747/
# [721/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.748/
# [722/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.749/
# [723/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.75/
# [724/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.750/
# [725/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.751/
# [726/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.752/
# [727/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.76/
# [728/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.77/
# [729/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.78/
# [730/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.79/
# [731/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.8/
# [732/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.80/
# [733/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.81/
# [734/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.82/
# [735/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.83/
# [736/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.84/
# [737/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.85/
# [738/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.86/
# [739/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.87/
# [740/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.88/
# [741/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.89/
# [742/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.9/
# [743/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.90/
# [744/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.91/
# [745/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.92/
# [746/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.93/
# [747/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.94/
# [748/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.95/
# [749/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.96/
# [750/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.97/
# [751/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.98/
# [752/752] Fetching abstract from https://aclanthology.org/2020.emnlp-main.99/
# Found 848 EMNLP 2021 main papers.
# [1/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.0/
# ⚠️ No abstract found for: https://aclanthology.org/2021.emnlp-main.0/
# [2/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.1/
# [3/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.10/
# [4/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.100/
# [5/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.101/
# [6/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.102/
# [7/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.103/
# [8/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.104/
# [9/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.105/
# [10/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.106/
# [11/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.107/
# [12/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.108/
# [13/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.109/
# [14/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.11/
# [15/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.110/
# [16/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.111/
# [17/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.112/
# [18/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.113/
# [19/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.114/
# [20/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.115/
# [21/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.116/
# [22/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.117/
# [23/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.118/
# [24/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.119/
# [25/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.12/
# [26/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.120/
# [27/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.121/
# [28/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.122/
# [29/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.123/
# [30/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.124/
# [31/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.125/
# [32/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.126/
# [33/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.127/
# [34/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.128/
# [35/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.129/
# [36/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.13/
# [37/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.130/
# [38/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.131/
# [39/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.132/
# [40/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.133/
# [41/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.134/
# [42/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.135/
# [43/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.136/
# [44/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.137/
# [45/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.138/
# [46/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.139/
# [47/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.14/
# [48/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.140/
# [49/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.141/
# [50/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.142/
# [51/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.143/
# [52/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.144/
# [53/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.145/
# [54/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.146/
# [55/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.147/
# [56/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.148/
# [57/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.149/
# [58/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.15/
# [59/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.150/
# [60/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.151/
# [61/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.152/
# [62/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.153/
# [63/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.154/
# [64/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.155/
# [65/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.156/
# [66/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.157/
# [67/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.158/
# [68/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.159/
# [69/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.16/
# [70/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.160/
# [71/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.161/
# [72/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.162/
# [73/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.163/
# [74/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.164/
# [75/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.165/
# [76/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.166/
# [77/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.167/
# [78/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.168/
# [79/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.169/
# [80/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.17/
# [81/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.170/
# [82/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.171/
# [83/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.172/
# [84/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.173/
# [85/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.174/
# [86/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.175/
# [87/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.176/
# [88/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.177/
# [89/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.178/
# [90/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.179/
# [91/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.18/
# [92/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.180/
# [93/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.181/
# [94/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.182/
# [95/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.183/
# [96/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.184/
# [97/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.185/
# [98/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.186/
# [99/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.187/
# [100/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.188/
# [101/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.189/
# [102/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.19/
# [103/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.190/
# [104/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.191/
# [105/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.192/
# [106/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.193/
# [107/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.194/
# [108/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.195/
# [109/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.196/
# [110/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.197/
# [111/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.198/
# [112/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.199/
# [113/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.2/
# [114/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.20/
# [115/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.200/
# [116/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.201/
# [117/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.202/
# [118/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.203/
# [119/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.204/
# [120/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.205/
# [121/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.206/
# [122/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.207/
# [123/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.208/
# [124/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.209/
# [125/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.21/
# [126/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.210/
# [127/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.211/
# [128/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.212/
# [129/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.213/
# [130/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.214/
# [131/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.215/
# [132/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.216/
# [133/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.217/
# [134/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.218/
# [135/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.219/
# [136/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.22/
# [137/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.220/
# [138/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.221/
# [139/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.222/
# [140/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.223/
# [141/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.224/
# [142/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.225/
# [143/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.226/
# [144/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.227/
# [145/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.228/
# [146/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.229/
# [147/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.23/
# [148/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.230/
# [149/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.231/
# [150/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.232/
# [151/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.233/
# [152/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.234/
# [153/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.235/
# [154/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.236/
# [155/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.237/
# [156/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.238/
# [157/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.239/
# [158/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.24/
# [159/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.240/
# [160/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.241/
# [161/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.242/
# [162/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.243/
# [163/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.244/
# [164/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.245/
# [165/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.246/
# [166/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.247/
# [167/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.248/
# [168/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.249/
# [169/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.25/
# [170/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.250/
# [171/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.251/
# [172/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.252/
# [173/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.253/
# [174/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.254/
# [175/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.255/
# [176/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.256/
# [177/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.257/
# [178/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.258/
# [179/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.259/
# [180/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.26/
# [181/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.260/
# [182/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.261/
# [183/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.262/
# [184/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.263/
# [185/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.264/
# [186/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.265/
# [187/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.266/
# [188/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.267/
# [189/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.268/
# [190/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.269/
# [191/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.27/
# [192/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.270/
# [193/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.271/
# [194/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.272/
# [195/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.273/
# [196/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.274/
# [197/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.275/
# [198/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.276/
# [199/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.277/
# [200/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.278/
# [201/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.279/
# [202/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.28/
# [203/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.280/
# [204/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.281/
# [205/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.282/
# [206/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.283/
# [207/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.284/
# [208/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.285/
# [209/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.286/
# [210/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.287/
# [211/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.288/
# [212/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.289/
# [213/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.29/
# [214/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.290/
# [215/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.291/
# [216/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.292/
# [217/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.293/
# [218/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.294/
# [219/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.295/
# [220/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.296/
# [221/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.297/
# [222/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.298/
# [223/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.299/
# [224/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.3/
# [225/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.30/
# [226/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.300/
# [227/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.301/
# [228/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.302/
# [229/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.303/
# [230/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.304/
# [231/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.305/
# [232/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.306/
# [233/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.307/
# [234/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.308/
# [235/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.309/
# [236/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.31/
# [237/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.310/
# [238/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.311/
# [239/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.312/
# [240/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.313/
# [241/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.314/
# [242/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.315/
# [243/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.316/
# [244/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.317/
# [245/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.318/
# [246/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.319/
# [247/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.32/
# [248/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.320/
# [249/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.321/
# [250/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.322/
# [251/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.323/
# [252/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.324/
# [253/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.325/
# [254/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.326/
# [255/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.327/
# [256/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.328/
# [257/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.329/
# [258/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.33/
# [259/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.330/
# [260/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.331/
# [261/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.332/
# [262/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.333/
# [263/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.334/
# [264/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.335/
# [265/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.336/
# [266/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.337/
# [267/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.338/
# [268/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.339/
# [269/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.34/
# [270/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.340/
# [271/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.341/
# [272/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.342/
# [273/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.343/
# [274/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.344/
# [275/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.345/
# [276/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.346/
# [277/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.347/
# [278/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.348/
# [279/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.349/
# [280/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.35/
# [281/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.350/
# [282/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.351/
# [283/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.352/
# [284/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.353/
# [285/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.354/
# [286/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.355/
# [287/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.356/
# [288/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.357/
# [289/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.358/
# [290/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.359/
# [291/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.36/
# [292/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.360/
# [293/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.361/
# [294/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.362/
# [295/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.363/
# [296/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.364/
# [297/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.365/
# [298/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.366/
# [299/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.367/
# [300/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.368/
# [301/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.369/
# [302/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.37/
# [303/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.370/
# [304/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.371/
# [305/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.372/
# [306/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.373/
# [307/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.374/
# [308/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.375/
# [309/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.376/
# [310/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.377/
# [311/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.378/
# [312/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.379/
# [313/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.38/
# [314/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.380/
# [315/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.381/
# [316/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.382/
# [317/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.383/
# [318/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.384/
# [319/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.385/
# [320/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.386/
# [321/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.387/
# [322/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.388/
# [323/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.389/
# [324/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.39/
# [325/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.390/
# [326/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.391/
# [327/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.392/
# [328/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.393/
# [329/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.394/
# [330/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.395/
# [331/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.396/
# [332/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.397/
# [333/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.398/
# [334/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.399/
# [335/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.4/
# [336/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.40/
# [337/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.400/
# [338/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.401/
# [339/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.402/
# [340/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.403/
# [341/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.404/
# [342/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.405/
# [343/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.406/
# [344/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.407/
# [345/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.408/
# [346/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.409/
# [347/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.41/
# [348/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.410/
# [349/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.411/
# [350/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.412/
# [351/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.413/
# [352/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.414/
# [353/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.415/
# [354/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.416/
# [355/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.417/
# [356/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.418/
# [357/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.419/
# [358/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.42/
# [359/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.420/
# [360/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.421/
# [361/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.422/
# [362/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.423/
# [363/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.424/
# [364/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.425/
# [365/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.426/
# [366/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.427/
# [367/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.428/
# [368/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.429/
# [369/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.43/
# [370/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.430/
# [371/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.431/
# [372/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.432/
# [373/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.433/
# [374/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.434/
# [375/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.435/
# [376/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.436/
# [377/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.437/
# [378/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.438/
# [379/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.439/
# [380/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.44/
# [381/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.440/
# [382/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.441/
# [383/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.442/
# [384/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.443/
# [385/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.444/
# [386/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.445/
# [387/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.446/
# [388/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.447/
# [389/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.448/
# [390/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.449/
# [391/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.45/
# [392/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.450/
# [393/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.451/
# [394/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.452/
# [395/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.453/
# [396/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.454/
# [397/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.455/
# [398/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.456/
# [399/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.457/
# [400/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.458/
# [401/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.459/
# [402/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.46/
# [403/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.460/
# [404/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.461/
# [405/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.462/
# [406/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.463/
# [407/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.464/
# [408/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.465/
# [409/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.466/
# [410/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.467/
# [411/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.468/
# [412/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.469/
# [413/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.47/
# [414/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.470/
# [415/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.471/
# [416/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.472/
# [417/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.473/
# [418/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.474/
# [419/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.475/
# [420/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.476/
# [421/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.477/
# [422/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.478/
# [423/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.479/
# [424/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.48/
# [425/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.480/
# [426/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.481/
# [427/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.482/
# [428/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.483/
# [429/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.484/
# [430/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.485/
# [431/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.486/
# [432/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.487/
# [433/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.488/
# [434/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.489/
# [435/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.49/
# [436/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.490/
# [437/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.491/
# [438/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.492/
# [439/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.493/
# [440/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.494/
# [441/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.495/
# [442/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.496/
# [443/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.497/
# [444/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.498/
# [445/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.499/
# [446/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.5/
# [447/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.50/
# [448/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.500/
# [449/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.501/
# [450/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.502/
# [451/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.503/
# [452/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.504/
# [453/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.505/
# [454/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.506/
# [455/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.507/
# [456/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.508/
# [457/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.509/
# [458/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.51/
# [459/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.510/
# [460/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.511/
# [461/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.512/
# [462/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.513/
# [463/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.514/
# [464/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.515/
# [465/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.516/
# [466/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.517/
# [467/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.518/
# [468/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.519/
# [469/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.52/
# [470/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.520/
# [471/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.521/
# [472/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.522/
# [473/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.523/
# [474/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.524/
# [475/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.525/
# [476/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.526/
# [477/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.527/
# [478/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.528/
# [479/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.529/
# [480/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.53/
# [481/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.530/
# [482/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.531/
# [483/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.532/
# [484/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.533/
# [485/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.534/
# [486/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.535/
# [487/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.536/
# [488/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.537/
# [489/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.538/
# [490/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.539/
# [491/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.54/
# [492/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.540/
# [493/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.541/
# [494/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.542/
# [495/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.543/
# [496/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.544/
# [497/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.545/
# [498/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.546/
# [499/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.547/
# [500/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.548/
# [501/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.549/
# [502/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.55/
# [503/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.550/
# [504/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.551/
# [505/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.552/
# [506/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.553/
# [507/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.554/
# [508/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.555/
# [509/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.556/
# [510/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.557/
# [511/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.558/
# [512/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.559/
# [513/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.56/
# [514/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.560/
# [515/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.561/
# [516/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.562/
# [517/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.563/
# [518/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.564/
# [519/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.565/
# [520/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.566/
# [521/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.567/
# [522/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.568/
# [523/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.569/
# [524/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.57/
# [525/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.570/
# [526/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.571/
# [527/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.572/
# [528/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.573/
# [529/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.574/
# [530/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.575/
# [531/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.576/
# [532/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.577/
# [533/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.578/
# [534/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.579/
# [535/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.58/
# [536/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.580/
# [537/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.581/
# [538/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.582/
# [539/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.583/
# [540/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.584/
# [541/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.585/
# [542/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.586/
# [543/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.587/
# [544/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.588/
# [545/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.589/
# [546/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.59/
# [547/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.590/
# [548/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.591/
# [549/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.592/
# [550/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.593/
# [551/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.594/
# [552/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.595/
# [553/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.596/
# [554/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.597/
# [555/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.598/
# [556/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.599/
# [557/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.6/
# [558/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.60/
# [559/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.600/
# [560/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.601/
# [561/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.602/
# [562/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.603/
# [563/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.604/
# [564/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.605/
# [565/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.606/
# [566/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.607/
# [567/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.608/
# [568/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.609/
# [569/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.61/
# [570/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.610/
# [571/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.611/
# [572/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.612/
# [573/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.613/
# [574/848] Fetching abstract from https://aclanthology.org/2021.emnlp-main.614/
# ...
# [242/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.315/
# [243/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.316/
# [244/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.317/
# [245/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.318/
# [246/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.319/
# [247/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.32/
# [248/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.320/
# [249/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.321/
# [250/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.322/
# [251/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.323/
# [252/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.324/
# [253/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.325/
# [254/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.326/
# [255/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.327/
# [256/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.328/
# [257/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.329/
# [258/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.33/
# [259/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.330/
# [260/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.331/
# [261/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.332/
# [262/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.333/
# [263/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.334/
# [264/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.335/
# [265/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.336/
# [266/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.337/
# [267/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.338/
# [268/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.339/
# [269/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.34/
# [270/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.340/
# [271/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.341/
# [272/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.342/
# [273/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.343/
# [274/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.344/
# [275/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.345/
# [276/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.346/
# [277/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.347/
# [278/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.348/
# [279/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.349/
# [280/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.35/
# [281/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.350/
# [282/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.351/
# [283/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.352/
# [284/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.353/
# [285/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.354/
# [286/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.355/
# [287/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.356/
# [288/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.357/
# [289/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.358/
# [290/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.359/
# [291/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.36/
# [292/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.360/
# [293/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.361/
# [294/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.362/
# [295/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.363/
# [296/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.364/
# [297/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.365/
# [298/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.366/
# [299/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.367/
# [300/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.368/
# [301/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.369/
# [302/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.37/
# [303/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.370/
# [304/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.371/
# [305/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.372/
# [306/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.373/
# [307/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.374/
# [308/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.375/
# [309/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.376/
# [310/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.377/
# [311/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.378/
# [312/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.379/
# [313/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.38/
# [314/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.380/
# [315/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.381/
# [316/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.382/
# [317/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.383/
# [318/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.384/
# [319/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.385/
# [320/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.386/
# [321/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.387/
# [322/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.388/
# [323/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.389/
# [324/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.39/
# [325/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.390/
# [326/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.391/
# [327/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.392/
# [328/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.393/
# [329/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.394/
# [330/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.395/
# [331/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.396/
# [332/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.397/
# [333/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.398/
# [334/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.399/
# [335/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.4/
# [336/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.40/
# [337/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.400/
# [338/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.401/
# [339/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.402/
# [340/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.403/
# [341/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.404/
# [342/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.405/
# [343/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.406/
# [344/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.407/
# [345/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.408/
# [346/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.409/
# [347/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.41/
# [348/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.410/
# [349/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.411/
# [350/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.412/
# [351/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.413/
# [352/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.414/
# [353/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.415/
# [354/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.416/
# [355/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.417/
# [356/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.418/
# [357/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.419/
# [358/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.42/
# [359/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.420/
# [360/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.421/
# [361/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.422/
# [362/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.423/
# [363/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.424/
# [364/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.425/
# [365/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.426/
# [366/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.427/
# [367/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.428/
# [368/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.429/
# [369/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.43/
# [370/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.430/
# [371/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.431/
# [372/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.432/
# [373/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.433/
# [374/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.434/
# [375/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.435/
# [376/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.436/
# [377/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.437/
# [378/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.438/
# [379/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.439/
# [380/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.44/
# [381/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.440/
# [382/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.441/
# [383/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.442/
# [384/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.45/
# [385/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.46/
# [386/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.47/
# [387/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.48/
# [388/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.49/
# [389/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.5/
# [390/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.50/
# [391/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.51/
# [392/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.52/
# [393/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.53/
# [394/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.54/
# [395/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.55/
# [396/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.56/
# [397/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.57/
# [398/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.58/
# [399/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.59/
# [400/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.6/
# [401/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.60/
# [402/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.61/
# [403/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.62/
# [404/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.63/
# [405/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.64/
# [406/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.65/
# [407/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.66/
# [408/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.67/
# [409/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.68/
# [410/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.69/
# [411/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.7/
# [412/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.70/
# [413/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.71/
# [414/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.72/
# [415/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.73/
# [416/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.74/
# [417/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.75/
# [418/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.76/
# [419/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.77/
# [420/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.78/
# [421/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.79/
# [422/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.8/
# [423/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.80/
# [424/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.81/
# [425/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.82/
# [426/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.83/
# [427/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.84/
# [428/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.85/
# [429/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.86/
# [430/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.87/
# [431/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.88/
# [432/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.89/
# [433/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.9/
# [434/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.90/
# [435/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.91/
# [436/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.92/
# [437/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.93/
# [438/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.94/
# [439/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.95/
# [440/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.96/
# [441/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.97/
# [442/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.98/
# [443/443] Fetching abstract from https://aclanthology.org/2022.naacl-main.99/
# Found 0 NAACL 2023 main papers.
# Found 0 NAACL 2024 main papers.

# %%
import requests
from bs4 import BeautifulSoup
import time

VOLUME_URL = "https://aclanthology.org/volumes/2024.naacl-long/"

def get_paper_links():
    response = requests.get(VOLUME_URL)
    if response.status_code != 200:
        print(f"Failed to access {VOLUME_URL}")
        return []

    soup = BeautifulSoup(response.content, 'html.parser')

    paper_links = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        if href.startswith("/2024.naacl-long.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)

    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    links = get_paper_links()
    print(f"Found {len(links)} NAACL 2024 long papers.")
    with open("naacl_2024_long_abstracts.txt", "w", encoding="utf-8") as f:
        for i, url in enumerate(links, 1):
            print(f"[{i}/{len(links)}] Fetching abstract from {url}")
            abstract = extract_abstract(url)
            if abstract:
                f.write(f"URL: {url}\n")
                f.write(f"Abstract: {abstract}\n")
                f.write("="*80 + "\n")
            else:
                print(f"No abstract found for: {url}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# Found 488 NAACL 2024 long papers.
# [1/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.0/
# ⚠️ No abstract found for: https://aclanthology.org/2024.naacl-long.0/
# [2/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.1/
# [3/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.10/
# [4/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.100/
# [5/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.101/
# [6/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.102/
# [7/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.103/
# [8/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.104/
# [9/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.105/
# [10/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.106/
# [11/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.107/
# [12/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.108/
# [13/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.109/
# [14/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.11/
# [15/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.110/
# [16/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.111/
# [17/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.112/
# [18/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.113/
# [19/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.114/
# [20/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.115/
# [21/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.116/
# [22/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.117/
# [23/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.118/
# [24/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.119/
# [25/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.12/
# [26/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.120/
# [27/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.121/
# [28/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.122/
# [29/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.123/
# [30/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.124/
# [31/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.125/
# [32/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.126/
# [33/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.127/
# [34/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.128/
# [35/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.129/
# [36/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.13/
# [37/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.130/
# [38/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.131/
# [39/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.132/
# [40/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.133/
# [41/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.134/
# [42/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.135/
# [43/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.136/
# [44/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.137/
# [45/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.138/
# [46/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.139/
# [47/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.14/
# [48/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.140/
# [49/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.141/
# [50/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.142/
# [51/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.143/
# [52/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.144/
# [53/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.145/
# [54/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.146/
# [55/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.147/
# [56/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.148/
# [57/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.149/
# [58/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.15/
# [59/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.150/
# [60/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.151/
# [61/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.152/
# [62/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.153/
# [63/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.154/
# [64/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.155/
# [65/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.156/
# [66/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.157/
# [67/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.158/
# [68/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.159/
# [69/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.16/
# [70/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.160/
# [71/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.161/
# [72/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.162/
# [73/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.163/
# [74/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.164/
# [75/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.165/
# [76/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.166/
# [77/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.167/
# [78/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.168/
# [79/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.169/
# [80/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.17/
# [81/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.170/
# [82/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.171/
# [83/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.172/
# [84/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.173/
# [85/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.174/
# [86/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.175/
# [87/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.176/
# [88/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.177/
# [89/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.178/
# [90/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.179/
# [91/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.18/
# [92/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.180/
# [93/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.181/
# [94/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.182/
# [95/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.183/
# [96/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.184/
# [97/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.185/
# [98/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.186/
# [99/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.187/
# [100/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.188/
# [101/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.189/
# [102/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.19/
# [103/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.190/
# [104/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.191/
# [105/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.192/
# [106/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.193/
# [107/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.194/
# [108/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.195/
# [109/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.196/
# [110/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.197/
# [111/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.198/
# [112/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.199/
# [113/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.2/
# [114/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.20/
# [115/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.200/
# [116/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.201/
# [117/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.202/
# [118/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.203/
# [119/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.204/
# [120/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.205/
# [121/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.206/
# [122/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.207/
# [123/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.208/
# [124/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.209/
# [125/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.21/
# [126/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.210/
# [127/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.211/
# [128/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.212/
# [129/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.213/
# [130/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.214/
# [131/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.215/
# [132/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.216/
# [133/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.217/
# [134/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.218/
# [135/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.219/
# [136/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.22/
# [137/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.220/
# [138/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.221/
# [139/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.222/
# [140/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.223/
# [141/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.224/
# [142/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.225/
# [143/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.226/
# [144/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.227/
# [145/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.228/
# [146/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.229/
# [147/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.23/
# [148/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.230/
# [149/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.231/
# [150/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.232/
# [151/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.233/
# [152/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.234/
# [153/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.235/
# [154/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.236/
# [155/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.237/
# [156/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.238/
# [157/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.239/
# [158/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.24/
# [159/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.240/
# [160/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.241/
# [161/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.242/
# [162/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.243/
# [163/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.244/
# [164/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.245/
# [165/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.246/
# [166/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.247/
# [167/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.248/
# [168/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.249/
# [169/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.25/
# [170/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.250/
# [171/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.251/
# [172/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.252/
# [173/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.253/
# [174/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.254/
# [175/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.255/
# [176/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.256/
# [177/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.257/
# [178/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.258/
# [179/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.259/
# [180/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.26/
# [181/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.260/
# [182/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.261/
# [183/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.262/
# [184/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.263/
# [185/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.264/
# [186/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.265/
# [187/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.266/
# [188/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.267/
# [189/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.268/
# [190/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.269/
# [191/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.27/
# [192/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.270/
# [193/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.271/
# [194/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.272/
# [195/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.273/
# [196/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.274/
# [197/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.275/
# [198/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.276/
# [199/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.277/
# [200/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.278/
# [201/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.279/
# [202/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.28/
# [203/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.280/
# [204/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.281/
# [205/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.282/
# [206/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.283/
# [207/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.284/
# [208/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.285/
# [209/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.286/
# [210/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.287/
# [211/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.288/
# [212/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.289/
# [213/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.29/
# [214/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.290/
# [215/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.291/
# [216/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.292/
# [217/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.293/
# [218/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.294/
# [219/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.295/
# [220/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.296/
# [221/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.297/
# [222/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.298/
# [223/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.299/
# [224/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.3/
# [225/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.30/
# [226/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.300/
# [227/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.301/
# [228/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.302/
# [229/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.303/
# [230/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.304/
# [231/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.305/
# [232/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.306/
# [233/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.307/
# [234/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.308/
# [235/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.309/
# [236/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.31/
# [237/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.310/
# [238/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.311/
# [239/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.312/
# [240/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.313/
# [241/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.314/
# [242/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.315/
# [243/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.316/
# [244/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.317/
# [245/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.318/
# [246/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.319/
# [247/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.32/
# [248/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.320/
# [249/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.321/
# [250/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.322/
# [251/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.323/
# [252/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.324/
# [253/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.325/
# [254/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.326/
# [255/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.327/
# [256/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.328/
# [257/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.329/
# [258/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.33/
# [259/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.330/
# [260/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.331/
# [261/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.332/
# [262/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.333/
# [263/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.334/
# [264/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.335/
# [265/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.336/
# [266/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.337/
# [267/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.338/
# [268/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.339/
# [269/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.34/
# [270/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.340/
# [271/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.341/
# [272/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.342/
# [273/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.343/
# [274/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.344/
# [275/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.345/
# [276/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.346/
# [277/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.347/
# [278/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.348/
# [279/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.349/
# [280/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.35/
# [281/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.350/
# [282/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.351/
# [283/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.352/
# [284/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.353/
# [285/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.354/
# [286/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.355/
# [287/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.356/
# [288/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.357/
# [289/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.358/
# [290/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.359/
# [291/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.36/
# [292/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.360/
# [293/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.361/
# [294/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.362/
# [295/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.363/
# [296/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.364/
# [297/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.365/
# [298/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.366/
# [299/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.367/
# [300/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.368/
# [301/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.369/
# [302/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.37/
# [303/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.370/
# [304/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.371/
# [305/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.372/
# [306/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.373/
# [307/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.374/
# [308/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.375/
# [309/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.376/
# [310/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.377/
# [311/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.378/
# [312/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.379/
# [313/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.38/
# [314/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.380/
# [315/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.381/
# [316/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.382/
# [317/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.383/
# [318/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.384/
# [319/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.385/
# [320/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.386/
# [321/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.387/
# [322/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.388/
# [323/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.389/
# [324/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.39/
# [325/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.390/
# [326/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.391/
# [327/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.392/
# [328/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.393/
# [329/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.394/
# [330/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.395/
# [331/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.396/
# [332/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.397/
# [333/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.398/
# [334/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.399/
# [335/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.4/
# [336/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.40/
# [337/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.400/
# [338/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.401/
# [339/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.402/
# [340/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.403/
# [341/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.404/
# [342/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.405/
# [343/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.406/
# [344/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.407/
# [345/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.408/
# [346/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.409/
# [347/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.41/
# [348/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.410/
# [349/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.411/
# [350/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.412/
# [351/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.413/
# [352/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.414/
# [353/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.415/
# [354/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.416/
# [355/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.417/
# [356/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.418/
# [357/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.419/
# [358/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.42/
# [359/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.420/
# [360/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.421/
# [361/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.422/
# [362/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.423/
# [363/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.424/
# [364/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.425/
# [365/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.426/
# [366/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.427/
# [367/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.428/
# [368/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.429/
# [369/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.43/
# [370/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.430/
# [371/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.431/
# [372/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.432/
# [373/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.433/
# [374/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.434/
# [375/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.435/
# [376/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.436/
# [377/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.437/
# [378/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.438/
# [379/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.439/
# [380/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.44/
# [381/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.440/
# [382/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.441/
# [383/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.442/
# [384/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.443/
# [385/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.444/
# [386/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.445/
# [387/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.446/
# [388/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.447/
# [389/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.448/
# [390/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.449/
# [391/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.45/
# [392/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.450/
# [393/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.451/
# [394/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.452/
# [395/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.453/
# [396/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.454/
# [397/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.455/
# [398/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.456/
# [399/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.457/
# [400/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.458/
# [401/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.459/
# [402/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.46/
# [403/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.460/
# [404/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.461/
# [405/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.462/
# [406/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.463/
# [407/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.464/
# [408/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.465/
# [409/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.466/
# [410/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.467/
# [411/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.468/
# [412/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.469/
# [413/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.47/
# [414/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.470/
# [415/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.471/
# [416/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.472/
# [417/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.473/
# [418/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.474/
# [419/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.475/
# [420/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.476/
# [421/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.477/
# [422/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.478/
# [423/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.479/
# [424/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.48/
# [425/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.480/
# [426/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.481/
# [427/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.482/
# [428/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.483/
# [429/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.484/
# [430/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.485/
# [431/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.486/
# [432/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.487/
# [433/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.49/
# [434/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.5/
# [435/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.50/
# [436/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.51/
# [437/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.52/
# [438/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.53/
# [439/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.54/
# [440/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.55/
# [441/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.56/
# [442/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.57/
# [443/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.58/
# [444/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.59/
# [445/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.6/
# [446/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.60/
# [447/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.61/
# [448/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.62/
# [449/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.63/
# [450/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.64/
# [451/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.65/
# [452/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.66/
# [453/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.67/
# [454/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.68/
# [455/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.69/
# [456/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.7/
# [457/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.70/
# [458/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.71/
# [459/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.72/
# [460/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.73/
# [461/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.74/
# [462/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.75/
# [463/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.76/
# [464/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.77/
# [465/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.78/
# [466/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.79/
# [467/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.8/
# [468/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.80/
# [469/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.81/
# [470/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.82/
# [471/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.83/
# [472/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.84/
# [473/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.85/
# [474/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.86/
# [475/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.87/
# [476/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.88/
# [477/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.89/
# [478/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.9/
# [479/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.90/
# [480/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.91/
# [481/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.92/
# [482/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.93/
# [483/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.94/
# [484/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.95/
# [485/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.96/
# [486/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.97/
# [487/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.98/
# [488/488] Fetching abstract from https://aclanthology.org/2024.naacl-long.99/

# %%
import requests
from bs4 import BeautifulSoup
import time

VOLUME_URL = "https://aclanthology.org/volumes/2024.naacl-short/"

def get_paper_links():
    response = requests.get(VOLUME_URL)
    if response.status_code != 200:
        print(f"Failed to access {VOLUME_URL}")
        return []

    soup = BeautifulSoup(response.content, 'html.parser')

    paper_links = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        if href.startswith("/2024.naacl-short.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)

    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    links = get_paper_links()
    print(f"Found {len(links)} NAACL 2024 short papers.")
    with open("naacl_2024_short_abstracts.txt", "w", encoding="utf-8") as f:
        for i, url in enumerate(links, 1):
            print(f"[{i}/{len(links)}] Fetching abstract from {url}")
            abstract = extract_abstract(url)
            if abstract:
                f.write(f"URL: {url}\n")
                f.write(f"Abstract: {abstract}\n")
                f.write("="*80 + "\n")
            else:
                print(f"No abstract found for: {url}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# 📄 Found 76 NAACL 2024 short papers.
# [1/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.0/
# ⚠️ No abstract found for: https://aclanthology.org/2024.naacl-short.0/
# [2/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.1/
# [3/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.10/
# [4/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.11/
# [5/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.12/
# [6/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.13/
# [7/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.14/
# [8/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.15/
# [9/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.16/
# [10/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.17/
# [11/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.18/
# [12/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.19/
# [13/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.2/
# [14/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.20/
# [15/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.21/
# [16/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.22/
# [17/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.23/
# [18/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.24/
# [19/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.25/
# [20/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.26/
# [21/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.27/
# [22/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.28/
# [23/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.29/
# [24/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.3/
# [25/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.30/
# [26/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.31/
# [27/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.32/
# [28/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.33/
# [29/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.34/
# [30/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.35/
# [31/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.36/
# [32/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.37/
# [33/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.38/
# [34/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.39/
# [35/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.4/
# [36/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.40/
# [37/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.41/
# [38/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.42/
# [39/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.43/
# [40/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.44/
# [41/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.45/
# [42/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.46/
# [43/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.47/
# [44/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.48/
# [45/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.49/
# [46/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.5/
# [47/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.50/
# [48/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.51/
# [49/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.52/
# [50/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.53/
# [51/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.54/
# [52/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.55/
# [53/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.56/
# [54/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.57/
# [55/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.58/
# [56/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.59/
# [57/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.6/
# [58/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.60/
# [59/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.61/
# [60/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.62/
# [61/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.63/
# [62/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.64/
# [63/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.65/
# [64/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.66/
# [65/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.67/
# [66/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.68/
# [67/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.69/
# [68/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.7/
# [69/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.70/
# [70/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.71/
# [71/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.72/
# [72/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.73/
# [73/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.74/
# [74/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.75/
# [75/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.8/
# [76/76] Fetching abstract from https://aclanthology.org/2024.naacl-short.9/

# %%
import requests
from bs4 import BeautifulSoup
import time

VOLUME_URL = "https://aclanthology.org/volumes/2021.acl-long/"

def get_paper_links():
    response = requests.get(VOLUME_URL)
    if response.status_code != 200:
        print(f"Failed to access {VOLUME_URL}")
        return []

    soup = BeautifulSoup(response.content, 'html.parser')

    paper_links = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        if href.startswith("/2021.acl-long.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)

    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    links = get_paper_links()
    print(f"Found {len(links)} ACL 2021 long papers.")
    with open("acl_2021_long_abstracts.txt", "w", encoding="utf-8") as f:
        for i, url in enumerate(links, 1):
            print(f"[{i}/{len(links)}] Fetching abstract from {url}")
            abstract = extract_abstract(url)
            if abstract:
                f.write(f"URL: {url}\n")
                f.write(f"Abstract: {abstract}\n")
                f.write("="*80 + "\n")
            else:
                print(f"No abstract found for: {url}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# 📄 Found 572 ACL 2021 long papers.
# [1/572] Fetching abstract from https://aclanthology.org/2021.acl-long.0/
# ⚠️ No abstract found for: https://aclanthology.org/2021.acl-long.0/
# [2/572] Fetching abstract from https://aclanthology.org/2021.acl-long.1/
# [3/572] Fetching abstract from https://aclanthology.org/2021.acl-long.10/
# [4/572] Fetching abstract from https://aclanthology.org/2021.acl-long.100/
# [5/572] Fetching abstract from https://aclanthology.org/2021.acl-long.101/
# [6/572] Fetching abstract from https://aclanthology.org/2021.acl-long.102/
# [7/572] Fetching abstract from https://aclanthology.org/2021.acl-long.103/
# [8/572] Fetching abstract from https://aclanthology.org/2021.acl-long.104/
# [9/572] Fetching abstract from https://aclanthology.org/2021.acl-long.105/
# [10/572] Fetching abstract from https://aclanthology.org/2021.acl-long.106/
# [11/572] Fetching abstract from https://aclanthology.org/2021.acl-long.107/
# [12/572] Fetching abstract from https://aclanthology.org/2021.acl-long.108/
# [13/572] Fetching abstract from https://aclanthology.org/2021.acl-long.109/
# [14/572] Fetching abstract from https://aclanthology.org/2021.acl-long.11/
# [15/572] Fetching abstract from https://aclanthology.org/2021.acl-long.110/
# [16/572] Fetching abstract from https://aclanthology.org/2021.acl-long.111/
# [17/572] Fetching abstract from https://aclanthology.org/2021.acl-long.112/
# [18/572] Fetching abstract from https://aclanthology.org/2021.acl-long.113/
# [19/572] Fetching abstract from https://aclanthology.org/2021.acl-long.114/
# [20/572] Fetching abstract from https://aclanthology.org/2021.acl-long.115/
# [21/572] Fetching abstract from https://aclanthology.org/2021.acl-long.116/
# [22/572] Fetching abstract from https://aclanthology.org/2021.acl-long.117/
# [23/572] Fetching abstract from https://aclanthology.org/2021.acl-long.118/
# [24/572] Fetching abstract from https://aclanthology.org/2021.acl-long.119/
# [25/572] Fetching abstract from https://aclanthology.org/2021.acl-long.12/
# [26/572] Fetching abstract from https://aclanthology.org/2021.acl-long.120/
# [27/572] Fetching abstract from https://aclanthology.org/2021.acl-long.121/
# [28/572] Fetching abstract from https://aclanthology.org/2021.acl-long.122/
# [29/572] Fetching abstract from https://aclanthology.org/2021.acl-long.123/
# [30/572] Fetching abstract from https://aclanthology.org/2021.acl-long.124/
# [31/572] Fetching abstract from https://aclanthology.org/2021.acl-long.125/
# [32/572] Fetching abstract from https://aclanthology.org/2021.acl-long.126/
# [33/572] Fetching abstract from https://aclanthology.org/2021.acl-long.127/
# [34/572] Fetching abstract from https://aclanthology.org/2021.acl-long.128/
# [35/572] Fetching abstract from https://aclanthology.org/2021.acl-long.129/
# [36/572] Fetching abstract from https://aclanthology.org/2021.acl-long.13/
# [37/572] Fetching abstract from https://aclanthology.org/2021.acl-long.130/
# [38/572] Fetching abstract from https://aclanthology.org/2021.acl-long.131/
# [39/572] Fetching abstract from https://aclanthology.org/2021.acl-long.132/
# [40/572] Fetching abstract from https://aclanthology.org/2021.acl-long.133/
# [41/572] Fetching abstract from https://aclanthology.org/2021.acl-long.134/
# [42/572] Fetching abstract from https://aclanthology.org/2021.acl-long.135/
# [43/572] Fetching abstract from https://aclanthology.org/2021.acl-long.136/
# [44/572] Fetching abstract from https://aclanthology.org/2021.acl-long.137/
# [45/572] Fetching abstract from https://aclanthology.org/2021.acl-long.138/
# [46/572] Fetching abstract from https://aclanthology.org/2021.acl-long.139/
# [47/572] Fetching abstract from https://aclanthology.org/2021.acl-long.14/
# [48/572] Fetching abstract from https://aclanthology.org/2021.acl-long.140/
# [49/572] Fetching abstract from https://aclanthology.org/2021.acl-long.141/
# [50/572] Fetching abstract from https://aclanthology.org/2021.acl-long.142/
# [51/572] Fetching abstract from https://aclanthology.org/2021.acl-long.143/
# [52/572] Fetching abstract from https://aclanthology.org/2021.acl-long.144/
# [53/572] Fetching abstract from https://aclanthology.org/2021.acl-long.145/
# [54/572] Fetching abstract from https://aclanthology.org/2021.acl-long.146/
# [55/572] Fetching abstract from https://aclanthology.org/2021.acl-long.147/
# [56/572] Fetching abstract from https://aclanthology.org/2021.acl-long.148/
# [57/572] Fetching abstract from https://aclanthology.org/2021.acl-long.149/
# [58/572] Fetching abstract from https://aclanthology.org/2021.acl-long.15/
# [59/572] Fetching abstract from https://aclanthology.org/2021.acl-long.150/
# [60/572] Fetching abstract from https://aclanthology.org/2021.acl-long.151/
# [61/572] Fetching abstract from https://aclanthology.org/2021.acl-long.152/
# [62/572] Fetching abstract from https://aclanthology.org/2021.acl-long.153/
# [63/572] Fetching abstract from https://aclanthology.org/2021.acl-long.154/
# [64/572] Fetching abstract from https://aclanthology.org/2021.acl-long.155/
# [65/572] Fetching abstract from https://aclanthology.org/2021.acl-long.156/
# [66/572] Fetching abstract from https://aclanthology.org/2021.acl-long.157/
# [67/572] Fetching abstract from https://aclanthology.org/2021.acl-long.158/
# [68/572] Fetching abstract from https://aclanthology.org/2021.acl-long.159/
# [69/572] Fetching abstract from https://aclanthology.org/2021.acl-long.16/
# [70/572] Fetching abstract from https://aclanthology.org/2021.acl-long.160/
# [71/572] Fetching abstract from https://aclanthology.org/2021.acl-long.161/
# [72/572] Fetching abstract from https://aclanthology.org/2021.acl-long.162/
# [73/572] Fetching abstract from https://aclanthology.org/2021.acl-long.163/
# [74/572] Fetching abstract from https://aclanthology.org/2021.acl-long.164/
# [75/572] Fetching abstract from https://aclanthology.org/2021.acl-long.165/
# [76/572] Fetching abstract from https://aclanthology.org/2021.acl-long.166/
# [77/572] Fetching abstract from https://aclanthology.org/2021.acl-long.167/
# [78/572] Fetching abstract from https://aclanthology.org/2021.acl-long.168/
# [79/572] Fetching abstract from https://aclanthology.org/2021.acl-long.169/
# [80/572] Fetching abstract from https://aclanthology.org/2021.acl-long.17/
# [81/572] Fetching abstract from https://aclanthology.org/2021.acl-long.170/
# [82/572] Fetching abstract from https://aclanthology.org/2021.acl-long.171/
# [83/572] Fetching abstract from https://aclanthology.org/2021.acl-long.172/
# [84/572] Fetching abstract from https://aclanthology.org/2021.acl-long.173/
# [85/572] Fetching abstract from https://aclanthology.org/2021.acl-long.174/
# [86/572] Fetching abstract from https://aclanthology.org/2021.acl-long.175/
# [87/572] Fetching abstract from https://aclanthology.org/2021.acl-long.176/
# [88/572] Fetching abstract from https://aclanthology.org/2021.acl-long.177/
# [89/572] Fetching abstract from https://aclanthology.org/2021.acl-long.178/
# [90/572] Fetching abstract from https://aclanthology.org/2021.acl-long.179/
# [91/572] Fetching abstract from https://aclanthology.org/2021.acl-long.18/
# [92/572] Fetching abstract from https://aclanthology.org/2021.acl-long.180/
# [93/572] Fetching abstract from https://aclanthology.org/2021.acl-long.181/
# [94/572] Fetching abstract from https://aclanthology.org/2021.acl-long.182/
# [95/572] Fetching abstract from https://aclanthology.org/2021.acl-long.183/
# [96/572] Fetching abstract from https://aclanthology.org/2021.acl-long.184/
# [97/572] Fetching abstract from https://aclanthology.org/2021.acl-long.185/
# [98/572] Fetching abstract from https://aclanthology.org/2021.acl-long.186/
# [99/572] Fetching abstract from https://aclanthology.org/2021.acl-long.187/
# [100/572] Fetching abstract from https://aclanthology.org/2021.acl-long.188/
# [101/572] Fetching abstract from https://aclanthology.org/2021.acl-long.189/
# [102/572] Fetching abstract from https://aclanthology.org/2021.acl-long.19/
# [103/572] Fetching abstract from https://aclanthology.org/2021.acl-long.190/
# [104/572] Fetching abstract from https://aclanthology.org/2021.acl-long.191/
# [105/572] Fetching abstract from https://aclanthology.org/2021.acl-long.192/
# [106/572] Fetching abstract from https://aclanthology.org/2021.acl-long.193/
# [107/572] Fetching abstract from https://aclanthology.org/2021.acl-long.194/
# [108/572] Fetching abstract from https://aclanthology.org/2021.acl-long.195/
# [109/572] Fetching abstract from https://aclanthology.org/2021.acl-long.196/
# [110/572] Fetching abstract from https://aclanthology.org/2021.acl-long.197/
# [111/572] Fetching abstract from https://aclanthology.org/2021.acl-long.198/
# [112/572] Fetching abstract from https://aclanthology.org/2021.acl-long.199/
# [113/572] Fetching abstract from https://aclanthology.org/2021.acl-long.2/
# [114/572] Fetching abstract from https://aclanthology.org/2021.acl-long.20/
# [115/572] Fetching abstract from https://aclanthology.org/2021.acl-long.200/
# [116/572] Fetching abstract from https://aclanthology.org/2021.acl-long.201/
# [117/572] Fetching abstract from https://aclanthology.org/2021.acl-long.202/
# [118/572] Fetching abstract from https://aclanthology.org/2021.acl-long.203/
# [119/572] Fetching abstract from https://aclanthology.org/2021.acl-long.204/
# [120/572] Fetching abstract from https://aclanthology.org/2021.acl-long.205/
# [121/572] Fetching abstract from https://aclanthology.org/2021.acl-long.206/
# [122/572] Fetching abstract from https://aclanthology.org/2021.acl-long.207/
# [123/572] Fetching abstract from https://aclanthology.org/2021.acl-long.208/
# [124/572] Fetching abstract from https://aclanthology.org/2021.acl-long.209/
# [125/572] Fetching abstract from https://aclanthology.org/2021.acl-long.21/
# [126/572] Fetching abstract from https://aclanthology.org/2021.acl-long.210/
# [127/572] Fetching abstract from https://aclanthology.org/2021.acl-long.211/
# [128/572] Fetching abstract from https://aclanthology.org/2021.acl-long.212/
# [129/572] Fetching abstract from https://aclanthology.org/2021.acl-long.213/
# [130/572] Fetching abstract from https://aclanthology.org/2021.acl-long.214/
# [131/572] Fetching abstract from https://aclanthology.org/2021.acl-long.215/
# [132/572] Fetching abstract from https://aclanthology.org/2021.acl-long.216/
# [133/572] Fetching abstract from https://aclanthology.org/2021.acl-long.217/
# [134/572] Fetching abstract from https://aclanthology.org/2021.acl-long.218/
# [135/572] Fetching abstract from https://aclanthology.org/2021.acl-long.219/
# [136/572] Fetching abstract from https://aclanthology.org/2021.acl-long.22/
# [137/572] Fetching abstract from https://aclanthology.org/2021.acl-long.220/
# [138/572] Fetching abstract from https://aclanthology.org/2021.acl-long.221/
# [139/572] Fetching abstract from https://aclanthology.org/2021.acl-long.222/
# [140/572] Fetching abstract from https://aclanthology.org/2021.acl-long.223/
# [141/572] Fetching abstract from https://aclanthology.org/2021.acl-long.224/
# [142/572] Fetching abstract from https://aclanthology.org/2021.acl-long.225/
# [143/572] Fetching abstract from https://aclanthology.org/2021.acl-long.226/
# [144/572] Fetching abstract from https://aclanthology.org/2021.acl-long.227/
# [145/572] Fetching abstract from https://aclanthology.org/2021.acl-long.228/
# [146/572] Fetching abstract from https://aclanthology.org/2021.acl-long.229/
# [147/572] Fetching abstract from https://aclanthology.org/2021.acl-long.23/
# [148/572] Fetching abstract from https://aclanthology.org/2021.acl-long.230/
# [149/572] Fetching abstract from https://aclanthology.org/2021.acl-long.231/
# [150/572] Fetching abstract from https://aclanthology.org/2021.acl-long.232/
# [151/572] Fetching abstract from https://aclanthology.org/2021.acl-long.233/
# [152/572] Fetching abstract from https://aclanthology.org/2021.acl-long.234/
# [153/572] Fetching abstract from https://aclanthology.org/2021.acl-long.235/
# [154/572] Fetching abstract from https://aclanthology.org/2021.acl-long.236/
# [155/572] Fetching abstract from https://aclanthology.org/2021.acl-long.237/
# [156/572] Fetching abstract from https://aclanthology.org/2021.acl-long.238/
# [157/572] Fetching abstract from https://aclanthology.org/2021.acl-long.239/
# [158/572] Fetching abstract from https://aclanthology.org/2021.acl-long.24/
# [159/572] Fetching abstract from https://aclanthology.org/2021.acl-long.240/
# [160/572] Fetching abstract from https://aclanthology.org/2021.acl-long.241/
# [161/572] Fetching abstract from https://aclanthology.org/2021.acl-long.242/
# [162/572] Fetching abstract from https://aclanthology.org/2021.acl-long.243/
# [163/572] Fetching abstract from https://aclanthology.org/2021.acl-long.244/
# [164/572] Fetching abstract from https://aclanthology.org/2021.acl-long.245/
# [165/572] Fetching abstract from https://aclanthology.org/2021.acl-long.246/
# [166/572] Fetching abstract from https://aclanthology.org/2021.acl-long.247/
# [167/572] Fetching abstract from https://aclanthology.org/2021.acl-long.248/
# [168/572] Fetching abstract from https://aclanthology.org/2021.acl-long.249/
# [169/572] Fetching abstract from https://aclanthology.org/2021.acl-long.25/
# [170/572] Fetching abstract from https://aclanthology.org/2021.acl-long.250/
# [171/572] Fetching abstract from https://aclanthology.org/2021.acl-long.251/
# [172/572] Fetching abstract from https://aclanthology.org/2021.acl-long.252/
# [173/572] Fetching abstract from https://aclanthology.org/2021.acl-long.253/
# [174/572] Fetching abstract from https://aclanthology.org/2021.acl-long.254/
# [175/572] Fetching abstract from https://aclanthology.org/2021.acl-long.255/
# [176/572] Fetching abstract from https://aclanthology.org/2021.acl-long.256/
# [177/572] Fetching abstract from https://aclanthology.org/2021.acl-long.257/
# [178/572] Fetching abstract from https://aclanthology.org/2021.acl-long.258/
# [179/572] Fetching abstract from https://aclanthology.org/2021.acl-long.259/
# [180/572] Fetching abstract from https://aclanthology.org/2021.acl-long.26/
# [181/572] Fetching abstract from https://aclanthology.org/2021.acl-long.260/
# [182/572] Fetching abstract from https://aclanthology.org/2021.acl-long.261/
# [183/572] Fetching abstract from https://aclanthology.org/2021.acl-long.262/
# [184/572] Fetching abstract from https://aclanthology.org/2021.acl-long.263/
# [185/572] Fetching abstract from https://aclanthology.org/2021.acl-long.264/
# [186/572] Fetching abstract from https://aclanthology.org/2021.acl-long.265/
# [187/572] Fetching abstract from https://aclanthology.org/2021.acl-long.266/
# [188/572] Fetching abstract from https://aclanthology.org/2021.acl-long.267/
# [189/572] Fetching abstract from https://aclanthology.org/2021.acl-long.268/
# [190/572] Fetching abstract from https://aclanthology.org/2021.acl-long.269/
# [191/572] Fetching abstract from https://aclanthology.org/2021.acl-long.27/
# [192/572] Fetching abstract from https://aclanthology.org/2021.acl-long.270/
# [193/572] Fetching abstract from https://aclanthology.org/2021.acl-long.271/
# [194/572] Fetching abstract from https://aclanthology.org/2021.acl-long.272/
# [195/572] Fetching abstract from https://aclanthology.org/2021.acl-long.273/
# [196/572] Fetching abstract from https://aclanthology.org/2021.acl-long.274/
# [197/572] Fetching abstract from https://aclanthology.org/2021.acl-long.275/
# [198/572] Fetching abstract from https://aclanthology.org/2021.acl-long.276/
# [199/572] Fetching abstract from https://aclanthology.org/2021.acl-long.277/
# [200/572] Fetching abstract from https://aclanthology.org/2021.acl-long.278/
# [201/572] Fetching abstract from https://aclanthology.org/2021.acl-long.279/
# [202/572] Fetching abstract from https://aclanthology.org/2021.acl-long.28/
# [203/572] Fetching abstract from https://aclanthology.org/2021.acl-long.280/
# [204/572] Fetching abstract from https://aclanthology.org/2021.acl-long.281/
# [205/572] Fetching abstract from https://aclanthology.org/2021.acl-long.282/
# [206/572] Fetching abstract from https://aclanthology.org/2021.acl-long.283/
# [207/572] Fetching abstract from https://aclanthology.org/2021.acl-long.284/
# [208/572] Fetching abstract from https://aclanthology.org/2021.acl-long.285/
# [209/572] Fetching abstract from https://aclanthology.org/2021.acl-long.286/
# [210/572] Fetching abstract from https://aclanthology.org/2021.acl-long.287/
# [211/572] Fetching abstract from https://aclanthology.org/2021.acl-long.288/
# [212/572] Fetching abstract from https://aclanthology.org/2021.acl-long.289/
# [213/572] Fetching abstract from https://aclanthology.org/2021.acl-long.29/
# [214/572] Fetching abstract from https://aclanthology.org/2021.acl-long.290/
# [215/572] Fetching abstract from https://aclanthology.org/2021.acl-long.291/
# [216/572] Fetching abstract from https://aclanthology.org/2021.acl-long.292/
# [217/572] Fetching abstract from https://aclanthology.org/2021.acl-long.293/
# [218/572] Fetching abstract from https://aclanthology.org/2021.acl-long.294/
# [219/572] Fetching abstract from https://aclanthology.org/2021.acl-long.295/
# [220/572] Fetching abstract from https://aclanthology.org/2021.acl-long.296/
# [221/572] Fetching abstract from https://aclanthology.org/2021.acl-long.297/
# [222/572] Fetching abstract from https://aclanthology.org/2021.acl-long.298/
# [223/572] Fetching abstract from https://aclanthology.org/2021.acl-long.299/
# [224/572] Fetching abstract from https://aclanthology.org/2021.acl-long.3/
# [225/572] Fetching abstract from https://aclanthology.org/2021.acl-long.30/
# [226/572] Fetching abstract from https://aclanthology.org/2021.acl-long.300/
# [227/572] Fetching abstract from https://aclanthology.org/2021.acl-long.301/
# [228/572] Fetching abstract from https://aclanthology.org/2021.acl-long.302/
# [229/572] Fetching abstract from https://aclanthology.org/2021.acl-long.303/
# [230/572] Fetching abstract from https://aclanthology.org/2021.acl-long.304/
# [231/572] Fetching abstract from https://aclanthology.org/2021.acl-long.305/
# [232/572] Fetching abstract from https://aclanthology.org/2021.acl-long.306/
# [233/572] Fetching abstract from https://aclanthology.org/2021.acl-long.307/
# [234/572] Fetching abstract from https://aclanthology.org/2021.acl-long.308/
# [235/572] Fetching abstract from https://aclanthology.org/2021.acl-long.309/
# [236/572] Fetching abstract from https://aclanthology.org/2021.acl-long.31/
# [237/572] Fetching abstract from https://aclanthology.org/2021.acl-long.310/
# [238/572] Fetching abstract from https://aclanthology.org/2021.acl-long.311/
# [239/572] Fetching abstract from https://aclanthology.org/2021.acl-long.312/
# [240/572] Fetching abstract from https://aclanthology.org/2021.acl-long.313/
# [241/572] Fetching abstract from https://aclanthology.org/2021.acl-long.314/
# [242/572] Fetching abstract from https://aclanthology.org/2021.acl-long.315/
# [243/572] Fetching abstract from https://aclanthology.org/2021.acl-long.316/
# [244/572] Fetching abstract from https://aclanthology.org/2021.acl-long.317/
# [245/572] Fetching abstract from https://aclanthology.org/2021.acl-long.318/
# [246/572] Fetching abstract from https://aclanthology.org/2021.acl-long.319/
# [247/572] Fetching abstract from https://aclanthology.org/2021.acl-long.32/
# [248/572] Fetching abstract from https://aclanthology.org/2021.acl-long.320/
# [249/572] Fetching abstract from https://aclanthology.org/2021.acl-long.321/
# [250/572] Fetching abstract from https://aclanthology.org/2021.acl-long.322/
# [251/572] Fetching abstract from https://aclanthology.org/2021.acl-long.323/
# [252/572] Fetching abstract from https://aclanthology.org/2021.acl-long.324/
# [253/572] Fetching abstract from https://aclanthology.org/2021.acl-long.325/
# [254/572] Fetching abstract from https://aclanthology.org/2021.acl-long.326/
# [255/572] Fetching abstract from https://aclanthology.org/2021.acl-long.327/
# [256/572] Fetching abstract from https://aclanthology.org/2021.acl-long.328/
# [257/572] Fetching abstract from https://aclanthology.org/2021.acl-long.329/
# [258/572] Fetching abstract from https://aclanthology.org/2021.acl-long.33/
# [259/572] Fetching abstract from https://aclanthology.org/2021.acl-long.330/
# [260/572] Fetching abstract from https://aclanthology.org/2021.acl-long.331/
# [261/572] Fetching abstract from https://aclanthology.org/2021.acl-long.332/
# [262/572] Fetching abstract from https://aclanthology.org/2021.acl-long.333/
# [263/572] Fetching abstract from https://aclanthology.org/2021.acl-long.334/
# [264/572] Fetching abstract from https://aclanthology.org/2021.acl-long.335/
# [265/572] Fetching abstract from https://aclanthology.org/2021.acl-long.336/
# [266/572] Fetching abstract from https://aclanthology.org/2021.acl-long.337/
# [267/572] Fetching abstract from https://aclanthology.org/2021.acl-long.338/
# [268/572] Fetching abstract from https://aclanthology.org/2021.acl-long.339/
# [269/572] Fetching abstract from https://aclanthology.org/2021.acl-long.34/
# [270/572] Fetching abstract from https://aclanthology.org/2021.acl-long.340/
# [271/572] Fetching abstract from https://aclanthology.org/2021.acl-long.341/
# [272/572] Fetching abstract from https://aclanthology.org/2021.acl-long.342/
# [273/572] Fetching abstract from https://aclanthology.org/2021.acl-long.343/
# [274/572] Fetching abstract from https://aclanthology.org/2021.acl-long.344/
# [275/572] Fetching abstract from https://aclanthology.org/2021.acl-long.345/
# [276/572] Fetching abstract from https://aclanthology.org/2021.acl-long.346/
# [277/572] Fetching abstract from https://aclanthology.org/2021.acl-long.347/
# [278/572] Fetching abstract from https://aclanthology.org/2021.acl-long.348/
# [279/572] Fetching abstract from https://aclanthology.org/2021.acl-long.349/
# [280/572] Fetching abstract from https://aclanthology.org/2021.acl-long.35/
# [281/572] Fetching abstract from https://aclanthology.org/2021.acl-long.350/
# [282/572] Fetching abstract from https://aclanthology.org/2021.acl-long.351/
# [283/572] Fetching abstract from https://aclanthology.org/2021.acl-long.352/
# [284/572] Fetching abstract from https://aclanthology.org/2021.acl-long.353/
# [285/572] Fetching abstract from https://aclanthology.org/2021.acl-long.354/
# [286/572] Fetching abstract from https://aclanthology.org/2021.acl-long.355/
# [287/572] Fetching abstract from https://aclanthology.org/2021.acl-long.356/
# [288/572] Fetching abstract from https://aclanthology.org/2021.acl-long.357/
# [289/572] Fetching abstract from https://aclanthology.org/2021.acl-long.358/
# [290/572] Fetching abstract from https://aclanthology.org/2021.acl-long.359/
# [291/572] Fetching abstract from https://aclanthology.org/2021.acl-long.36/
# [292/572] Fetching abstract from https://aclanthology.org/2021.acl-long.360/
# [293/572] Fetching abstract from https://aclanthology.org/2021.acl-long.361/
# [294/572] Fetching abstract from https://aclanthology.org/2021.acl-long.362/
# [295/572] Fetching abstract from https://aclanthology.org/2021.acl-long.363/
# [296/572] Fetching abstract from https://aclanthology.org/2021.acl-long.364/
# [297/572] Fetching abstract from https://aclanthology.org/2021.acl-long.365/
# [298/572] Fetching abstract from https://aclanthology.org/2021.acl-long.366/
# [299/572] Fetching abstract from https://aclanthology.org/2021.acl-long.367/
# [300/572] Fetching abstract from https://aclanthology.org/2021.acl-long.368/
# [301/572] Fetching abstract from https://aclanthology.org/2021.acl-long.369/
# [302/572] Fetching abstract from https://aclanthology.org/2021.acl-long.37/
# [303/572] Fetching abstract from https://aclanthology.org/2021.acl-long.370/
# [304/572] Fetching abstract from https://aclanthology.org/2021.acl-long.371/
# [305/572] Fetching abstract from https://aclanthology.org/2021.acl-long.372/
# [306/572] Fetching abstract from https://aclanthology.org/2021.acl-long.373/
# [307/572] Fetching abstract from https://aclanthology.org/2021.acl-long.374/
# [308/572] Fetching abstract from https://aclanthology.org/2021.acl-long.375/
# [309/572] Fetching abstract from https://aclanthology.org/2021.acl-long.376/
# [310/572] Fetching abstract from https://aclanthology.org/2021.acl-long.377/
# [311/572] Fetching abstract from https://aclanthology.org/2021.acl-long.378/
# [312/572] Fetching abstract from https://aclanthology.org/2021.acl-long.379/
# [313/572] Fetching abstract from https://aclanthology.org/2021.acl-long.38/
# [314/572] Fetching abstract from https://aclanthology.org/2021.acl-long.380/
# [315/572] Fetching abstract from https://aclanthology.org/2021.acl-long.381/
# [316/572] Fetching abstract from https://aclanthology.org/2021.acl-long.382/
# [317/572] Fetching abstract from https://aclanthology.org/2021.acl-long.383/
# [318/572] Fetching abstract from https://aclanthology.org/2021.acl-long.384/
# [319/572] Fetching abstract from https://aclanthology.org/2021.acl-long.385/
# [320/572] Fetching abstract from https://aclanthology.org/2021.acl-long.386/
# [321/572] Fetching abstract from https://aclanthology.org/2021.acl-long.387/
# [322/572] Fetching abstract from https://aclanthology.org/2021.acl-long.388/
# [323/572] Fetching abstract from https://aclanthology.org/2021.acl-long.389/
# [324/572] Fetching abstract from https://aclanthology.org/2021.acl-long.39/
# [325/572] Fetching abstract from https://aclanthology.org/2021.acl-long.390/
# [326/572] Fetching abstract from https://aclanthology.org/2021.acl-long.391/
# [327/572] Fetching abstract from https://aclanthology.org/2021.acl-long.392/
# [328/572] Fetching abstract from https://aclanthology.org/2021.acl-long.393/
# [329/572] Fetching abstract from https://aclanthology.org/2021.acl-long.394/
# [330/572] Fetching abstract from https://aclanthology.org/2021.acl-long.395/
# [331/572] Fetching abstract from https://aclanthology.org/2021.acl-long.396/
# [332/572] Fetching abstract from https://aclanthology.org/2021.acl-long.397/
# [333/572] Fetching abstract from https://aclanthology.org/2021.acl-long.398/
# [334/572] Fetching abstract from https://aclanthology.org/2021.acl-long.399/
# [335/572] Fetching abstract from https://aclanthology.org/2021.acl-long.4/
# [336/572] Fetching abstract from https://aclanthology.org/2021.acl-long.40/
# [337/572] Fetching abstract from https://aclanthology.org/2021.acl-long.400/
# [338/572] Fetching abstract from https://aclanthology.org/2021.acl-long.401/
# [339/572] Fetching abstract from https://aclanthology.org/2021.acl-long.402/
# [340/572] Fetching abstract from https://aclanthology.org/2021.acl-long.403/
# [341/572] Fetching abstract from https://aclanthology.org/2021.acl-long.404/
# [342/572] Fetching abstract from https://aclanthology.org/2021.acl-long.405/
# [343/572] Fetching abstract from https://aclanthology.org/2021.acl-long.406/
# [344/572] Fetching abstract from https://aclanthology.org/2021.acl-long.407/
# [345/572] Fetching abstract from https://aclanthology.org/2021.acl-long.408/
# [346/572] Fetching abstract from https://aclanthology.org/2021.acl-long.409/
# [347/572] Fetching abstract from https://aclanthology.org/2021.acl-long.41/
# [348/572] Fetching abstract from https://aclanthology.org/2021.acl-long.410/
# [349/572] Fetching abstract from https://aclanthology.org/2021.acl-long.411/
# [350/572] Fetching abstract from https://aclanthology.org/2021.acl-long.412/
# [351/572] Fetching abstract from https://aclanthology.org/2021.acl-long.413/
# [352/572] Fetching abstract from https://aclanthology.org/2021.acl-long.414/
# [353/572] Fetching abstract from https://aclanthology.org/2021.acl-long.415/
# [354/572] Fetching abstract from https://aclanthology.org/2021.acl-long.416/
# [355/572] Fetching abstract from https://aclanthology.org/2021.acl-long.417/
# [356/572] Fetching abstract from https://aclanthology.org/2021.acl-long.418/
# [357/572] Fetching abstract from https://aclanthology.org/2021.acl-long.419/
# [358/572] Fetching abstract from https://aclanthology.org/2021.acl-long.42/
# [359/572] Fetching abstract from https://aclanthology.org/2021.acl-long.420/
# [360/572] Fetching abstract from https://aclanthology.org/2021.acl-long.421/
# [361/572] Fetching abstract from https://aclanthology.org/2021.acl-long.422/
# [362/572] Fetching abstract from https://aclanthology.org/2021.acl-long.423/
# [363/572] Fetching abstract from https://aclanthology.org/2021.acl-long.424/
# [364/572] Fetching abstract from https://aclanthology.org/2021.acl-long.425/
# [365/572] Fetching abstract from https://aclanthology.org/2021.acl-long.426/
# [366/572] Fetching abstract from https://aclanthology.org/2021.acl-long.427/
# [367/572] Fetching abstract from https://aclanthology.org/2021.acl-long.428/
# [368/572] Fetching abstract from https://aclanthology.org/2021.acl-long.429/
# [369/572] Fetching abstract from https://aclanthology.org/2021.acl-long.43/
# [370/572] Fetching abstract from https://aclanthology.org/2021.acl-long.430/
# [371/572] Fetching abstract from https://aclanthology.org/2021.acl-long.431/
# [372/572] Fetching abstract from https://aclanthology.org/2021.acl-long.432/
# [373/572] Fetching abstract from https://aclanthology.org/2021.acl-long.433/
# [374/572] Fetching abstract from https://aclanthology.org/2021.acl-long.434/
# [375/572] Fetching abstract from https://aclanthology.org/2021.acl-long.435/
# [376/572] Fetching abstract from https://aclanthology.org/2021.acl-long.436/
# [377/572] Fetching abstract from https://aclanthology.org/2021.acl-long.437/
# [378/572] Fetching abstract from https://aclanthology.org/2021.acl-long.438/
# [379/572] Fetching abstract from https://aclanthology.org/2021.acl-long.439/
# [380/572] Fetching abstract from https://aclanthology.org/2021.acl-long.44/
# [381/572] Fetching abstract from https://aclanthology.org/2021.acl-long.440/
# [382/572] Fetching abstract from https://aclanthology.org/2021.acl-long.441/
# [383/572] Fetching abstract from https://aclanthology.org/2021.acl-long.442/
# [384/572] Fetching abstract from https://aclanthology.org/2021.acl-long.443/
# [385/572] Fetching abstract from https://aclanthology.org/2021.acl-long.444/
# [386/572] Fetching abstract from https://aclanthology.org/2021.acl-long.445/
# [387/572] Fetching abstract from https://aclanthology.org/2021.acl-long.446/
# [388/572] Fetching abstract from https://aclanthology.org/2021.acl-long.447/
# [389/572] Fetching abstract from https://aclanthology.org/2021.acl-long.448/
# [390/572] Fetching abstract from https://aclanthology.org/2021.acl-long.449/
# [391/572] Fetching abstract from https://aclanthology.org/2021.acl-long.45/
# [392/572] Fetching abstract from https://aclanthology.org/2021.acl-long.450/
# [393/572] Fetching abstract from https://aclanthology.org/2021.acl-long.451/
# [394/572] Fetching abstract from https://aclanthology.org/2021.acl-long.452/
# [395/572] Fetching abstract from https://aclanthology.org/2021.acl-long.453/
# [396/572] Fetching abstract from https://aclanthology.org/2021.acl-long.454/
# [397/572] Fetching abstract from https://aclanthology.org/2021.acl-long.455/
# [398/572] Fetching abstract from https://aclanthology.org/2021.acl-long.456/
# [399/572] Fetching abstract from https://aclanthology.org/2021.acl-long.457/
# [400/572] Fetching abstract from https://aclanthology.org/2021.acl-long.458/
# [401/572] Fetching abstract from https://aclanthology.org/2021.acl-long.459/
# [402/572] Fetching abstract from https://aclanthology.org/2021.acl-long.46/
# [403/572] Fetching abstract from https://aclanthology.org/2021.acl-long.460/
# [404/572] Fetching abstract from https://aclanthology.org/2021.acl-long.461/
# [405/572] Fetching abstract from https://aclanthology.org/2021.acl-long.462/
# [406/572] Fetching abstract from https://aclanthology.org/2021.acl-long.463/
# [407/572] Fetching abstract from https://aclanthology.org/2021.acl-long.464/
# [408/572] Fetching abstract from https://aclanthology.org/2021.acl-long.465/
# [409/572] Fetching abstract from https://aclanthology.org/2021.acl-long.466/
# [410/572] Fetching abstract from https://aclanthology.org/2021.acl-long.467/
# [411/572] Fetching abstract from https://aclanthology.org/2021.acl-long.468/
# [412/572] Fetching abstract from https://aclanthology.org/2021.acl-long.469/
# [413/572] Fetching abstract from https://aclanthology.org/2021.acl-long.47/
# [414/572] Fetching abstract from https://aclanthology.org/2021.acl-long.470/
# [415/572] Fetching abstract from https://aclanthology.org/2021.acl-long.471/
# [416/572] Fetching abstract from https://aclanthology.org/2021.acl-long.472/
# [417/572] Fetching abstract from https://aclanthology.org/2021.acl-long.473/
# [418/572] Fetching abstract from https://aclanthology.org/2021.acl-long.474/
# [419/572] Fetching abstract from https://aclanthology.org/2021.acl-long.475/
# [420/572] Fetching abstract from https://aclanthology.org/2021.acl-long.476/
# [421/572] Fetching abstract from https://aclanthology.org/2021.acl-long.477/
# [422/572] Fetching abstract from https://aclanthology.org/2021.acl-long.478/
# [423/572] Fetching abstract from https://aclanthology.org/2021.acl-long.479/
# [424/572] Fetching abstract from https://aclanthology.org/2021.acl-long.48/
# [425/572] Fetching abstract from https://aclanthology.org/2021.acl-long.480/
# [426/572] Fetching abstract from https://aclanthology.org/2021.acl-long.481/
# [427/572] Fetching abstract from https://aclanthology.org/2021.acl-long.482/
# [428/572] Fetching abstract from https://aclanthology.org/2021.acl-long.483/
# [429/572] Fetching abstract from https://aclanthology.org/2021.acl-long.484/
# [430/572] Fetching abstract from https://aclanthology.org/2021.acl-long.485/
# [431/572] Fetching abstract from https://aclanthology.org/2021.acl-long.486/
# [432/572] Fetching abstract from https://aclanthology.org/2021.acl-long.487/
# [433/572] Fetching abstract from https://aclanthology.org/2021.acl-long.488/
# [434/572] Fetching abstract from https://aclanthology.org/2021.acl-long.489/
# [435/572] Fetching abstract from https://aclanthology.org/2021.acl-long.49/
# [436/572] Fetching abstract from https://aclanthology.org/2021.acl-long.490/
# [437/572] Fetching abstract from https://aclanthology.org/2021.acl-long.491/
# [438/572] Fetching abstract from https://aclanthology.org/2021.acl-long.492/
# [439/572] Fetching abstract from https://aclanthology.org/2021.acl-long.493/
# [440/572] Fetching abstract from https://aclanthology.org/2021.acl-long.494/
# [441/572] Fetching abstract from https://aclanthology.org/2021.acl-long.495/
# [442/572] Fetching abstract from https://aclanthology.org/2021.acl-long.496/
# [443/572] Fetching abstract from https://aclanthology.org/2021.acl-long.497/
# [444/572] Fetching abstract from https://aclanthology.org/2021.acl-long.498/
# [445/572] Fetching abstract from https://aclanthology.org/2021.acl-long.499/
# [446/572] Fetching abstract from https://aclanthology.org/2021.acl-long.5/
# [447/572] Fetching abstract from https://aclanthology.org/2021.acl-long.50/
# [448/572] Fetching abstract from https://aclanthology.org/2021.acl-long.500/
# [449/572] Fetching abstract from https://aclanthology.org/2021.acl-long.501/
# [450/572] Fetching abstract from https://aclanthology.org/2021.acl-long.502/
# [451/572] Fetching abstract from https://aclanthology.org/2021.acl-long.503/
# [452/572] Fetching abstract from https://aclanthology.org/2021.acl-long.504/
# [453/572] Fetching abstract from https://aclanthology.org/2021.acl-long.505/
# [454/572] Fetching abstract from https://aclanthology.org/2021.acl-long.506/
# [455/572] Fetching abstract from https://aclanthology.org/2021.acl-long.507/
# [456/572] Fetching abstract from https://aclanthology.org/2021.acl-long.508/
# [457/572] Fetching abstract from https://aclanthology.org/2021.acl-long.509/
# [458/572] Fetching abstract from https://aclanthology.org/2021.acl-long.51/
# [459/572] Fetching abstract from https://aclanthology.org/2021.acl-long.510/
# [460/572] Fetching abstract from https://aclanthology.org/2021.acl-long.511/
# [461/572] Fetching abstract from https://aclanthology.org/2021.acl-long.512/
# [462/572] Fetching abstract from https://aclanthology.org/2021.acl-long.513/
# [463/572] Fetching abstract from https://aclanthology.org/2021.acl-long.514/
# [464/572] Fetching abstract from https://aclanthology.org/2021.acl-long.515/
# [465/572] Fetching abstract from https://aclanthology.org/2021.acl-long.516/
# [466/572] Fetching abstract from https://aclanthology.org/2021.acl-long.517/
# [467/572] Fetching abstract from https://aclanthology.org/2021.acl-long.518/
# [468/572] Fetching abstract from https://aclanthology.org/2021.acl-long.519/
# [469/572] Fetching abstract from https://aclanthology.org/2021.acl-long.52/
# [470/572] Fetching abstract from https://aclanthology.org/2021.acl-long.520/
# [471/572] Fetching abstract from https://aclanthology.org/2021.acl-long.521/
# [472/572] Fetching abstract from https://aclanthology.org/2021.acl-long.522/
# [473/572] Fetching abstract from https://aclanthology.org/2021.acl-long.523/
# [474/572] Fetching abstract from https://aclanthology.org/2021.acl-long.524/
# [475/572] Fetching abstract from https://aclanthology.org/2021.acl-long.525/
# [476/572] Fetching abstract from https://aclanthology.org/2021.acl-long.526/
# [477/572] Fetching abstract from https://aclanthology.org/2021.acl-long.527/
# [478/572] Fetching abstract from https://aclanthology.org/2021.acl-long.528/
# [479/572] Fetching abstract from https://aclanthology.org/2021.acl-long.529/
# [480/572] Fetching abstract from https://aclanthology.org/2021.acl-long.53/
# [481/572] Fetching abstract from https://aclanthology.org/2021.acl-long.530/
# [482/572] Fetching abstract from https://aclanthology.org/2021.acl-long.531/
# [483/572] Fetching abstract from https://aclanthology.org/2021.acl-long.532/
# [484/572] Fetching abstract from https://aclanthology.org/2021.acl-long.533/
# [485/572] Fetching abstract from https://aclanthology.org/2021.acl-long.534/
# [486/572] Fetching abstract from https://aclanthology.org/2021.acl-long.535/
# [487/572] Fetching abstract from https://aclanthology.org/2021.acl-long.536/
# [488/572] Fetching abstract from https://aclanthology.org/2021.acl-long.537/
# [489/572] Fetching abstract from https://aclanthology.org/2021.acl-long.538/
# [490/572] Fetching abstract from https://aclanthology.org/2021.acl-long.539/
# [491/572] Fetching abstract from https://aclanthology.org/2021.acl-long.54/
# [492/572] Fetching abstract from https://aclanthology.org/2021.acl-long.540/
# [493/572] Fetching abstract from https://aclanthology.org/2021.acl-long.541/
# [494/572] Fetching abstract from https://aclanthology.org/2021.acl-long.542/
# [495/572] Fetching abstract from https://aclanthology.org/2021.acl-long.543/
# [496/572] Fetching abstract from https://aclanthology.org/2021.acl-long.544/
# [497/572] Fetching abstract from https://aclanthology.org/2021.acl-long.545/
# [498/572] Fetching abstract from https://aclanthology.org/2021.acl-long.546/
# [499/572] Fetching abstract from https://aclanthology.org/2021.acl-long.547/
# [500/572] Fetching abstract from https://aclanthology.org/2021.acl-long.548/
# [501/572] Fetching abstract from https://aclanthology.org/2021.acl-long.549/
# [502/572] Fetching abstract from https://aclanthology.org/2021.acl-long.55/
# [503/572] Fetching abstract from https://aclanthology.org/2021.acl-long.550/
# [504/572] Fetching abstract from https://aclanthology.org/2021.acl-long.551/
# [505/572] Fetching abstract from https://aclanthology.org/2021.acl-long.552/
# [506/572] Fetching abstract from https://aclanthology.org/2021.acl-long.553/
# [507/572] Fetching abstract from https://aclanthology.org/2021.acl-long.554/
# [508/572] Fetching abstract from https://aclanthology.org/2021.acl-long.555/
# [509/572] Fetching abstract from https://aclanthology.org/2021.acl-long.556/
# [510/572] Fetching abstract from https://aclanthology.org/2021.acl-long.557/
# [511/572] Fetching abstract from https://aclanthology.org/2021.acl-long.558/
# [512/572] Fetching abstract from https://aclanthology.org/2021.acl-long.559/
# [513/572] Fetching abstract from https://aclanthology.org/2021.acl-long.56/
# [514/572] Fetching abstract from https://aclanthology.org/2021.acl-long.560/
# [515/572] Fetching abstract from https://aclanthology.org/2021.acl-long.561/
# [516/572] Fetching abstract from https://aclanthology.org/2021.acl-long.562/
# [517/572] Fetching abstract from https://aclanthology.org/2021.acl-long.563/
# [518/572] Fetching abstract from https://aclanthology.org/2021.acl-long.564/
# [519/572] Fetching abstract from https://aclanthology.org/2021.acl-long.565/
# [520/572] Fetching abstract from https://aclanthology.org/2021.acl-long.566/
# [521/572] Fetching abstract from https://aclanthology.org/2021.acl-long.567/
# [522/572] Fetching abstract from https://aclanthology.org/2021.acl-long.568/
# [523/572] Fetching abstract from https://aclanthology.org/2021.acl-long.569/
# [524/572] Fetching abstract from https://aclanthology.org/2021.acl-long.57/
# [525/572] Fetching abstract from https://aclanthology.org/2021.acl-long.570/
# [526/572] Fetching abstract from https://aclanthology.org/2021.acl-long.571/
# [527/572] Fetching abstract from https://aclanthology.org/2021.acl-long.58/
# [528/572] Fetching abstract from https://aclanthology.org/2021.acl-long.59/
# [529/572] Fetching abstract from https://aclanthology.org/2021.acl-long.6/
# [530/572] Fetching abstract from https://aclanthology.org/2021.acl-long.60/
# [531/572] Fetching abstract from https://aclanthology.org/2021.acl-long.61/
# [532/572] Fetching abstract from https://aclanthology.org/2021.acl-long.62/
# [533/572] Fetching abstract from https://aclanthology.org/2021.acl-long.63/
# [534/572] Fetching abstract from https://aclanthology.org/2021.acl-long.64/
# [535/572] Fetching abstract from https://aclanthology.org/2021.acl-long.65/
# [536/572] Fetching abstract from https://aclanthology.org/2021.acl-long.66/
# [537/572] Fetching abstract from https://aclanthology.org/2021.acl-long.67/
# [538/572] Fetching abstract from https://aclanthology.org/2021.acl-long.68/
# [539/572] Fetching abstract from https://aclanthology.org/2021.acl-long.69/
# [540/572] Fetching abstract from https://aclanthology.org/2021.acl-long.7/
# [541/572] Fetching abstract from https://aclanthology.org/2021.acl-long.70/
# [542/572] Fetching abstract from https://aclanthology.org/2021.acl-long.71/
# [543/572] Fetching abstract from https://aclanthology.org/2021.acl-long.72/
# [544/572] Fetching abstract from https://aclanthology.org/2021.acl-long.73/
# [545/572] Fetching abstract from https://aclanthology.org/2021.acl-long.74/
# [546/572] Fetching abstract from https://aclanthology.org/2021.acl-long.75/
# [547/572] Fetching abstract from https://aclanthology.org/2021.acl-long.76/
# [548/572] Fetching abstract from https://aclanthology.org/2021.acl-long.77/
# [549/572] Fetching abstract from https://aclanthology.org/2021.acl-long.78/
# [550/572] Fetching abstract from https://aclanthology.org/2021.acl-long.79/
# [551/572] Fetching abstract from https://aclanthology.org/2021.acl-long.8/
# [552/572] Fetching abstract from https://aclanthology.org/2021.acl-long.80/
# [553/572] Fetching abstract from https://aclanthology.org/2021.acl-long.81/
# [554/572] Fetching abstract from https://aclanthology.org/2021.acl-long.82/
# [555/572] Fetching abstract from https://aclanthology.org/2021.acl-long.83/
# [556/572] Fetching abstract from https://aclanthology.org/2021.acl-long.84/
# [557/572] Fetching abstract from https://aclanthology.org/2021.acl-long.85/
# [558/572] Fetching abstract from https://aclanthology.org/2021.acl-long.86/
# [559/572] Fetching abstract from https://aclanthology.org/2021.acl-long.87/
# [560/572] Fetching abstract from https://aclanthology.org/2021.acl-long.88/
# [561/572] Fetching abstract from https://aclanthology.org/2021.acl-long.89/
# [562/572] Fetching abstract from https://aclanthology.org/2021.acl-long.9/
# [563/572] Fetching abstract from https://aclanthology.org/2021.acl-long.90/
# [564/572] Fetching abstract from https://aclanthology.org/2021.acl-long.91/
# [565/572] Fetching abstract from https://aclanthology.org/2021.acl-long.92/
# [566/572] Fetching abstract from https://aclanthology.org/2021.acl-long.93/
# [567/572] Fetching abstract from https://aclanthology.org/2021.acl-long.94/
# [568/572] Fetching abstract from https://aclanthology.org/2021.acl-long.95/
# [569/572] Fetching abstract from https://aclanthology.org/2021.acl-long.96/
# [570/572] Fetching abstract from https://aclanthology.org/2021.acl-long.97/
# [571/572] Fetching abstract from https://aclanthology.org/2021.acl-long.98/
# [572/572] Fetching abstract from https://aclanthology.org/2021.acl-long.99/

# %%
import requests
from bs4 import BeautifulSoup
import time

VOLUME_URL = "https://aclanthology.org/volumes/2021.acl-short/"

def get_paper_links():
    response = requests.get(VOLUME_URL)
    if response.status_code != 200:
        print(f"Failed to access {VOLUME_URL}")
        return []

    soup = BeautifulSoup(response.content, 'html.parser')

    paper_links = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        if href.startswith("/2021.acl-short.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)

    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    links = get_paper_links()
    print(f"Found {len(links)} ACL 2021 short papers.")
    with open("acl_2021_short_abstracts.txt", "w", encoding="utf-8") as f:
        for i, url in enumerate(links, 1):
            print(f"[{i}/{len(links)}] Fetching abstract from {url}")
            abstract = extract_abstract(url)
            if abstract:
                f.write(f"URL: {url}\n")
                f.write(f"Abstract: {abstract}\n")
                f.write("="*80 + "\n")
            else:
                print(f"No abstract found for: {url}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# 📄 Found 140 ACL 2021 short papers.
# [1/140] Fetching abstract from https://aclanthology.org/2021.acl-short.0/
# ⚠️ No abstract found for: https://aclanthology.org/2021.acl-short.0/
# [2/140] Fetching abstract from https://aclanthology.org/2021.acl-short.1/
# [3/140] Fetching abstract from https://aclanthology.org/2021.acl-short.10/
# [4/140] Fetching abstract from https://aclanthology.org/2021.acl-short.100/
# [5/140] Fetching abstract from https://aclanthology.org/2021.acl-short.101/
# [6/140] Fetching abstract from https://aclanthology.org/2021.acl-short.102/
# [7/140] Fetching abstract from https://aclanthology.org/2021.acl-short.103/
# [8/140] Fetching abstract from https://aclanthology.org/2021.acl-short.104/
# [9/140] Fetching abstract from https://aclanthology.org/2021.acl-short.105/
# [10/140] Fetching abstract from https://aclanthology.org/2021.acl-short.106/
# [11/140] Fetching abstract from https://aclanthology.org/2021.acl-short.107/
# [12/140] Fetching abstract from https://aclanthology.org/2021.acl-short.108/
# [13/140] Fetching abstract from https://aclanthology.org/2021.acl-short.109/
# [14/140] Fetching abstract from https://aclanthology.org/2021.acl-short.11/
# [15/140] Fetching abstract from https://aclanthology.org/2021.acl-short.110/
# [16/140] Fetching abstract from https://aclanthology.org/2021.acl-short.111/
# [17/140] Fetching abstract from https://aclanthology.org/2021.acl-short.112/
# [18/140] Fetching abstract from https://aclanthology.org/2021.acl-short.113/
# [19/140] Fetching abstract from https://aclanthology.org/2021.acl-short.114/
# [20/140] Fetching abstract from https://aclanthology.org/2021.acl-short.115/
# [21/140] Fetching abstract from https://aclanthology.org/2021.acl-short.116/
# [22/140] Fetching abstract from https://aclanthology.org/2021.acl-short.117/
# [23/140] Fetching abstract from https://aclanthology.org/2021.acl-short.118/
# [24/140] Fetching abstract from https://aclanthology.org/2021.acl-short.119/
# [25/140] Fetching abstract from https://aclanthology.org/2021.acl-short.12/
# [26/140] Fetching abstract from https://aclanthology.org/2021.acl-short.120/
# [27/140] Fetching abstract from https://aclanthology.org/2021.acl-short.121/
# [28/140] Fetching abstract from https://aclanthology.org/2021.acl-short.122/
# [29/140] Fetching abstract from https://aclanthology.org/2021.acl-short.123/
# [30/140] Fetching abstract from https://aclanthology.org/2021.acl-short.124/
# [31/140] Fetching abstract from https://aclanthology.org/2021.acl-short.125/
# [32/140] Fetching abstract from https://aclanthology.org/2021.acl-short.126/
# [33/140] Fetching abstract from https://aclanthology.org/2021.acl-short.127/
# [34/140] Fetching abstract from https://aclanthology.org/2021.acl-short.128/
# [35/140] Fetching abstract from https://aclanthology.org/2021.acl-short.129/
# [36/140] Fetching abstract from https://aclanthology.org/2021.acl-short.13/
# [37/140] Fetching abstract from https://aclanthology.org/2021.acl-short.130/
# [38/140] Fetching abstract from https://aclanthology.org/2021.acl-short.131/
# [39/140] Fetching abstract from https://aclanthology.org/2021.acl-short.132/
# [40/140] Fetching abstract from https://aclanthology.org/2021.acl-short.133/
# [41/140] Fetching abstract from https://aclanthology.org/2021.acl-short.134/
# [42/140] Fetching abstract from https://aclanthology.org/2021.acl-short.135/
# [43/140] Fetching abstract from https://aclanthology.org/2021.acl-short.136/
# [44/140] Fetching abstract from https://aclanthology.org/2021.acl-short.137/
# [45/140] Fetching abstract from https://aclanthology.org/2021.acl-short.138/
# [46/140] Fetching abstract from https://aclanthology.org/2021.acl-short.139/
# [47/140] Fetching abstract from https://aclanthology.org/2021.acl-short.14/
# [48/140] Fetching abstract from https://aclanthology.org/2021.acl-short.15/
# [49/140] Fetching abstract from https://aclanthology.org/2021.acl-short.16/
# [50/140] Fetching abstract from https://aclanthology.org/2021.acl-short.17/
# [51/140] Fetching abstract from https://aclanthology.org/2021.acl-short.18/
# [52/140] Fetching abstract from https://aclanthology.org/2021.acl-short.19/
# [53/140] Fetching abstract from https://aclanthology.org/2021.acl-short.2/
# [54/140] Fetching abstract from https://aclanthology.org/2021.acl-short.20/
# [55/140] Fetching abstract from https://aclanthology.org/2021.acl-short.21/
# [56/140] Fetching abstract from https://aclanthology.org/2021.acl-short.22/
# [57/140] Fetching abstract from https://aclanthology.org/2021.acl-short.23/
# [58/140] Fetching abstract from https://aclanthology.org/2021.acl-short.24/
# [59/140] Fetching abstract from https://aclanthology.org/2021.acl-short.25/
# [60/140] Fetching abstract from https://aclanthology.org/2021.acl-short.26/
# [61/140] Fetching abstract from https://aclanthology.org/2021.acl-short.27/
# [62/140] Fetching abstract from https://aclanthology.org/2021.acl-short.28/
# [63/140] Fetching abstract from https://aclanthology.org/2021.acl-short.29/
# [64/140] Fetching abstract from https://aclanthology.org/2021.acl-short.3/
# [65/140] Fetching abstract from https://aclanthology.org/2021.acl-short.30/
# [66/140] Fetching abstract from https://aclanthology.org/2021.acl-short.31/
# [67/140] Fetching abstract from https://aclanthology.org/2021.acl-short.32/
# [68/140] Fetching abstract from https://aclanthology.org/2021.acl-short.33/
# [69/140] Fetching abstract from https://aclanthology.org/2021.acl-short.34/
# [70/140] Fetching abstract from https://aclanthology.org/2021.acl-short.35/
# [71/140] Fetching abstract from https://aclanthology.org/2021.acl-short.36/
# [72/140] Fetching abstract from https://aclanthology.org/2021.acl-short.37/
# [73/140] Fetching abstract from https://aclanthology.org/2021.acl-short.38/
# [74/140] Fetching abstract from https://aclanthology.org/2021.acl-short.39/
# [75/140] Fetching abstract from https://aclanthology.org/2021.acl-short.4/
# [76/140] Fetching abstract from https://aclanthology.org/2021.acl-short.40/
# [77/140] Fetching abstract from https://aclanthology.org/2021.acl-short.41/
# [78/140] Fetching abstract from https://aclanthology.org/2021.acl-short.42/
# [79/140] Fetching abstract from https://aclanthology.org/2021.acl-short.43/
# [80/140] Fetching abstract from https://aclanthology.org/2021.acl-short.44/
# [81/140] Fetching abstract from https://aclanthology.org/2021.acl-short.45/
# [82/140] Fetching abstract from https://aclanthology.org/2021.acl-short.46/
# [83/140] Fetching abstract from https://aclanthology.org/2021.acl-short.47/
# [84/140] Fetching abstract from https://aclanthology.org/2021.acl-short.48/
# [85/140] Fetching abstract from https://aclanthology.org/2021.acl-short.49/
# [86/140] Fetching abstract from https://aclanthology.org/2021.acl-short.5/
# [87/140] Fetching abstract from https://aclanthology.org/2021.acl-short.50/
# [88/140] Fetching abstract from https://aclanthology.org/2021.acl-short.51/
# [89/140] Fetching abstract from https://aclanthology.org/2021.acl-short.52/
# [90/140] Fetching abstract from https://aclanthology.org/2021.acl-short.53/
# [91/140] Fetching abstract from https://aclanthology.org/2021.acl-short.54/
# [92/140] Fetching abstract from https://aclanthology.org/2021.acl-short.55/
# [93/140] Fetching abstract from https://aclanthology.org/2021.acl-short.56/
# [94/140] Fetching abstract from https://aclanthology.org/2021.acl-short.57/
# [95/140] Fetching abstract from https://aclanthology.org/2021.acl-short.58/
# [96/140] Fetching abstract from https://aclanthology.org/2021.acl-short.59/
# [97/140] Fetching abstract from https://aclanthology.org/2021.acl-short.6/
# [98/140] Fetching abstract from https://aclanthology.org/2021.acl-short.60/
# [99/140] Fetching abstract from https://aclanthology.org/2021.acl-short.61/
# [100/140] Fetching abstract from https://aclanthology.org/2021.acl-short.62/
# [101/140] Fetching abstract from https://aclanthology.org/2021.acl-short.63/
# [102/140] Fetching abstract from https://aclanthology.org/2021.acl-short.64/
# [103/140] Fetching abstract from https://aclanthology.org/2021.acl-short.65/
# [104/140] Fetching abstract from https://aclanthology.org/2021.acl-short.66/
# [105/140] Fetching abstract from https://aclanthology.org/2021.acl-short.67/
# [106/140] Fetching abstract from https://aclanthology.org/2021.acl-short.68/
# [107/140] Fetching abstract from https://aclanthology.org/2021.acl-short.69/
# [108/140] Fetching abstract from https://aclanthology.org/2021.acl-short.7/
# [109/140] Fetching abstract from https://aclanthology.org/2021.acl-short.70/
# [110/140] Fetching abstract from https://aclanthology.org/2021.acl-short.71/
# [111/140] Fetching abstract from https://aclanthology.org/2021.acl-short.72/
# [112/140] Fetching abstract from https://aclanthology.org/2021.acl-short.73/
# [113/140] Fetching abstract from https://aclanthology.org/2021.acl-short.74/
# [114/140] Fetching abstract from https://aclanthology.org/2021.acl-short.75/
# [115/140] Fetching abstract from https://aclanthology.org/2021.acl-short.76/
# [116/140] Fetching abstract from https://aclanthology.org/2021.acl-short.77/
# [117/140] Fetching abstract from https://aclanthology.org/2021.acl-short.78/
# [118/140] Fetching abstract from https://aclanthology.org/2021.acl-short.79/
# [119/140] Fetching abstract from https://aclanthology.org/2021.acl-short.8/
# [120/140] Fetching abstract from https://aclanthology.org/2021.acl-short.80/
# [121/140] Fetching abstract from https://aclanthology.org/2021.acl-short.81/
# [122/140] Fetching abstract from https://aclanthology.org/2021.acl-short.82/
# [123/140] Fetching abstract from https://aclanthology.org/2021.acl-short.83/
# [124/140] Fetching abstract from https://aclanthology.org/2021.acl-short.84/
# [125/140] Fetching abstract from https://aclanthology.org/2021.acl-short.85/
# [126/140] Fetching abstract from https://aclanthology.org/2021.acl-short.86/
# [127/140] Fetching abstract from https://aclanthology.org/2021.acl-short.87/
# [128/140] Fetching abstract from https://aclanthology.org/2021.acl-short.88/
# [129/140] Fetching abstract from https://aclanthology.org/2021.acl-short.89/
# [130/140] Fetching abstract from https://aclanthology.org/2021.acl-short.9/
# [131/140] Fetching abstract from https://aclanthology.org/2021.acl-short.90/
# [132/140] Fetching abstract from https://aclanthology.org/2021.acl-short.91/
# [133/140] Fetching abstract from https://aclanthology.org/2021.acl-short.92/
# [134/140] Fetching abstract from https://aclanthology.org/2021.acl-short.93/
# [135/140] Fetching abstract from https://aclanthology.org/2021.acl-short.94/
# [136/140] Fetching abstract from https://aclanthology.org/2021.acl-short.95/
# [137/140] Fetching abstract from https://aclanthology.org/2021.acl-short.96/
# [138/140] Fetching abstract from https://aclanthology.org/2021.acl-short.97/
# [139/140] Fetching abstract from https://aclanthology.org/2021.acl-short.98/
# [140/140] Fetching abstract from https://aclanthology.org/2021.acl-short.99/

# %%
import requests
from bs4 import BeautifulSoup
import time

VOLUME_URL = "https://aclanthology.org/volumes/2022.acl-long/"

def get_paper_links():
    response = requests.get(VOLUME_URL)
    if response.status_code != 200:
        print(f"Failed to access {VOLUME_URL}")
        return []

    soup = BeautifulSoup(response.content, 'html.parser')

    paper_links = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        if href.startswith("/2022.acl-long.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)

    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    links = get_paper_links()
    print(f"Found {len(links)} ACL 2022 long papers.")
    with open("acl_2022_long_abstracts.txt", "w", encoding="utf-8") as f:
        for i, url in enumerate(links, 1):
            print(f"[{i}/{len(links)}] Fetching abstract from {url}")
            abstract = extract_abstract(url)
            if abstract:
                f.write(f"URL: {url}\n")
                f.write(f"Abstract: {abstract}\n")
                f.write("="*80 + "\n")
            else:
                print(f"No abstract found for: {url}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# 📄 Found 604 ACL 2022 long papers.
# [1/604] Fetching abstract from https://aclanthology.org/2022.acl-long.0/
# ⚠️ No abstract found for: https://aclanthology.org/2022.acl-long.0/
# [2/604] Fetching abstract from https://aclanthology.org/2022.acl-long.1/
# [3/604] Fetching abstract from https://aclanthology.org/2022.acl-long.10/
# [4/604] Fetching abstract from https://aclanthology.org/2022.acl-long.100/
# [5/604] Fetching abstract from https://aclanthology.org/2022.acl-long.101/
# [6/604] Fetching abstract from https://aclanthology.org/2022.acl-long.102/
# [7/604] Fetching abstract from https://aclanthology.org/2022.acl-long.103/
# [8/604] Fetching abstract from https://aclanthology.org/2022.acl-long.104/
# [9/604] Fetching abstract from https://aclanthology.org/2022.acl-long.105/
# [10/604] Fetching abstract from https://aclanthology.org/2022.acl-long.106/
# [11/604] Fetching abstract from https://aclanthology.org/2022.acl-long.107/
# [12/604] Fetching abstract from https://aclanthology.org/2022.acl-long.108/
# [13/604] Fetching abstract from https://aclanthology.org/2022.acl-long.109/
# [14/604] Fetching abstract from https://aclanthology.org/2022.acl-long.11/
# [15/604] Fetching abstract from https://aclanthology.org/2022.acl-long.110/
# [16/604] Fetching abstract from https://aclanthology.org/2022.acl-long.111/
# [17/604] Fetching abstract from https://aclanthology.org/2022.acl-long.112/
# [18/604] Fetching abstract from https://aclanthology.org/2022.acl-long.113/
# [19/604] Fetching abstract from https://aclanthology.org/2022.acl-long.114/
# [20/604] Fetching abstract from https://aclanthology.org/2022.acl-long.115/
# [21/604] Fetching abstract from https://aclanthology.org/2022.acl-long.116/
# [22/604] Fetching abstract from https://aclanthology.org/2022.acl-long.117/
# [23/604] Fetching abstract from https://aclanthology.org/2022.acl-long.118/
# [24/604] Fetching abstract from https://aclanthology.org/2022.acl-long.119/
# [25/604] Fetching abstract from https://aclanthology.org/2022.acl-long.12/
# [26/604] Fetching abstract from https://aclanthology.org/2022.acl-long.120/
# [27/604] Fetching abstract from https://aclanthology.org/2022.acl-long.121/
# [28/604] Fetching abstract from https://aclanthology.org/2022.acl-long.122/
# [29/604] Fetching abstract from https://aclanthology.org/2022.acl-long.123/
# [30/604] Fetching abstract from https://aclanthology.org/2022.acl-long.124/
# [31/604] Fetching abstract from https://aclanthology.org/2022.acl-long.125/
# [32/604] Fetching abstract from https://aclanthology.org/2022.acl-long.126/
# [33/604] Fetching abstract from https://aclanthology.org/2022.acl-long.127/
# [34/604] Fetching abstract from https://aclanthology.org/2022.acl-long.128/
# [35/604] Fetching abstract from https://aclanthology.org/2022.acl-long.129/
# [36/604] Fetching abstract from https://aclanthology.org/2022.acl-long.13/
# [37/604] Fetching abstract from https://aclanthology.org/2022.acl-long.130/
# [38/604] Fetching abstract from https://aclanthology.org/2022.acl-long.131/
# [39/604] Fetching abstract from https://aclanthology.org/2022.acl-long.132/
# [40/604] Fetching abstract from https://aclanthology.org/2022.acl-long.133/
# [41/604] Fetching abstract from https://aclanthology.org/2022.acl-long.134/
# [42/604] Fetching abstract from https://aclanthology.org/2022.acl-long.135/
# [43/604] Fetching abstract from https://aclanthology.org/2022.acl-long.136/
# [44/604] Fetching abstract from https://aclanthology.org/2022.acl-long.137/
# [45/604] Fetching abstract from https://aclanthology.org/2022.acl-long.138/
# [46/604] Fetching abstract from https://aclanthology.org/2022.acl-long.139/
# [47/604] Fetching abstract from https://aclanthology.org/2022.acl-long.14/
# [48/604] Fetching abstract from https://aclanthology.org/2022.acl-long.140/
# [49/604] Fetching abstract from https://aclanthology.org/2022.acl-long.141/
# [50/604] Fetching abstract from https://aclanthology.org/2022.acl-long.142/
# [51/604] Fetching abstract from https://aclanthology.org/2022.acl-long.143/
# [52/604] Fetching abstract from https://aclanthology.org/2022.acl-long.144/
# [53/604] Fetching abstract from https://aclanthology.org/2022.acl-long.145/
# [54/604] Fetching abstract from https://aclanthology.org/2022.acl-long.146/
# [55/604] Fetching abstract from https://aclanthology.org/2022.acl-long.147/
# [56/604] Fetching abstract from https://aclanthology.org/2022.acl-long.148/
# [57/604] Fetching abstract from https://aclanthology.org/2022.acl-long.149/
# [58/604] Fetching abstract from https://aclanthology.org/2022.acl-long.15/
# [59/604] Fetching abstract from https://aclanthology.org/2022.acl-long.150/
# [60/604] Fetching abstract from https://aclanthology.org/2022.acl-long.151/
# [61/604] Fetching abstract from https://aclanthology.org/2022.acl-long.152/
# [62/604] Fetching abstract from https://aclanthology.org/2022.acl-long.153/
# [63/604] Fetching abstract from https://aclanthology.org/2022.acl-long.154/
# [64/604] Fetching abstract from https://aclanthology.org/2022.acl-long.155/
# [65/604] Fetching abstract from https://aclanthology.org/2022.acl-long.156/
# [66/604] Fetching abstract from https://aclanthology.org/2022.acl-long.157/
# [67/604] Fetching abstract from https://aclanthology.org/2022.acl-long.158/
# [68/604] Fetching abstract from https://aclanthology.org/2022.acl-long.159/
# [69/604] Fetching abstract from https://aclanthology.org/2022.acl-long.16/
# [70/604] Fetching abstract from https://aclanthology.org/2022.acl-long.160/
# [71/604] Fetching abstract from https://aclanthology.org/2022.acl-long.161/
# [72/604] Fetching abstract from https://aclanthology.org/2022.acl-long.162/
# [73/604] Fetching abstract from https://aclanthology.org/2022.acl-long.163/
# [74/604] Fetching abstract from https://aclanthology.org/2022.acl-long.164/
# [75/604] Fetching abstract from https://aclanthology.org/2022.acl-long.165/
# [76/604] Fetching abstract from https://aclanthology.org/2022.acl-long.166/
# [77/604] Fetching abstract from https://aclanthology.org/2022.acl-long.167/
# [78/604] Fetching abstract from https://aclanthology.org/2022.acl-long.168/
# [79/604] Fetching abstract from https://aclanthology.org/2022.acl-long.169/
# [80/604] Fetching abstract from https://aclanthology.org/2022.acl-long.17/
# [81/604] Fetching abstract from https://aclanthology.org/2022.acl-long.170/
# [82/604] Fetching abstract from https://aclanthology.org/2022.acl-long.171/
# [83/604] Fetching abstract from https://aclanthology.org/2022.acl-long.172/
# [84/604] Fetching abstract from https://aclanthology.org/2022.acl-long.173/
# [85/604] Fetching abstract from https://aclanthology.org/2022.acl-long.174/
# [86/604] Fetching abstract from https://aclanthology.org/2022.acl-long.175/
# [87/604] Fetching abstract from https://aclanthology.org/2022.acl-long.176/
# [88/604] Fetching abstract from https://aclanthology.org/2022.acl-long.177/
# [89/604] Fetching abstract from https://aclanthology.org/2022.acl-long.178/
# [90/604] Fetching abstract from https://aclanthology.org/2022.acl-long.179/
# [91/604] Fetching abstract from https://aclanthology.org/2022.acl-long.18/
# [92/604] Fetching abstract from https://aclanthology.org/2022.acl-long.180/
# [93/604] Fetching abstract from https://aclanthology.org/2022.acl-long.181/
# [94/604] Fetching abstract from https://aclanthology.org/2022.acl-long.182/
# [95/604] Fetching abstract from https://aclanthology.org/2022.acl-long.183/
# [96/604] Fetching abstract from https://aclanthology.org/2022.acl-long.184/
# [97/604] Fetching abstract from https://aclanthology.org/2022.acl-long.185/
# [98/604] Fetching abstract from https://aclanthology.org/2022.acl-long.186/
# [99/604] Fetching abstract from https://aclanthology.org/2022.acl-long.187/
# [100/604] Fetching abstract from https://aclanthology.org/2022.acl-long.188/
# [101/604] Fetching abstract from https://aclanthology.org/2022.acl-long.189/
# [102/604] Fetching abstract from https://aclanthology.org/2022.acl-long.19/
# [103/604] Fetching abstract from https://aclanthology.org/2022.acl-long.190/
# [104/604] Fetching abstract from https://aclanthology.org/2022.acl-long.191/
# [105/604] Fetching abstract from https://aclanthology.org/2022.acl-long.192/
# [106/604] Fetching abstract from https://aclanthology.org/2022.acl-long.193/
# [107/604] Fetching abstract from https://aclanthology.org/2022.acl-long.194/
# [108/604] Fetching abstract from https://aclanthology.org/2022.acl-long.195/
# [109/604] Fetching abstract from https://aclanthology.org/2022.acl-long.196/
# [110/604] Fetching abstract from https://aclanthology.org/2022.acl-long.197/
# [111/604] Fetching abstract from https://aclanthology.org/2022.acl-long.198/
# [112/604] Fetching abstract from https://aclanthology.org/2022.acl-long.199/
# [113/604] Fetching abstract from https://aclanthology.org/2022.acl-long.2/
# [114/604] Fetching abstract from https://aclanthology.org/2022.acl-long.20/
# [115/604] Fetching abstract from https://aclanthology.org/2022.acl-long.200/
# [116/604] Fetching abstract from https://aclanthology.org/2022.acl-long.201/
# [117/604] Fetching abstract from https://aclanthology.org/2022.acl-long.202/
# [118/604] Fetching abstract from https://aclanthology.org/2022.acl-long.203/
# [119/604] Fetching abstract from https://aclanthology.org/2022.acl-long.204/
# [120/604] Fetching abstract from https://aclanthology.org/2022.acl-long.205/
# [121/604] Fetching abstract from https://aclanthology.org/2022.acl-long.206/
# [122/604] Fetching abstract from https://aclanthology.org/2022.acl-long.207/
# [123/604] Fetching abstract from https://aclanthology.org/2022.acl-long.208/
# [124/604] Fetching abstract from https://aclanthology.org/2022.acl-long.209/
# [125/604] Fetching abstract from https://aclanthology.org/2022.acl-long.21/
# [126/604] Fetching abstract from https://aclanthology.org/2022.acl-long.210/
# [127/604] Fetching abstract from https://aclanthology.org/2022.acl-long.211/
# [128/604] Fetching abstract from https://aclanthology.org/2022.acl-long.212/
# [129/604] Fetching abstract from https://aclanthology.org/2022.acl-long.213/
# [130/604] Fetching abstract from https://aclanthology.org/2022.acl-long.214/
# [131/604] Fetching abstract from https://aclanthology.org/2022.acl-long.215/
# [132/604] Fetching abstract from https://aclanthology.org/2022.acl-long.216/
# [133/604] Fetching abstract from https://aclanthology.org/2022.acl-long.217/
# [134/604] Fetching abstract from https://aclanthology.org/2022.acl-long.218/
# [135/604] Fetching abstract from https://aclanthology.org/2022.acl-long.219/
# [136/604] Fetching abstract from https://aclanthology.org/2022.acl-long.22/
# [137/604] Fetching abstract from https://aclanthology.org/2022.acl-long.220/
# [138/604] Fetching abstract from https://aclanthology.org/2022.acl-long.221/
# [139/604] Fetching abstract from https://aclanthology.org/2022.acl-long.222/
# [140/604] Fetching abstract from https://aclanthology.org/2022.acl-long.223/
# [141/604] Fetching abstract from https://aclanthology.org/2022.acl-long.224/
# [142/604] Fetching abstract from https://aclanthology.org/2022.acl-long.225/
# [143/604] Fetching abstract from https://aclanthology.org/2022.acl-long.226/
# [144/604] Fetching abstract from https://aclanthology.org/2022.acl-long.227/
# [145/604] Fetching abstract from https://aclanthology.org/2022.acl-long.228/
# [146/604] Fetching abstract from https://aclanthology.org/2022.acl-long.229/
# [147/604] Fetching abstract from https://aclanthology.org/2022.acl-long.23/
# [148/604] Fetching abstract from https://aclanthology.org/2022.acl-long.230/
# [149/604] Fetching abstract from https://aclanthology.org/2022.acl-long.231/
# [150/604] Fetching abstract from https://aclanthology.org/2022.acl-long.232/
# [151/604] Fetching abstract from https://aclanthology.org/2022.acl-long.233/
# [152/604] Fetching abstract from https://aclanthology.org/2022.acl-long.234/
# [153/604] Fetching abstract from https://aclanthology.org/2022.acl-long.235/
# [154/604] Fetching abstract from https://aclanthology.org/2022.acl-long.236/
# [155/604] Fetching abstract from https://aclanthology.org/2022.acl-long.237/
# [156/604] Fetching abstract from https://aclanthology.org/2022.acl-long.238/
# [157/604] Fetching abstract from https://aclanthology.org/2022.acl-long.239/
# [158/604] Fetching abstract from https://aclanthology.org/2022.acl-long.24/
# [159/604] Fetching abstract from https://aclanthology.org/2022.acl-long.240/
# [160/604] Fetching abstract from https://aclanthology.org/2022.acl-long.241/
# [161/604] Fetching abstract from https://aclanthology.org/2022.acl-long.242/
# [162/604] Fetching abstract from https://aclanthology.org/2022.acl-long.243/
# [163/604] Fetching abstract from https://aclanthology.org/2022.acl-long.244/
# [164/604] Fetching abstract from https://aclanthology.org/2022.acl-long.245/
# [165/604] Fetching abstract from https://aclanthology.org/2022.acl-long.246/
# [166/604] Fetching abstract from https://aclanthology.org/2022.acl-long.247/
# [167/604] Fetching abstract from https://aclanthology.org/2022.acl-long.248/
# [168/604] Fetching abstract from https://aclanthology.org/2022.acl-long.249/
# [169/604] Fetching abstract from https://aclanthology.org/2022.acl-long.25/
# [170/604] Fetching abstract from https://aclanthology.org/2022.acl-long.250/
# [171/604] Fetching abstract from https://aclanthology.org/2022.acl-long.251/
# [172/604] Fetching abstract from https://aclanthology.org/2022.acl-long.252/
# [173/604] Fetching abstract from https://aclanthology.org/2022.acl-long.253/
# [174/604] Fetching abstract from https://aclanthology.org/2022.acl-long.254/
# [175/604] Fetching abstract from https://aclanthology.org/2022.acl-long.255/
# [176/604] Fetching abstract from https://aclanthology.org/2022.acl-long.256/
# [177/604] Fetching abstract from https://aclanthology.org/2022.acl-long.257/
# [178/604] Fetching abstract from https://aclanthology.org/2022.acl-long.258/
# [179/604] Fetching abstract from https://aclanthology.org/2022.acl-long.259/
# [180/604] Fetching abstract from https://aclanthology.org/2022.acl-long.26/
# [181/604] Fetching abstract from https://aclanthology.org/2022.acl-long.260/
# [182/604] Fetching abstract from https://aclanthology.org/2022.acl-long.261/
# [183/604] Fetching abstract from https://aclanthology.org/2022.acl-long.262/
# [184/604] Fetching abstract from https://aclanthology.org/2022.acl-long.263/
# [185/604] Fetching abstract from https://aclanthology.org/2022.acl-long.264/
# [186/604] Fetching abstract from https://aclanthology.org/2022.acl-long.265/
# [187/604] Fetching abstract from https://aclanthology.org/2022.acl-long.266/
# [188/604] Fetching abstract from https://aclanthology.org/2022.acl-long.267/
# [189/604] Fetching abstract from https://aclanthology.org/2022.acl-long.268/
# [190/604] Fetching abstract from https://aclanthology.org/2022.acl-long.269/
# [191/604] Fetching abstract from https://aclanthology.org/2022.acl-long.27/
# [192/604] Fetching abstract from https://aclanthology.org/2022.acl-long.270/
# [193/604] Fetching abstract from https://aclanthology.org/2022.acl-long.271/
# [194/604] Fetching abstract from https://aclanthology.org/2022.acl-long.272/
# [195/604] Fetching abstract from https://aclanthology.org/2022.acl-long.273/
# [196/604] Fetching abstract from https://aclanthology.org/2022.acl-long.274/
# [197/604] Fetching abstract from https://aclanthology.org/2022.acl-long.275/
# [198/604] Fetching abstract from https://aclanthology.org/2022.acl-long.276/
# [199/604] Fetching abstract from https://aclanthology.org/2022.acl-long.277/
# [200/604] Fetching abstract from https://aclanthology.org/2022.acl-long.278/
# [201/604] Fetching abstract from https://aclanthology.org/2022.acl-long.279/
# [202/604] Fetching abstract from https://aclanthology.org/2022.acl-long.28/
# [203/604] Fetching abstract from https://aclanthology.org/2022.acl-long.280/
# [204/604] Fetching abstract from https://aclanthology.org/2022.acl-long.281/
# [205/604] Fetching abstract from https://aclanthology.org/2022.acl-long.282/
# [206/604] Fetching abstract from https://aclanthology.org/2022.acl-long.283/
# [207/604] Fetching abstract from https://aclanthology.org/2022.acl-long.284/
# [208/604] Fetching abstract from https://aclanthology.org/2022.acl-long.285/
# [209/604] Fetching abstract from https://aclanthology.org/2022.acl-long.286/
# [210/604] Fetching abstract from https://aclanthology.org/2022.acl-long.287/
# [211/604] Fetching abstract from https://aclanthology.org/2022.acl-long.288/
# [212/604] Fetching abstract from https://aclanthology.org/2022.acl-long.289/
# [213/604] Fetching abstract from https://aclanthology.org/2022.acl-long.29/
# [214/604] Fetching abstract from https://aclanthology.org/2022.acl-long.290/
# [215/604] Fetching abstract from https://aclanthology.org/2022.acl-long.291/
# [216/604] Fetching abstract from https://aclanthology.org/2022.acl-long.292/
# [217/604] Fetching abstract from https://aclanthology.org/2022.acl-long.293/
# [218/604] Fetching abstract from https://aclanthology.org/2022.acl-long.294/
# [219/604] Fetching abstract from https://aclanthology.org/2022.acl-long.295/
# [220/604] Fetching abstract from https://aclanthology.org/2022.acl-long.296/
# [221/604] Fetching abstract from https://aclanthology.org/2022.acl-long.297/
# [222/604] Fetching abstract from https://aclanthology.org/2022.acl-long.298/
# [223/604] Fetching abstract from https://aclanthology.org/2022.acl-long.299/
# [224/604] Fetching abstract from https://aclanthology.org/2022.acl-long.3/
# [225/604] Fetching abstract from https://aclanthology.org/2022.acl-long.30/
# [226/604] Fetching abstract from https://aclanthology.org/2022.acl-long.300/
# [227/604] Fetching abstract from https://aclanthology.org/2022.acl-long.301/
# [228/604] Fetching abstract from https://aclanthology.org/2022.acl-long.302/
# [229/604] Fetching abstract from https://aclanthology.org/2022.acl-long.303/
# [230/604] Fetching abstract from https://aclanthology.org/2022.acl-long.304/
# [231/604] Fetching abstract from https://aclanthology.org/2022.acl-long.305/
# [232/604] Fetching abstract from https://aclanthology.org/2022.acl-long.306/
# [233/604] Fetching abstract from https://aclanthology.org/2022.acl-long.307/
# [234/604] Fetching abstract from https://aclanthology.org/2022.acl-long.308/
# [235/604] Fetching abstract from https://aclanthology.org/2022.acl-long.309/
# [236/604] Fetching abstract from https://aclanthology.org/2022.acl-long.31/
# [237/604] Fetching abstract from https://aclanthology.org/2022.acl-long.310/
# [238/604] Fetching abstract from https://aclanthology.org/2022.acl-long.311/
# [239/604] Fetching abstract from https://aclanthology.org/2022.acl-long.312/
# [240/604] Fetching abstract from https://aclanthology.org/2022.acl-long.313/
# [241/604] Fetching abstract from https://aclanthology.org/2022.acl-long.314/
# [242/604] Fetching abstract from https://aclanthology.org/2022.acl-long.315/
# [243/604] Fetching abstract from https://aclanthology.org/2022.acl-long.316/
# [244/604] Fetching abstract from https://aclanthology.org/2022.acl-long.317/
# [245/604] Fetching abstract from https://aclanthology.org/2022.acl-long.318/
# [246/604] Fetching abstract from https://aclanthology.org/2022.acl-long.319/
# [247/604] Fetching abstract from https://aclanthology.org/2022.acl-long.32/
# [248/604] Fetching abstract from https://aclanthology.org/2022.acl-long.320/
# [249/604] Fetching abstract from https://aclanthology.org/2022.acl-long.321/
# [250/604] Fetching abstract from https://aclanthology.org/2022.acl-long.322/
# [251/604] Fetching abstract from https://aclanthology.org/2022.acl-long.323/
# [252/604] Fetching abstract from https://aclanthology.org/2022.acl-long.324/
# [253/604] Fetching abstract from https://aclanthology.org/2022.acl-long.325/
# [254/604] Fetching abstract from https://aclanthology.org/2022.acl-long.326/
# [255/604] Fetching abstract from https://aclanthology.org/2022.acl-long.327/
# [256/604] Fetching abstract from https://aclanthology.org/2022.acl-long.328/
# [257/604] Fetching abstract from https://aclanthology.org/2022.acl-long.329/
# [258/604] Fetching abstract from https://aclanthology.org/2022.acl-long.33/
# [259/604] Fetching abstract from https://aclanthology.org/2022.acl-long.330/
# [260/604] Fetching abstract from https://aclanthology.org/2022.acl-long.331/
# [261/604] Fetching abstract from https://aclanthology.org/2022.acl-long.332/
# [262/604] Fetching abstract from https://aclanthology.org/2022.acl-long.333/
# [263/604] Fetching abstract from https://aclanthology.org/2022.acl-long.334/
# [264/604] Fetching abstract from https://aclanthology.org/2022.acl-long.335/
# [265/604] Fetching abstract from https://aclanthology.org/2022.acl-long.336/
# [266/604] Fetching abstract from https://aclanthology.org/2022.acl-long.337/
# [267/604] Fetching abstract from https://aclanthology.org/2022.acl-long.338/
# [268/604] Fetching abstract from https://aclanthology.org/2022.acl-long.339/
# [269/604] Fetching abstract from https://aclanthology.org/2022.acl-long.34/
# [270/604] Fetching abstract from https://aclanthology.org/2022.acl-long.340/
# [271/604] Fetching abstract from https://aclanthology.org/2022.acl-long.341/
# [272/604] Fetching abstract from https://aclanthology.org/2022.acl-long.342/
# [273/604] Fetching abstract from https://aclanthology.org/2022.acl-long.343/
# [274/604] Fetching abstract from https://aclanthology.org/2022.acl-long.344/
# [275/604] Fetching abstract from https://aclanthology.org/2022.acl-long.345/
# [276/604] Fetching abstract from https://aclanthology.org/2022.acl-long.346/
# [277/604] Fetching abstract from https://aclanthology.org/2022.acl-long.347/
# [278/604] Fetching abstract from https://aclanthology.org/2022.acl-long.348/
# [279/604] Fetching abstract from https://aclanthology.org/2022.acl-long.349/
# [280/604] Fetching abstract from https://aclanthology.org/2022.acl-long.35/
# [281/604] Fetching abstract from https://aclanthology.org/2022.acl-long.350/
# [282/604] Fetching abstract from https://aclanthology.org/2022.acl-long.351/
# [283/604] Fetching abstract from https://aclanthology.org/2022.acl-long.352/
# [284/604] Fetching abstract from https://aclanthology.org/2022.acl-long.353/
# [285/604] Fetching abstract from https://aclanthology.org/2022.acl-long.354/
# [286/604] Fetching abstract from https://aclanthology.org/2022.acl-long.355/
# [287/604] Fetching abstract from https://aclanthology.org/2022.acl-long.356/
# [288/604] Fetching abstract from https://aclanthology.org/2022.acl-long.357/
# [289/604] Fetching abstract from https://aclanthology.org/2022.acl-long.358/
# [290/604] Fetching abstract from https://aclanthology.org/2022.acl-long.359/
# [291/604] Fetching abstract from https://aclanthology.org/2022.acl-long.36/
# [292/604] Fetching abstract from https://aclanthology.org/2022.acl-long.360/
# [293/604] Fetching abstract from https://aclanthology.org/2022.acl-long.361/
# [294/604] Fetching abstract from https://aclanthology.org/2022.acl-long.362/
# [295/604] Fetching abstract from https://aclanthology.org/2022.acl-long.363/
# [296/604] Fetching abstract from https://aclanthology.org/2022.acl-long.364/
# [297/604] Fetching abstract from https://aclanthology.org/2022.acl-long.365/
# [298/604] Fetching abstract from https://aclanthology.org/2022.acl-long.366/
# [299/604] Fetching abstract from https://aclanthology.org/2022.acl-long.367/
# [300/604] Fetching abstract from https://aclanthology.org/2022.acl-long.368/
# [301/604] Fetching abstract from https://aclanthology.org/2022.acl-long.369/
# [302/604] Fetching abstract from https://aclanthology.org/2022.acl-long.37/
# [303/604] Fetching abstract from https://aclanthology.org/2022.acl-long.370/
# [304/604] Fetching abstract from https://aclanthology.org/2022.acl-long.371/
# [305/604] Fetching abstract from https://aclanthology.org/2022.acl-long.372/
# [306/604] Fetching abstract from https://aclanthology.org/2022.acl-long.373/
# [307/604] Fetching abstract from https://aclanthology.org/2022.acl-long.374/
# [308/604] Fetching abstract from https://aclanthology.org/2022.acl-long.375/
# [309/604] Fetching abstract from https://aclanthology.org/2022.acl-long.376/
# [310/604] Fetching abstract from https://aclanthology.org/2022.acl-long.377/
# [311/604] Fetching abstract from https://aclanthology.org/2022.acl-long.378/
# [312/604] Fetching abstract from https://aclanthology.org/2022.acl-long.379/
# [313/604] Fetching abstract from https://aclanthology.org/2022.acl-long.38/
# [314/604] Fetching abstract from https://aclanthology.org/2022.acl-long.380/
# [315/604] Fetching abstract from https://aclanthology.org/2022.acl-long.381/
# [316/604] Fetching abstract from https://aclanthology.org/2022.acl-long.382/
# [317/604] Fetching abstract from https://aclanthology.org/2022.acl-long.383/
# [318/604] Fetching abstract from https://aclanthology.org/2022.acl-long.384/
# [319/604] Fetching abstract from https://aclanthology.org/2022.acl-long.385/
# [320/604] Fetching abstract from https://aclanthology.org/2022.acl-long.386/
# [321/604] Fetching abstract from https://aclanthology.org/2022.acl-long.387/
# [322/604] Fetching abstract from https://aclanthology.org/2022.acl-long.388/
# [323/604] Fetching abstract from https://aclanthology.org/2022.acl-long.389/
# [324/604] Fetching abstract from https://aclanthology.org/2022.acl-long.39/
# [325/604] Fetching abstract from https://aclanthology.org/2022.acl-long.390/
# [326/604] Fetching abstract from https://aclanthology.org/2022.acl-long.391/
# [327/604] Fetching abstract from https://aclanthology.org/2022.acl-long.392/
# [328/604] Fetching abstract from https://aclanthology.org/2022.acl-long.393/
# [329/604] Fetching abstract from https://aclanthology.org/2022.acl-long.394/
# [330/604] Fetching abstract from https://aclanthology.org/2022.acl-long.395/
# [331/604] Fetching abstract from https://aclanthology.org/2022.acl-long.396/
# [332/604] Fetching abstract from https://aclanthology.org/2022.acl-long.397/
# [333/604] Fetching abstract from https://aclanthology.org/2022.acl-long.398/
# [334/604] Fetching abstract from https://aclanthology.org/2022.acl-long.399/
# [335/604] Fetching abstract from https://aclanthology.org/2022.acl-long.4/
# [336/604] Fetching abstract from https://aclanthology.org/2022.acl-long.40/
# [337/604] Fetching abstract from https://aclanthology.org/2022.acl-long.400/
# [338/604] Fetching abstract from https://aclanthology.org/2022.acl-long.401/
# [339/604] Fetching abstract from https://aclanthology.org/2022.acl-long.402/
# [340/604] Fetching abstract from https://aclanthology.org/2022.acl-long.403/
# [341/604] Fetching abstract from https://aclanthology.org/2022.acl-long.404/
# [342/604] Fetching abstract from https://aclanthology.org/2022.acl-long.405/
# [343/604] Fetching abstract from https://aclanthology.org/2022.acl-long.406/
# [344/604] Fetching abstract from https://aclanthology.org/2022.acl-long.407/
# [345/604] Fetching abstract from https://aclanthology.org/2022.acl-long.408/
# [346/604] Fetching abstract from https://aclanthology.org/2022.acl-long.409/
# [347/604] Fetching abstract from https://aclanthology.org/2022.acl-long.41/
# [348/604] Fetching abstract from https://aclanthology.org/2022.acl-long.410/
# [349/604] Fetching abstract from https://aclanthology.org/2022.acl-long.411/
# [350/604] Fetching abstract from https://aclanthology.org/2022.acl-long.412/
# [351/604] Fetching abstract from https://aclanthology.org/2022.acl-long.413/
# [352/604] Fetching abstract from https://aclanthology.org/2022.acl-long.414/
# [353/604] Fetching abstract from https://aclanthology.org/2022.acl-long.415/
# [354/604] Fetching abstract from https://aclanthology.org/2022.acl-long.416/
# [355/604] Fetching abstract from https://aclanthology.org/2022.acl-long.417/
# [356/604] Fetching abstract from https://aclanthology.org/2022.acl-long.418/
# [357/604] Fetching abstract from https://aclanthology.org/2022.acl-long.419/
# [358/604] Fetching abstract from https://aclanthology.org/2022.acl-long.42/
# [359/604] Fetching abstract from https://aclanthology.org/2022.acl-long.420/
# [360/604] Fetching abstract from https://aclanthology.org/2022.acl-long.421/
# [361/604] Fetching abstract from https://aclanthology.org/2022.acl-long.422/
# [362/604] Fetching abstract from https://aclanthology.org/2022.acl-long.423/
# [363/604] Fetching abstract from https://aclanthology.org/2022.acl-long.424/
# [364/604] Fetching abstract from https://aclanthology.org/2022.acl-long.425/
# [365/604] Fetching abstract from https://aclanthology.org/2022.acl-long.426/
# [366/604] Fetching abstract from https://aclanthology.org/2022.acl-long.427/
# [367/604] Fetching abstract from https://aclanthology.org/2022.acl-long.428/
# [368/604] Fetching abstract from https://aclanthology.org/2022.acl-long.429/
# [369/604] Fetching abstract from https://aclanthology.org/2022.acl-long.43/
# [370/604] Fetching abstract from https://aclanthology.org/2022.acl-long.430/
# [371/604] Fetching abstract from https://aclanthology.org/2022.acl-long.431/
# [372/604] Fetching abstract from https://aclanthology.org/2022.acl-long.432/
# [373/604] Fetching abstract from https://aclanthology.org/2022.acl-long.433/
# [374/604] Fetching abstract from https://aclanthology.org/2022.acl-long.434/
# [375/604] Fetching abstract from https://aclanthology.org/2022.acl-long.435/
# [376/604] Fetching abstract from https://aclanthology.org/2022.acl-long.436/
# [377/604] Fetching abstract from https://aclanthology.org/2022.acl-long.437/
# [378/604] Fetching abstract from https://aclanthology.org/2022.acl-long.438/
# [379/604] Fetching abstract from https://aclanthology.org/2022.acl-long.439/
# [380/604] Fetching abstract from https://aclanthology.org/2022.acl-long.44/
# [381/604] Fetching abstract from https://aclanthology.org/2022.acl-long.440/
# [382/604] Fetching abstract from https://aclanthology.org/2022.acl-long.441/
# [383/604] Fetching abstract from https://aclanthology.org/2022.acl-long.442/
# [384/604] Fetching abstract from https://aclanthology.org/2022.acl-long.443/
# [385/604] Fetching abstract from https://aclanthology.org/2022.acl-long.444/
# [386/604] Fetching abstract from https://aclanthology.org/2022.acl-long.445/
# [387/604] Fetching abstract from https://aclanthology.org/2022.acl-long.446/
# [388/604] Fetching abstract from https://aclanthology.org/2022.acl-long.447/
# [389/604] Fetching abstract from https://aclanthology.org/2022.acl-long.448/
# [390/604] Fetching abstract from https://aclanthology.org/2022.acl-long.449/
# [391/604] Fetching abstract from https://aclanthology.org/2022.acl-long.45/
# [392/604] Fetching abstract from https://aclanthology.org/2022.acl-long.450/
# [393/604] Fetching abstract from https://aclanthology.org/2022.acl-long.451/
# [394/604] Fetching abstract from https://aclanthology.org/2022.acl-long.452/
# [395/604] Fetching abstract from https://aclanthology.org/2022.acl-long.453/
# [396/604] Fetching abstract from https://aclanthology.org/2022.acl-long.454/
# [397/604] Fetching abstract from https://aclanthology.org/2022.acl-long.455/
# [398/604] Fetching abstract from https://aclanthology.org/2022.acl-long.456/
# [399/604] Fetching abstract from https://aclanthology.org/2022.acl-long.457/
# [400/604] Fetching abstract from https://aclanthology.org/2022.acl-long.458/
# [401/604] Fetching abstract from https://aclanthology.org/2022.acl-long.459/
# [402/604] Fetching abstract from https://aclanthology.org/2022.acl-long.46/
# [403/604] Fetching abstract from https://aclanthology.org/2022.acl-long.460/
# [404/604] Fetching abstract from https://aclanthology.org/2022.acl-long.461/
# [405/604] Fetching abstract from https://aclanthology.org/2022.acl-long.462/
# [406/604] Fetching abstract from https://aclanthology.org/2022.acl-long.463/
# [407/604] Fetching abstract from https://aclanthology.org/2022.acl-long.464/
# [408/604] Fetching abstract from https://aclanthology.org/2022.acl-long.465/
# [409/604] Fetching abstract from https://aclanthology.org/2022.acl-long.466/
# [410/604] Fetching abstract from https://aclanthology.org/2022.acl-long.467/
# [411/604] Fetching abstract from https://aclanthology.org/2022.acl-long.468/
# [412/604] Fetching abstract from https://aclanthology.org/2022.acl-long.469/
# [413/604] Fetching abstract from https://aclanthology.org/2022.acl-long.47/
# [414/604] Fetching abstract from https://aclanthology.org/2022.acl-long.470/
# [415/604] Fetching abstract from https://aclanthology.org/2022.acl-long.471/
# [416/604] Fetching abstract from https://aclanthology.org/2022.acl-long.472/
# [417/604] Fetching abstract from https://aclanthology.org/2022.acl-long.473/
# [418/604] Fetching abstract from https://aclanthology.org/2022.acl-long.474/
# [419/604] Fetching abstract from https://aclanthology.org/2022.acl-long.475/
# [420/604] Fetching abstract from https://aclanthology.org/2022.acl-long.476/
# [421/604] Fetching abstract from https://aclanthology.org/2022.acl-long.477/
# [422/604] Fetching abstract from https://aclanthology.org/2022.acl-long.478/
# [423/604] Fetching abstract from https://aclanthology.org/2022.acl-long.479/
# [424/604] Fetching abstract from https://aclanthology.org/2022.acl-long.48/
# [425/604] Fetching abstract from https://aclanthology.org/2022.acl-long.480/
# [426/604] Fetching abstract from https://aclanthology.org/2022.acl-long.481/
# [427/604] Fetching abstract from https://aclanthology.org/2022.acl-long.482/
# [428/604] Fetching abstract from https://aclanthology.org/2022.acl-long.483/
# [429/604] Fetching abstract from https://aclanthology.org/2022.acl-long.484/
# [430/604] Fetching abstract from https://aclanthology.org/2022.acl-long.485/
# [431/604] Fetching abstract from https://aclanthology.org/2022.acl-long.486/
# [432/604] Fetching abstract from https://aclanthology.org/2022.acl-long.487/
# [433/604] Fetching abstract from https://aclanthology.org/2022.acl-long.488/
# [434/604] Fetching abstract from https://aclanthology.org/2022.acl-long.489/
# [435/604] Fetching abstract from https://aclanthology.org/2022.acl-long.49/
# [436/604] Fetching abstract from https://aclanthology.org/2022.acl-long.490/
# [437/604] Fetching abstract from https://aclanthology.org/2022.acl-long.491/
# [438/604] Fetching abstract from https://aclanthology.org/2022.acl-long.492/
# [439/604] Fetching abstract from https://aclanthology.org/2022.acl-long.493/
# [440/604] Fetching abstract from https://aclanthology.org/2022.acl-long.494/
# [441/604] Fetching abstract from https://aclanthology.org/2022.acl-long.495/
# [442/604] Fetching abstract from https://aclanthology.org/2022.acl-long.496/
# [443/604] Fetching abstract from https://aclanthology.org/2022.acl-long.497/
# [444/604] Fetching abstract from https://aclanthology.org/2022.acl-long.498/
# [445/604] Fetching abstract from https://aclanthology.org/2022.acl-long.499/
# [446/604] Fetching abstract from https://aclanthology.org/2022.acl-long.5/
# [447/604] Fetching abstract from https://aclanthology.org/2022.acl-long.50/
# [448/604] Fetching abstract from https://aclanthology.org/2022.acl-long.500/
# [449/604] Fetching abstract from https://aclanthology.org/2022.acl-long.501/
# [450/604] Fetching abstract from https://aclanthology.org/2022.acl-long.502/
# [451/604] Fetching abstract from https://aclanthology.org/2022.acl-long.503/
# [452/604] Fetching abstract from https://aclanthology.org/2022.acl-long.504/
# [453/604] Fetching abstract from https://aclanthology.org/2022.acl-long.505/
# [454/604] Fetching abstract from https://aclanthology.org/2022.acl-long.506/
# [455/604] Fetching abstract from https://aclanthology.org/2022.acl-long.507/
# [456/604] Fetching abstract from https://aclanthology.org/2022.acl-long.508/
# [457/604] Fetching abstract from https://aclanthology.org/2022.acl-long.509/
# [458/604] Fetching abstract from https://aclanthology.org/2022.acl-long.51/
# [459/604] Fetching abstract from https://aclanthology.org/2022.acl-long.510/
# [460/604] Fetching abstract from https://aclanthology.org/2022.acl-long.511/
# [461/604] Fetching abstract from https://aclanthology.org/2022.acl-long.512/
# [462/604] Fetching abstract from https://aclanthology.org/2022.acl-long.513/
# [463/604] Fetching abstract from https://aclanthology.org/2022.acl-long.514/
# [464/604] Fetching abstract from https://aclanthology.org/2022.acl-long.515/
# [465/604] Fetching abstract from https://aclanthology.org/2022.acl-long.516/
# [466/604] Fetching abstract from https://aclanthology.org/2022.acl-long.517/
# [467/604] Fetching abstract from https://aclanthology.org/2022.acl-long.518/
# [468/604] Fetching abstract from https://aclanthology.org/2022.acl-long.519/
# [469/604] Fetching abstract from https://aclanthology.org/2022.acl-long.52/
# [470/604] Fetching abstract from https://aclanthology.org/2022.acl-long.520/
# [471/604] Fetching abstract from https://aclanthology.org/2022.acl-long.521/
# [472/604] Fetching abstract from https://aclanthology.org/2022.acl-long.522/
# [473/604] Fetching abstract from https://aclanthology.org/2022.acl-long.523/
# [474/604] Fetching abstract from https://aclanthology.org/2022.acl-long.524/
# [475/604] Fetching abstract from https://aclanthology.org/2022.acl-long.525/
# [476/604] Fetching abstract from https://aclanthology.org/2022.acl-long.526/
# [477/604] Fetching abstract from https://aclanthology.org/2022.acl-long.527/
# [478/604] Fetching abstract from https://aclanthology.org/2022.acl-long.528/
# [479/604] Fetching abstract from https://aclanthology.org/2022.acl-long.529/
# [480/604] Fetching abstract from https://aclanthology.org/2022.acl-long.53/
# [481/604] Fetching abstract from https://aclanthology.org/2022.acl-long.530/
# [482/604] Fetching abstract from https://aclanthology.org/2022.acl-long.531/
# [483/604] Fetching abstract from https://aclanthology.org/2022.acl-long.532/
# [484/604] Fetching abstract from https://aclanthology.org/2022.acl-long.533/
# [485/604] Fetching abstract from https://aclanthology.org/2022.acl-long.534/
# [486/604] Fetching abstract from https://aclanthology.org/2022.acl-long.535/
# [487/604] Fetching abstract from https://aclanthology.org/2022.acl-long.536/
# [488/604] Fetching abstract from https://aclanthology.org/2022.acl-long.537/
# [489/604] Fetching abstract from https://aclanthology.org/2022.acl-long.538/
# [490/604] Fetching abstract from https://aclanthology.org/2022.acl-long.539/
# [491/604] Fetching abstract from https://aclanthology.org/2022.acl-long.54/
# [492/604] Fetching abstract from https://aclanthology.org/2022.acl-long.540/
# [493/604] Fetching abstract from https://aclanthology.org/2022.acl-long.541/
# [494/604] Fetching abstract from https://aclanthology.org/2022.acl-long.542/
# [495/604] Fetching abstract from https://aclanthology.org/2022.acl-long.543/
# [496/604] Fetching abstract from https://aclanthology.org/2022.acl-long.544/
# [497/604] Fetching abstract from https://aclanthology.org/2022.acl-long.545/
# [498/604] Fetching abstract from https://aclanthology.org/2022.acl-long.546/
# [499/604] Fetching abstract from https://aclanthology.org/2022.acl-long.547/
# [500/604] Fetching abstract from https://aclanthology.org/2022.acl-long.548/
# [501/604] Fetching abstract from https://aclanthology.org/2022.acl-long.549/
# [502/604] Fetching abstract from https://aclanthology.org/2022.acl-long.55/
# [503/604] Fetching abstract from https://aclanthology.org/2022.acl-long.550/
# [504/604] Fetching abstract from https://aclanthology.org/2022.acl-long.551/
# [505/604] Fetching abstract from https://aclanthology.org/2022.acl-long.552/
# [506/604] Fetching abstract from https://aclanthology.org/2022.acl-long.553/
# [507/604] Fetching abstract from https://aclanthology.org/2022.acl-long.554/
# [508/604] Fetching abstract from https://aclanthology.org/2022.acl-long.555/
# [509/604] Fetching abstract from https://aclanthology.org/2022.acl-long.556/
# [510/604] Fetching abstract from https://aclanthology.org/2022.acl-long.557/
# [511/604] Fetching abstract from https://aclanthology.org/2022.acl-long.558/
# [512/604] Fetching abstract from https://aclanthology.org/2022.acl-long.559/
# [513/604] Fetching abstract from https://aclanthology.org/2022.acl-long.56/
# [514/604] Fetching abstract from https://aclanthology.org/2022.acl-long.560/
# [515/604] Fetching abstract from https://aclanthology.org/2022.acl-long.561/
# [516/604] Fetching abstract from https://aclanthology.org/2022.acl-long.562/
# [517/604] Fetching abstract from https://aclanthology.org/2022.acl-long.563/
# [518/604] Fetching abstract from https://aclanthology.org/2022.acl-long.564/
# [519/604] Fetching abstract from https://aclanthology.org/2022.acl-long.565/
# [520/604] Fetching abstract from https://aclanthology.org/2022.acl-long.566/
# [521/604] Fetching abstract from https://aclanthology.org/2022.acl-long.567/
# [522/604] Fetching abstract from https://aclanthology.org/2022.acl-long.568/
# [523/604] Fetching abstract from https://aclanthology.org/2022.acl-long.569/
# [524/604] Fetching abstract from https://aclanthology.org/2022.acl-long.57/
# [525/604] Fetching abstract from https://aclanthology.org/2022.acl-long.570/
# [526/604] Fetching abstract from https://aclanthology.org/2022.acl-long.571/
# [527/604] Fetching abstract from https://aclanthology.org/2022.acl-long.572/
# [528/604] Fetching abstract from https://aclanthology.org/2022.acl-long.573/
# [529/604] Fetching abstract from https://aclanthology.org/2022.acl-long.574/
# [530/604] Fetching abstract from https://aclanthology.org/2022.acl-long.575/
# [531/604] Fetching abstract from https://aclanthology.org/2022.acl-long.576/
# [532/604] Fetching abstract from https://aclanthology.org/2022.acl-long.577/
# [533/604] Fetching abstract from https://aclanthology.org/2022.acl-long.578/
# [534/604] Fetching abstract from https://aclanthology.org/2022.acl-long.579/
# [535/604] Fetching abstract from https://aclanthology.org/2022.acl-long.58/
# [536/604] Fetching abstract from https://aclanthology.org/2022.acl-long.580/
# [537/604] Fetching abstract from https://aclanthology.org/2022.acl-long.581/
# [538/604] Fetching abstract from https://aclanthology.org/2022.acl-long.582/
# [539/604] Fetching abstract from https://aclanthology.org/2022.acl-long.583/
# [540/604] Fetching abstract from https://aclanthology.org/2022.acl-long.584/
# [541/604] Fetching abstract from https://aclanthology.org/2022.acl-long.585/
# [542/604] Fetching abstract from https://aclanthology.org/2022.acl-long.586/
# [543/604] Fetching abstract from https://aclanthology.org/2022.acl-long.587/
# [544/604] Fetching abstract from https://aclanthology.org/2022.acl-long.588/
# [545/604] Fetching abstract from https://aclanthology.org/2022.acl-long.589/
# [546/604] Fetching abstract from https://aclanthology.org/2022.acl-long.59/
# [547/604] Fetching abstract from https://aclanthology.org/2022.acl-long.590/
# [548/604] Fetching abstract from https://aclanthology.org/2022.acl-long.591/
# [549/604] Fetching abstract from https://aclanthology.org/2022.acl-long.592/
# [550/604] Fetching abstract from https://aclanthology.org/2022.acl-long.593/
# [551/604] Fetching abstract from https://aclanthology.org/2022.acl-long.594/
# [552/604] Fetching abstract from https://aclanthology.org/2022.acl-long.595/
# [553/604] Fetching abstract from https://aclanthology.org/2022.acl-long.596/
# [554/604] Fetching abstract from https://aclanthology.org/2022.acl-long.597/
# [555/604] Fetching abstract from https://aclanthology.org/2022.acl-long.598/
# [556/604] Fetching abstract from https://aclanthology.org/2022.acl-long.599/
# [557/604] Fetching abstract from https://aclanthology.org/2022.acl-long.6/
# [558/604] Fetching abstract from https://aclanthology.org/2022.acl-long.60/
# [559/604] Fetching abstract from https://aclanthology.org/2022.acl-long.600/
# [560/604] Fetching abstract from https://aclanthology.org/2022.acl-long.601/
# [561/604] Fetching abstract from https://aclanthology.org/2022.acl-long.602/
# [562/604] Fetching abstract from https://aclanthology.org/2022.acl-long.603/
# [563/604] Fetching abstract from https://aclanthology.org/2022.acl-long.61/
# [564/604] Fetching abstract from https://aclanthology.org/2022.acl-long.62/
# [565/604] Fetching abstract from https://aclanthology.org/2022.acl-long.63/
# [566/604] Fetching abstract from https://aclanthology.org/2022.acl-long.64/
# [567/604] Fetching abstract from https://aclanthology.org/2022.acl-long.65/
# [568/604] Fetching abstract from https://aclanthology.org/2022.acl-long.66/
# [569/604] Fetching abstract from https://aclanthology.org/2022.acl-long.67/
# [570/604] Fetching abstract from https://aclanthology.org/2022.acl-long.68/
# [571/604] Fetching abstract from https://aclanthology.org/2022.acl-long.69/
# [572/604] Fetching abstract from https://aclanthology.org/2022.acl-long.7/
# [573/604] Fetching abstract from https://aclanthology.org/2022.acl-long.70/
# [574/604] Fetching abstract from https://aclanthology.org/2022.acl-long.71/
# [575/604] Fetching abstract from https://aclanthology.org/2022.acl-long.72/
# [576/604] Fetching abstract from https://aclanthology.org/2022.acl-long.73/
# [577/604] Fetching abstract from https://aclanthology.org/2022.acl-long.74/
# [578/604] Fetching abstract from https://aclanthology.org/2022.acl-long.75/
# [579/604] Fetching abstract from https://aclanthology.org/2022.acl-long.76/
# [580/604] Fetching abstract from https://aclanthology.org/2022.acl-long.77/
# [581/604] Fetching abstract from https://aclanthology.org/2022.acl-long.78/
# [582/604] Fetching abstract from https://aclanthology.org/2022.acl-long.79/
# [583/604] Fetching abstract from https://aclanthology.org/2022.acl-long.8/
# [584/604] Fetching abstract from https://aclanthology.org/2022.acl-long.80/
# [585/604] Fetching abstract from https://aclanthology.org/2022.acl-long.81/
# [586/604] Fetching abstract from https://aclanthology.org/2022.acl-long.82/
# [587/604] Fetching abstract from https://aclanthology.org/2022.acl-long.83/
# [588/604] Fetching abstract from https://aclanthology.org/2022.acl-long.84/
# [589/604] Fetching abstract from https://aclanthology.org/2022.acl-long.85/
# [590/604] Fetching abstract from https://aclanthology.org/2022.acl-long.86/
# [591/604] Fetching abstract from https://aclanthology.org/2022.acl-long.87/
# [592/604] Fetching abstract from https://aclanthology.org/2022.acl-long.88/
# [593/604] Fetching abstract from https://aclanthology.org/2022.acl-long.89/
# [594/604] Fetching abstract from https://aclanthology.org/2022.acl-long.9/
# [595/604] Fetching abstract from https://aclanthology.org/2022.acl-long.90/
# [596/604] Fetching abstract from https://aclanthology.org/2022.acl-long.91/
# [597/604] Fetching abstract from https://aclanthology.org/2022.acl-long.92/
# [598/604] Fetching abstract from https://aclanthology.org/2022.acl-long.93/
# [599/604] Fetching abstract from https://aclanthology.org/2022.acl-long.94/
# [600/604] Fetching abstract from https://aclanthology.org/2022.acl-long.95/
# [601/604] Fetching abstract from https://aclanthology.org/2022.acl-long.96/
# [602/604] Fetching abstract from https://aclanthology.org/2022.acl-long.97/
# [603/604] Fetching abstract from https://aclanthology.org/2022.acl-long.98/
# [604/604] Fetching abstract from https://aclanthology.org/2022.acl-long.99/

# %%
import requests
from bs4 import BeautifulSoup
import time

VOLUME_URL = "https://aclanthology.org/volumes/2022.acl-short/"

def get_paper_links():
    response = requests.get(VOLUME_URL)
    if response.status_code != 200:
        print(f"Failed to access {VOLUME_URL}")
        return []

    soup = BeautifulSoup(response.content, 'html.parser')

    paper_links = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        # Only match short paper pages (e.g., /2022.acl-short.XX/)
        if href.startswith("/2022.acl-short.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)

    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    links = get_paper_links()
    print(f"Found {len(links)} ACL 2022 short papers.")
    with open("acl_2022_short_abstracts.txt", "w", encoding="utf-8") as f:
        for i, url in enumerate(links, 1):
            print(f"[{i}/{len(links)}] Fetching abstract from {url}")
            abstract = extract_abstract(url)
            if abstract:
                f.write(f"URL: {url}\n")
                f.write(f"Abstract: {abstract}\n")
                f.write("="*80 + "\n")
            else:
                print(f"No abstract found for: {url}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# 📄 Found 98 ACL 2022 short papers.
# [1/98] Fetching abstract from https://aclanthology.org/2022.acl-short.0/
# ⚠️ No abstract found for: https://aclanthology.org/2022.acl-short.0/
# [2/98] Fetching abstract from https://aclanthology.org/2022.acl-short.1/
# [3/98] Fetching abstract from https://aclanthology.org/2022.acl-short.10/
# [4/98] Fetching abstract from https://aclanthology.org/2022.acl-short.11/
# [5/98] Fetching abstract from https://aclanthology.org/2022.acl-short.12/
# [6/98] Fetching abstract from https://aclanthology.org/2022.acl-short.13/
# [7/98] Fetching abstract from https://aclanthology.org/2022.acl-short.14/
# [8/98] Fetching abstract from https://aclanthology.org/2022.acl-short.15/
# [9/98] Fetching abstract from https://aclanthology.org/2022.acl-short.16/
# [10/98] Fetching abstract from https://aclanthology.org/2022.acl-short.17/
# [11/98] Fetching abstract from https://aclanthology.org/2022.acl-short.18/
# [12/98] Fetching abstract from https://aclanthology.org/2022.acl-short.19/
# [13/98] Fetching abstract from https://aclanthology.org/2022.acl-short.2/
# [14/98] Fetching abstract from https://aclanthology.org/2022.acl-short.20/
# [15/98] Fetching abstract from https://aclanthology.org/2022.acl-short.21/
# [16/98] Fetching abstract from https://aclanthology.org/2022.acl-short.22/
# [17/98] Fetching abstract from https://aclanthology.org/2022.acl-short.23/
# [18/98] Fetching abstract from https://aclanthology.org/2022.acl-short.24/
# [19/98] Fetching abstract from https://aclanthology.org/2022.acl-short.25/
# [20/98] Fetching abstract from https://aclanthology.org/2022.acl-short.26/
# [21/98] Fetching abstract from https://aclanthology.org/2022.acl-short.27/
# [22/98] Fetching abstract from https://aclanthology.org/2022.acl-short.28/
# [23/98] Fetching abstract from https://aclanthology.org/2022.acl-short.29/
# [24/98] Fetching abstract from https://aclanthology.org/2022.acl-short.3/
# [25/98] Fetching abstract from https://aclanthology.org/2022.acl-short.30/
# [26/98] Fetching abstract from https://aclanthology.org/2022.acl-short.31/
# [27/98] Fetching abstract from https://aclanthology.org/2022.acl-short.32/
# [28/98] Fetching abstract from https://aclanthology.org/2022.acl-short.33/
# [29/98] Fetching abstract from https://aclanthology.org/2022.acl-short.34/
# [30/98] Fetching abstract from https://aclanthology.org/2022.acl-short.35/
# [31/98] Fetching abstract from https://aclanthology.org/2022.acl-short.36/
# [32/98] Fetching abstract from https://aclanthology.org/2022.acl-short.37/
# [33/98] Fetching abstract from https://aclanthology.org/2022.acl-short.38/
# [34/98] Fetching abstract from https://aclanthology.org/2022.acl-short.39/
# [35/98] Fetching abstract from https://aclanthology.org/2022.acl-short.4/
# [36/98] Fetching abstract from https://aclanthology.org/2022.acl-short.40/
# [37/98] Fetching abstract from https://aclanthology.org/2022.acl-short.41/
# [38/98] Fetching abstract from https://aclanthology.org/2022.acl-short.42/
# [39/98] Fetching abstract from https://aclanthology.org/2022.acl-short.43/
# [40/98] Fetching abstract from https://aclanthology.org/2022.acl-short.44/
# [41/98] Fetching abstract from https://aclanthology.org/2022.acl-short.45/
# [42/98] Fetching abstract from https://aclanthology.org/2022.acl-short.46/
# [43/98] Fetching abstract from https://aclanthology.org/2022.acl-short.47/
# [44/98] Fetching abstract from https://aclanthology.org/2022.acl-short.48/
# [45/98] Fetching abstract from https://aclanthology.org/2022.acl-short.49/
# [46/98] Fetching abstract from https://aclanthology.org/2022.acl-short.5/
# [47/98] Fetching abstract from https://aclanthology.org/2022.acl-short.50/
# [48/98] Fetching abstract from https://aclanthology.org/2022.acl-short.51/
# [49/98] Fetching abstract from https://aclanthology.org/2022.acl-short.52/
# [50/98] Fetching abstract from https://aclanthology.org/2022.acl-short.53/
# [51/98] Fetching abstract from https://aclanthology.org/2022.acl-short.54/
# [52/98] Fetching abstract from https://aclanthology.org/2022.acl-short.55/
# [53/98] Fetching abstract from https://aclanthology.org/2022.acl-short.56/
# [54/98] Fetching abstract from https://aclanthology.org/2022.acl-short.57/
# [55/98] Fetching abstract from https://aclanthology.org/2022.acl-short.58/
# [56/98] Fetching abstract from https://aclanthology.org/2022.acl-short.59/
# [57/98] Fetching abstract from https://aclanthology.org/2022.acl-short.6/
# [58/98] Fetching abstract from https://aclanthology.org/2022.acl-short.60/
# [59/98] Fetching abstract from https://aclanthology.org/2022.acl-short.61/
# [60/98] Fetching abstract from https://aclanthology.org/2022.acl-short.62/
# [61/98] Fetching abstract from https://aclanthology.org/2022.acl-short.63/
# [62/98] Fetching abstract from https://aclanthology.org/2022.acl-short.64/
# [63/98] Fetching abstract from https://aclanthology.org/2022.acl-short.65/
# [64/98] Fetching abstract from https://aclanthology.org/2022.acl-short.66/
# [65/98] Fetching abstract from https://aclanthology.org/2022.acl-short.67/
# [66/98] Fetching abstract from https://aclanthology.org/2022.acl-short.68/
# [67/98] Fetching abstract from https://aclanthology.org/2022.acl-short.69/
# [68/98] Fetching abstract from https://aclanthology.org/2022.acl-short.7/
# [69/98] Fetching abstract from https://aclanthology.org/2022.acl-short.70/
# [70/98] Fetching abstract from https://aclanthology.org/2022.acl-short.71/
# [71/98] Fetching abstract from https://aclanthology.org/2022.acl-short.72/
# [72/98] Fetching abstract from https://aclanthology.org/2022.acl-short.73/
# [73/98] Fetching abstract from https://aclanthology.org/2022.acl-short.74/
# [74/98] Fetching abstract from https://aclanthology.org/2022.acl-short.75/
# [75/98] Fetching abstract from https://aclanthology.org/2022.acl-short.76/
# [76/98] Fetching abstract from https://aclanthology.org/2022.acl-short.77/
# [77/98] Fetching abstract from https://aclanthology.org/2022.acl-short.78/
# [78/98] Fetching abstract from https://aclanthology.org/2022.acl-short.79/
# [79/98] Fetching abstract from https://aclanthology.org/2022.acl-short.8/
# [80/98] Fetching abstract from https://aclanthology.org/2022.acl-short.80/
# [81/98] Fetching abstract from https://aclanthology.org/2022.acl-short.81/
# [82/98] Fetching abstract from https://aclanthology.org/2022.acl-short.82/
# [83/98] Fetching abstract from https://aclanthology.org/2022.acl-short.83/
# [84/98] Fetching abstract from https://aclanthology.org/2022.acl-short.84/
# [85/98] Fetching abstract from https://aclanthology.org/2022.acl-short.85/
# [86/98] Fetching abstract from https://aclanthology.org/2022.acl-short.86/
# [87/98] Fetching abstract from https://aclanthology.org/2022.acl-short.87/
# [88/98] Fetching abstract from https://aclanthology.org/2022.acl-short.88/
# [89/98] Fetching abstract from https://aclanthology.org/2022.acl-short.89/
# [90/98] Fetching abstract from https://aclanthology.org/2022.acl-short.9/
# [91/98] Fetching abstract from https://aclanthology.org/2022.acl-short.90/
# [92/98] Fetching abstract from https://aclanthology.org/2022.acl-short.91/
# [93/98] Fetching abstract from https://aclanthology.org/2022.acl-short.92/
# [94/98] Fetching abstract from https://aclanthology.org/2022.acl-short.93/
# [95/98] Fetching abstract from https://aclanthology.org/2022.acl-short.94/
# [96/98] Fetching abstract from https://aclanthology.org/2022.acl-short.95/
# [97/98] Fetching abstract from https://aclanthology.org/2022.acl-short.96/
# [98/98] Fetching abstract from https://aclanthology.org/2022.acl-short.97/

# %%
import requests
from bs4 import BeautifulSoup
import time

VOLUME_URL = "https://aclanthology.org/volumes/2023.acl-long/"

def get_paper_links():
    response = requests.get(VOLUME_URL)
    if response.status_code != 200:
        print(f"Failed to access {VOLUME_URL}")
        return []

    soup = BeautifulSoup(response.content, 'html.parser')
    paper_links = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        if href.startswith("/2023.acl-long.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)

    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    links = get_paper_links()
    print(f"Found {len(links)} ACL 2023 long papers.")
    with open("acl_2023_long_abstracts.txt", "w", encoding="utf-8") as f:
        for i, url in enumerate(links, 1):
            print(f"[{i}/{len(links)}] Fetching abstract from {url}")
            abstract = extract_abstract(url)
            if abstract:
                f.write(f"URL: {url}\n")
                f.write(f"Abstract: {abstract}\n")
                f.write("="*80 + "\n")
            else:
                print(f"No abstract found for: {url}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# 📄 Found 912 ACL 2023 long papers.
# [1/912] Fetching abstract from https://aclanthology.org/2023.acl-long.0/
# ⚠️ No abstract found for: https://aclanthology.org/2023.acl-long.0/
# [2/912] Fetching abstract from https://aclanthology.org/2023.acl-long.1/
# [3/912] Fetching abstract from https://aclanthology.org/2023.acl-long.10/
# [4/912] Fetching abstract from https://aclanthology.org/2023.acl-long.100/
# [5/912] Fetching abstract from https://aclanthology.org/2023.acl-long.101/
# [6/912] Fetching abstract from https://aclanthology.org/2023.acl-long.102/
# [7/912] Fetching abstract from https://aclanthology.org/2023.acl-long.103/
# [8/912] Fetching abstract from https://aclanthology.org/2023.acl-long.104/
# [9/912] Fetching abstract from https://aclanthology.org/2023.acl-long.105/
# [10/912] Fetching abstract from https://aclanthology.org/2023.acl-long.106/
# [11/912] Fetching abstract from https://aclanthology.org/2023.acl-long.107/
# [12/912] Fetching abstract from https://aclanthology.org/2023.acl-long.108/
# [13/912] Fetching abstract from https://aclanthology.org/2023.acl-long.109/
# [14/912] Fetching abstract from https://aclanthology.org/2023.acl-long.11/
# [15/912] Fetching abstract from https://aclanthology.org/2023.acl-long.110/
# [16/912] Fetching abstract from https://aclanthology.org/2023.acl-long.111/
# [17/912] Fetching abstract from https://aclanthology.org/2023.acl-long.112/
# [18/912] Fetching abstract from https://aclanthology.org/2023.acl-long.113/
# [19/912] Fetching abstract from https://aclanthology.org/2023.acl-long.114/
# [20/912] Fetching abstract from https://aclanthology.org/2023.acl-long.115/
# [21/912] Fetching abstract from https://aclanthology.org/2023.acl-long.116/
# [22/912] Fetching abstract from https://aclanthology.org/2023.acl-long.117/
# [23/912] Fetching abstract from https://aclanthology.org/2023.acl-long.118/
# [24/912] Fetching abstract from https://aclanthology.org/2023.acl-long.119/
# [25/912] Fetching abstract from https://aclanthology.org/2023.acl-long.12/
# [26/912] Fetching abstract from https://aclanthology.org/2023.acl-long.120/
# [27/912] Fetching abstract from https://aclanthology.org/2023.acl-long.121/
# [28/912] Fetching abstract from https://aclanthology.org/2023.acl-long.122/
# [29/912] Fetching abstract from https://aclanthology.org/2023.acl-long.123/
# [30/912] Fetching abstract from https://aclanthology.org/2023.acl-long.124/
# [31/912] Fetching abstract from https://aclanthology.org/2023.acl-long.125/
# [32/912] Fetching abstract from https://aclanthology.org/2023.acl-long.126/
# [33/912] Fetching abstract from https://aclanthology.org/2023.acl-long.127/
# [34/912] Fetching abstract from https://aclanthology.org/2023.acl-long.128/
# [35/912] Fetching abstract from https://aclanthology.org/2023.acl-long.129/
# [36/912] Fetching abstract from https://aclanthology.org/2023.acl-long.13/
# [37/912] Fetching abstract from https://aclanthology.org/2023.acl-long.130/
# [38/912] Fetching abstract from https://aclanthology.org/2023.acl-long.131/
# [39/912] Fetching abstract from https://aclanthology.org/2023.acl-long.132/
# [40/912] Fetching abstract from https://aclanthology.org/2023.acl-long.133/
# [41/912] Fetching abstract from https://aclanthology.org/2023.acl-long.134/
# [42/912] Fetching abstract from https://aclanthology.org/2023.acl-long.135/
# [43/912] Fetching abstract from https://aclanthology.org/2023.acl-long.136/
# [44/912] Fetching abstract from https://aclanthology.org/2023.acl-long.137/
# [45/912] Fetching abstract from https://aclanthology.org/2023.acl-long.138/
# [46/912] Fetching abstract from https://aclanthology.org/2023.acl-long.139/
# [47/912] Fetching abstract from https://aclanthology.org/2023.acl-long.14/
# [48/912] Fetching abstract from https://aclanthology.org/2023.acl-long.140/
# [49/912] Fetching abstract from https://aclanthology.org/2023.acl-long.141/
# [50/912] Fetching abstract from https://aclanthology.org/2023.acl-long.142/
# [51/912] Fetching abstract from https://aclanthology.org/2023.acl-long.143/
# [52/912] Fetching abstract from https://aclanthology.org/2023.acl-long.144/
# [53/912] Fetching abstract from https://aclanthology.org/2023.acl-long.145/
# [54/912] Fetching abstract from https://aclanthology.org/2023.acl-long.146/
# [55/912] Fetching abstract from https://aclanthology.org/2023.acl-long.147/
# [56/912] Fetching abstract from https://aclanthology.org/2023.acl-long.148/
# [57/912] Fetching abstract from https://aclanthology.org/2023.acl-long.149/
# [58/912] Fetching abstract from https://aclanthology.org/2023.acl-long.15/
# [59/912] Fetching abstract from https://aclanthology.org/2023.acl-long.150/
# [60/912] Fetching abstract from https://aclanthology.org/2023.acl-long.151/
# [61/912] Fetching abstract from https://aclanthology.org/2023.acl-long.152/
# [62/912] Fetching abstract from https://aclanthology.org/2023.acl-long.153/
# [63/912] Fetching abstract from https://aclanthology.org/2023.acl-long.154/
# [64/912] Fetching abstract from https://aclanthology.org/2023.acl-long.155/
# [65/912] Fetching abstract from https://aclanthology.org/2023.acl-long.156/
# [66/912] Fetching abstract from https://aclanthology.org/2023.acl-long.157/
# [67/912] Fetching abstract from https://aclanthology.org/2023.acl-long.158/
# [68/912] Fetching abstract from https://aclanthology.org/2023.acl-long.159/
# [69/912] Fetching abstract from https://aclanthology.org/2023.acl-long.16/
# [70/912] Fetching abstract from https://aclanthology.org/2023.acl-long.160/
# [71/912] Fetching abstract from https://aclanthology.org/2023.acl-long.161/
# [72/912] Fetching abstract from https://aclanthology.org/2023.acl-long.162/
# [73/912] Fetching abstract from https://aclanthology.org/2023.acl-long.163/
# [74/912] Fetching abstract from https://aclanthology.org/2023.acl-long.164/
# [75/912] Fetching abstract from https://aclanthology.org/2023.acl-long.165/
# [76/912] Fetching abstract from https://aclanthology.org/2023.acl-long.166/
# [77/912] Fetching abstract from https://aclanthology.org/2023.acl-long.167/
# [78/912] Fetching abstract from https://aclanthology.org/2023.acl-long.168/
# [79/912] Fetching abstract from https://aclanthology.org/2023.acl-long.169/
# [80/912] Fetching abstract from https://aclanthology.org/2023.acl-long.17/
# [81/912] Fetching abstract from https://aclanthology.org/2023.acl-long.170/
# [82/912] Fetching abstract from https://aclanthology.org/2023.acl-long.171/
# [83/912] Fetching abstract from https://aclanthology.org/2023.acl-long.172/
# [84/912] Fetching abstract from https://aclanthology.org/2023.acl-long.173/
# [85/912] Fetching abstract from https://aclanthology.org/2023.acl-long.174/
# [86/912] Fetching abstract from https://aclanthology.org/2023.acl-long.175/
# [87/912] Fetching abstract from https://aclanthology.org/2023.acl-long.176/
# [88/912] Fetching abstract from https://aclanthology.org/2023.acl-long.177/
# [89/912] Fetching abstract from https://aclanthology.org/2023.acl-long.178/
# [90/912] Fetching abstract from https://aclanthology.org/2023.acl-long.179/
# [91/912] Fetching abstract from https://aclanthology.org/2023.acl-long.18/
# [92/912] Fetching abstract from https://aclanthology.org/2023.acl-long.180/
# [93/912] Fetching abstract from https://aclanthology.org/2023.acl-long.181/
# [94/912] Fetching abstract from https://aclanthology.org/2023.acl-long.182/
# [95/912] Fetching abstract from https://aclanthology.org/2023.acl-long.183/
# [96/912] Fetching abstract from https://aclanthology.org/2023.acl-long.184/
# [97/912] Fetching abstract from https://aclanthology.org/2023.acl-long.185/
# [98/912] Fetching abstract from https://aclanthology.org/2023.acl-long.186/
# [99/912] Fetching abstract from https://aclanthology.org/2023.acl-long.187/
# [100/912] Fetching abstract from https://aclanthology.org/2023.acl-long.188/
# [101/912] Fetching abstract from https://aclanthology.org/2023.acl-long.189/
# [102/912] Fetching abstract from https://aclanthology.org/2023.acl-long.19/
# [103/912] Fetching abstract from https://aclanthology.org/2023.acl-long.190/
# [104/912] Fetching abstract from https://aclanthology.org/2023.acl-long.191/
# [105/912] Fetching abstract from https://aclanthology.org/2023.acl-long.192/
# [106/912] Fetching abstract from https://aclanthology.org/2023.acl-long.193/
# [107/912] Fetching abstract from https://aclanthology.org/2023.acl-long.194/
# [108/912] Fetching abstract from https://aclanthology.org/2023.acl-long.195/
# [109/912] Fetching abstract from https://aclanthology.org/2023.acl-long.196/
# [110/912] Fetching abstract from https://aclanthology.org/2023.acl-long.197/
# [111/912] Fetching abstract from https://aclanthology.org/2023.acl-long.198/
# [112/912] Fetching abstract from https://aclanthology.org/2023.acl-long.199/
# [113/912] Fetching abstract from https://aclanthology.org/2023.acl-long.2/
# [114/912] Fetching abstract from https://aclanthology.org/2023.acl-long.20/
# [115/912] Fetching abstract from https://aclanthology.org/2023.acl-long.200/
# [116/912] Fetching abstract from https://aclanthology.org/2023.acl-long.201/
# [117/912] Fetching abstract from https://aclanthology.org/2023.acl-long.202/
# [118/912] Fetching abstract from https://aclanthology.org/2023.acl-long.203/
# [119/912] Fetching abstract from https://aclanthology.org/2023.acl-long.204/
# [120/912] Fetching abstract from https://aclanthology.org/2023.acl-long.205/
# [121/912] Fetching abstract from https://aclanthology.org/2023.acl-long.206/
# [122/912] Fetching abstract from https://aclanthology.org/2023.acl-long.207/
# [123/912] Fetching abstract from https://aclanthology.org/2023.acl-long.208/
# [124/912] Fetching abstract from https://aclanthology.org/2023.acl-long.209/
# [125/912] Fetching abstract from https://aclanthology.org/2023.acl-long.21/
# [126/912] Fetching abstract from https://aclanthology.org/2023.acl-long.210/
# [127/912] Fetching abstract from https://aclanthology.org/2023.acl-long.211/
# [128/912] Fetching abstract from https://aclanthology.org/2023.acl-long.212/
# [129/912] Fetching abstract from https://aclanthology.org/2023.acl-long.213/
# [130/912] Fetching abstract from https://aclanthology.org/2023.acl-long.214/
# [131/912] Fetching abstract from https://aclanthology.org/2023.acl-long.215/
# [132/912] Fetching abstract from https://aclanthology.org/2023.acl-long.216/
# [133/912] Fetching abstract from https://aclanthology.org/2023.acl-long.217/
# [134/912] Fetching abstract from https://aclanthology.org/2023.acl-long.218/
# [135/912] Fetching abstract from https://aclanthology.org/2023.acl-long.219/
# [136/912] Fetching abstract from https://aclanthology.org/2023.acl-long.22/
# [137/912] Fetching abstract from https://aclanthology.org/2023.acl-long.220/
# [138/912] Fetching abstract from https://aclanthology.org/2023.acl-long.221/
# [139/912] Fetching abstract from https://aclanthology.org/2023.acl-long.222/
# [140/912] Fetching abstract from https://aclanthology.org/2023.acl-long.223/
# [141/912] Fetching abstract from https://aclanthology.org/2023.acl-long.224/
# [142/912] Fetching abstract from https://aclanthology.org/2023.acl-long.225/
# [143/912] Fetching abstract from https://aclanthology.org/2023.acl-long.226/
# [144/912] Fetching abstract from https://aclanthology.org/2023.acl-long.227/
# [145/912] Fetching abstract from https://aclanthology.org/2023.acl-long.228/
# [146/912] Fetching abstract from https://aclanthology.org/2023.acl-long.229/
# [147/912] Fetching abstract from https://aclanthology.org/2023.acl-long.23/
# [148/912] Fetching abstract from https://aclanthology.org/2023.acl-long.230/
# [149/912] Fetching abstract from https://aclanthology.org/2023.acl-long.231/
# [150/912] Fetching abstract from https://aclanthology.org/2023.acl-long.232/
# [151/912] Fetching abstract from https://aclanthology.org/2023.acl-long.233/
# [152/912] Fetching abstract from https://aclanthology.org/2023.acl-long.234/
# [153/912] Fetching abstract from https://aclanthology.org/2023.acl-long.235/
# [154/912] Fetching abstract from https://aclanthology.org/2023.acl-long.236/
# [155/912] Fetching abstract from https://aclanthology.org/2023.acl-long.237/
# [156/912] Fetching abstract from https://aclanthology.org/2023.acl-long.238/
# [157/912] Fetching abstract from https://aclanthology.org/2023.acl-long.239/
# [158/912] Fetching abstract from https://aclanthology.org/2023.acl-long.24/
# [159/912] Fetching abstract from https://aclanthology.org/2023.acl-long.240/
# [160/912] Fetching abstract from https://aclanthology.org/2023.acl-long.241/
# [161/912] Fetching abstract from https://aclanthology.org/2023.acl-long.242/
# [162/912] Fetching abstract from https://aclanthology.org/2023.acl-long.243/
# [163/912] Fetching abstract from https://aclanthology.org/2023.acl-long.244/
# [164/912] Fetching abstract from https://aclanthology.org/2023.acl-long.245/
# [165/912] Fetching abstract from https://aclanthology.org/2023.acl-long.246/
# [166/912] Fetching abstract from https://aclanthology.org/2023.acl-long.247/
# [167/912] Fetching abstract from https://aclanthology.org/2023.acl-long.248/
# [168/912] Fetching abstract from https://aclanthology.org/2023.acl-long.249/
# [169/912] Fetching abstract from https://aclanthology.org/2023.acl-long.25/
# [170/912] Fetching abstract from https://aclanthology.org/2023.acl-long.250/
# [171/912] Fetching abstract from https://aclanthology.org/2023.acl-long.251/
# [172/912] Fetching abstract from https://aclanthology.org/2023.acl-long.252/
# [173/912] Fetching abstract from https://aclanthology.org/2023.acl-long.253/
# [174/912] Fetching abstract from https://aclanthology.org/2023.acl-long.254/
# [175/912] Fetching abstract from https://aclanthology.org/2023.acl-long.255/
# [176/912] Fetching abstract from https://aclanthology.org/2023.acl-long.256/
# [177/912] Fetching abstract from https://aclanthology.org/2023.acl-long.257/
# [178/912] Fetching abstract from https://aclanthology.org/2023.acl-long.258/
# [179/912] Fetching abstract from https://aclanthology.org/2023.acl-long.259/
# [180/912] Fetching abstract from https://aclanthology.org/2023.acl-long.26/
# [181/912] Fetching abstract from https://aclanthology.org/2023.acl-long.260/
# [182/912] Fetching abstract from https://aclanthology.org/2023.acl-long.261/
# [183/912] Fetching abstract from https://aclanthology.org/2023.acl-long.262/
# [184/912] Fetching abstract from https://aclanthology.org/2023.acl-long.263/
# [185/912] Fetching abstract from https://aclanthology.org/2023.acl-long.264/
# [186/912] Fetching abstract from https://aclanthology.org/2023.acl-long.265/
# [187/912] Fetching abstract from https://aclanthology.org/2023.acl-long.266/
# [188/912] Fetching abstract from https://aclanthology.org/2023.acl-long.267/
# [189/912] Fetching abstract from https://aclanthology.org/2023.acl-long.268/
# [190/912] Fetching abstract from https://aclanthology.org/2023.acl-long.269/
# [191/912] Fetching abstract from https://aclanthology.org/2023.acl-long.27/
# [192/912] Fetching abstract from https://aclanthology.org/2023.acl-long.270/
# [193/912] Fetching abstract from https://aclanthology.org/2023.acl-long.271/
# [194/912] Fetching abstract from https://aclanthology.org/2023.acl-long.272/
# [195/912] Fetching abstract from https://aclanthology.org/2023.acl-long.273/
# [196/912] Fetching abstract from https://aclanthology.org/2023.acl-long.274/
# [197/912] Fetching abstract from https://aclanthology.org/2023.acl-long.275/
# [198/912] Fetching abstract from https://aclanthology.org/2023.acl-long.276/
# [199/912] Fetching abstract from https://aclanthology.org/2023.acl-long.277/
# [200/912] Fetching abstract from https://aclanthology.org/2023.acl-long.278/
# [201/912] Fetching abstract from https://aclanthology.org/2023.acl-long.279/
# [202/912] Fetching abstract from https://aclanthology.org/2023.acl-long.28/
# [203/912] Fetching abstract from https://aclanthology.org/2023.acl-long.280/
# [204/912] Fetching abstract from https://aclanthology.org/2023.acl-long.281/
# [205/912] Fetching abstract from https://aclanthology.org/2023.acl-long.282/
# [206/912] Fetching abstract from https://aclanthology.org/2023.acl-long.283/
# [207/912] Fetching abstract from https://aclanthology.org/2023.acl-long.284/
# [208/912] Fetching abstract from https://aclanthology.org/2023.acl-long.285/
# [209/912] Fetching abstract from https://aclanthology.org/2023.acl-long.286/
# [210/912] Fetching abstract from https://aclanthology.org/2023.acl-long.287/
# [211/912] Fetching abstract from https://aclanthology.org/2023.acl-long.288/
# [212/912] Fetching abstract from https://aclanthology.org/2023.acl-long.289/
# [213/912] Fetching abstract from https://aclanthology.org/2023.acl-long.29/
# [214/912] Fetching abstract from https://aclanthology.org/2023.acl-long.290/
# [215/912] Fetching abstract from https://aclanthology.org/2023.acl-long.291/
# [216/912] Fetching abstract from https://aclanthology.org/2023.acl-long.292/
# [217/912] Fetching abstract from https://aclanthology.org/2023.acl-long.293/
# [218/912] Fetching abstract from https://aclanthology.org/2023.acl-long.294/
# [219/912] Fetching abstract from https://aclanthology.org/2023.acl-long.295/
# [220/912] Fetching abstract from https://aclanthology.org/2023.acl-long.296/
# [221/912] Fetching abstract from https://aclanthology.org/2023.acl-long.297/
# [222/912] Fetching abstract from https://aclanthology.org/2023.acl-long.298/
# [223/912] Fetching abstract from https://aclanthology.org/2023.acl-long.299/
# [224/912] Fetching abstract from https://aclanthology.org/2023.acl-long.3/
# [225/912] Fetching abstract from https://aclanthology.org/2023.acl-long.30/
# [226/912] Fetching abstract from https://aclanthology.org/2023.acl-long.300/
# [227/912] Fetching abstract from https://aclanthology.org/2023.acl-long.301/
# [228/912] Fetching abstract from https://aclanthology.org/2023.acl-long.302/
# [229/912] Fetching abstract from https://aclanthology.org/2023.acl-long.303/
# [230/912] Fetching abstract from https://aclanthology.org/2023.acl-long.304/
# [231/912] Fetching abstract from https://aclanthology.org/2023.acl-long.305/
# [232/912] Fetching abstract from https://aclanthology.org/2023.acl-long.306/
# [233/912] Fetching abstract from https://aclanthology.org/2023.acl-long.307/
# [234/912] Fetching abstract from https://aclanthology.org/2023.acl-long.308/
# [235/912] Fetching abstract from https://aclanthology.org/2023.acl-long.309/
# [236/912] Fetching abstract from https://aclanthology.org/2023.acl-long.31/
# [237/912] Fetching abstract from https://aclanthology.org/2023.acl-long.310/
# [238/912] Fetching abstract from https://aclanthology.org/2023.acl-long.311/
# [239/912] Fetching abstract from https://aclanthology.org/2023.acl-long.312/
# [240/912] Fetching abstract from https://aclanthology.org/2023.acl-long.313/
# [241/912] Fetching abstract from https://aclanthology.org/2023.acl-long.314/
# [242/912] Fetching abstract from https://aclanthology.org/2023.acl-long.315/
# [243/912] Fetching abstract from https://aclanthology.org/2023.acl-long.316/
# [244/912] Fetching abstract from https://aclanthology.org/2023.acl-long.317/
# [245/912] Fetching abstract from https://aclanthology.org/2023.acl-long.318/
# [246/912] Fetching abstract from https://aclanthology.org/2023.acl-long.319/
# [247/912] Fetching abstract from https://aclanthology.org/2023.acl-long.32/
# [248/912] Fetching abstract from https://aclanthology.org/2023.acl-long.320/
# [249/912] Fetching abstract from https://aclanthology.org/2023.acl-long.321/
# [250/912] Fetching abstract from https://aclanthology.org/2023.acl-long.322/
# [251/912] Fetching abstract from https://aclanthology.org/2023.acl-long.323/
# [252/912] Fetching abstract from https://aclanthology.org/2023.acl-long.324/
# [253/912] Fetching abstract from https://aclanthology.org/2023.acl-long.325/
# [254/912] Fetching abstract from https://aclanthology.org/2023.acl-long.326/
# [255/912] Fetching abstract from https://aclanthology.org/2023.acl-long.327/
# [256/912] Fetching abstract from https://aclanthology.org/2023.acl-long.328/
# [257/912] Fetching abstract from https://aclanthology.org/2023.acl-long.329/
# [258/912] Fetching abstract from https://aclanthology.org/2023.acl-long.33/
# [259/912] Fetching abstract from https://aclanthology.org/2023.acl-long.330/
# [260/912] Fetching abstract from https://aclanthology.org/2023.acl-long.331/
# [261/912] Fetching abstract from https://aclanthology.org/2023.acl-long.332/
# [262/912] Fetching abstract from https://aclanthology.org/2023.acl-long.333/
# [263/912] Fetching abstract from https://aclanthology.org/2023.acl-long.334/
# [264/912] Fetching abstract from https://aclanthology.org/2023.acl-long.335/
# [265/912] Fetching abstract from https://aclanthology.org/2023.acl-long.336/
# [266/912] Fetching abstract from https://aclanthology.org/2023.acl-long.337/
# [267/912] Fetching abstract from https://aclanthology.org/2023.acl-long.338/
# [268/912] Fetching abstract from https://aclanthology.org/2023.acl-long.339/
# [269/912] Fetching abstract from https://aclanthology.org/2023.acl-long.34/
# [270/912] Fetching abstract from https://aclanthology.org/2023.acl-long.340/
# [271/912] Fetching abstract from https://aclanthology.org/2023.acl-long.341/
# [272/912] Fetching abstract from https://aclanthology.org/2023.acl-long.342/
# [273/912] Fetching abstract from https://aclanthology.org/2023.acl-long.343/
# [274/912] Fetching abstract from https://aclanthology.org/2023.acl-long.344/
# [275/912] Fetching abstract from https://aclanthology.org/2023.acl-long.345/
# [276/912] Fetching abstract from https://aclanthology.org/2023.acl-long.346/
# [277/912] Fetching abstract from https://aclanthology.org/2023.acl-long.347/
# [278/912] Fetching abstract from https://aclanthology.org/2023.acl-long.348/
# [279/912] Fetching abstract from https://aclanthology.org/2023.acl-long.349/
# [280/912] Fetching abstract from https://aclanthology.org/2023.acl-long.35/
# [281/912] Fetching abstract from https://aclanthology.org/2023.acl-long.350/
# [282/912] Fetching abstract from https://aclanthology.org/2023.acl-long.351/
# [283/912] Fetching abstract from https://aclanthology.org/2023.acl-long.352/
# [284/912] Fetching abstract from https://aclanthology.org/2023.acl-long.353/
# [285/912] Fetching abstract from https://aclanthology.org/2023.acl-long.354/
# [286/912] Fetching abstract from https://aclanthology.org/2023.acl-long.355/
# [287/912] Fetching abstract from https://aclanthology.org/2023.acl-long.356/
# [288/912] Fetching abstract from https://aclanthology.org/2023.acl-long.357/
# [289/912] Fetching abstract from https://aclanthology.org/2023.acl-long.358/
# [290/912] Fetching abstract from https://aclanthology.org/2023.acl-long.359/
# [291/912] Fetching abstract from https://aclanthology.org/2023.acl-long.36/
# [292/912] Fetching abstract from https://aclanthology.org/2023.acl-long.360/
# [293/912] Fetching abstract from https://aclanthology.org/2023.acl-long.361/
# [294/912] Fetching abstract from https://aclanthology.org/2023.acl-long.362/
# [295/912] Fetching abstract from https://aclanthology.org/2023.acl-long.363/
# [296/912] Fetching abstract from https://aclanthology.org/2023.acl-long.364/
# [297/912] Fetching abstract from https://aclanthology.org/2023.acl-long.365/
# [298/912] Fetching abstract from https://aclanthology.org/2023.acl-long.366/
# [299/912] Fetching abstract from https://aclanthology.org/2023.acl-long.367/
# [300/912] Fetching abstract from https://aclanthology.org/2023.acl-long.368/
# [301/912] Fetching abstract from https://aclanthology.org/2023.acl-long.369/
# [302/912] Fetching abstract from https://aclanthology.org/2023.acl-long.37/
# [303/912] Fetching abstract from https://aclanthology.org/2023.acl-long.370/
# [304/912] Fetching abstract from https://aclanthology.org/2023.acl-long.371/
# [305/912] Fetching abstract from https://aclanthology.org/2023.acl-long.372/
# [306/912] Fetching abstract from https://aclanthology.org/2023.acl-long.373/
# [307/912] Fetching abstract from https://aclanthology.org/2023.acl-long.374/
# [308/912] Fetching abstract from https://aclanthology.org/2023.acl-long.375/
# [309/912] Fetching abstract from https://aclanthology.org/2023.acl-long.376/
# [310/912] Fetching abstract from https://aclanthology.org/2023.acl-long.377/
# [311/912] Fetching abstract from https://aclanthology.org/2023.acl-long.378/
# [312/912] Fetching abstract from https://aclanthology.org/2023.acl-long.379/
# [313/912] Fetching abstract from https://aclanthology.org/2023.acl-long.38/
# [314/912] Fetching abstract from https://aclanthology.org/2023.acl-long.380/
# [315/912] Fetching abstract from https://aclanthology.org/2023.acl-long.381/
# [316/912] Fetching abstract from https://aclanthology.org/2023.acl-long.382/
# [317/912] Fetching abstract from https://aclanthology.org/2023.acl-long.383/
# [318/912] Fetching abstract from https://aclanthology.org/2023.acl-long.384/
# [319/912] Fetching abstract from https://aclanthology.org/2023.acl-long.385/
# [320/912] Fetching abstract from https://aclanthology.org/2023.acl-long.386/
# [321/912] Fetching abstract from https://aclanthology.org/2023.acl-long.387/
# [322/912] Fetching abstract from https://aclanthology.org/2023.acl-long.388/
# [323/912] Fetching abstract from https://aclanthology.org/2023.acl-long.389/
# [324/912] Fetching abstract from https://aclanthology.org/2023.acl-long.39/
# [325/912] Fetching abstract from https://aclanthology.org/2023.acl-long.390/
# [326/912] Fetching abstract from https://aclanthology.org/2023.acl-long.391/
# [327/912] Fetching abstract from https://aclanthology.org/2023.acl-long.392/
# [328/912] Fetching abstract from https://aclanthology.org/2023.acl-long.393/
# [329/912] Fetching abstract from https://aclanthology.org/2023.acl-long.394/
# [330/912] Fetching abstract from https://aclanthology.org/2023.acl-long.395/
# [331/912] Fetching abstract from https://aclanthology.org/2023.acl-long.396/
# [332/912] Fetching abstract from https://aclanthology.org/2023.acl-long.397/
# [333/912] Fetching abstract from https://aclanthology.org/2023.acl-long.398/
# [334/912] Fetching abstract from https://aclanthology.org/2023.acl-long.399/
# [335/912] Fetching abstract from https://aclanthology.org/2023.acl-long.4/
# [336/912] Fetching abstract from https://aclanthology.org/2023.acl-long.40/
# [337/912] Fetching abstract from https://aclanthology.org/2023.acl-long.400/
# [338/912] Fetching abstract from https://aclanthology.org/2023.acl-long.401/
# [339/912] Fetching abstract from https://aclanthology.org/2023.acl-long.402/
# [340/912] Fetching abstract from https://aclanthology.org/2023.acl-long.403/
# [341/912] Fetching abstract from https://aclanthology.org/2023.acl-long.404/
# [342/912] Fetching abstract from https://aclanthology.org/2023.acl-long.405/
# [343/912] Fetching abstract from https://aclanthology.org/2023.acl-long.406/
# [344/912] Fetching abstract from https://aclanthology.org/2023.acl-long.407/
# [345/912] Fetching abstract from https://aclanthology.org/2023.acl-long.408/
# [346/912] Fetching abstract from https://aclanthology.org/2023.acl-long.409/
# [347/912] Fetching abstract from https://aclanthology.org/2023.acl-long.41/
# [348/912] Fetching abstract from https://aclanthology.org/2023.acl-long.410/
# [349/912] Fetching abstract from https://aclanthology.org/2023.acl-long.411/
# [350/912] Fetching abstract from https://aclanthology.org/2023.acl-long.412/
# [351/912] Fetching abstract from https://aclanthology.org/2023.acl-long.413/
# [352/912] Fetching abstract from https://aclanthology.org/2023.acl-long.414/
# [353/912] Fetching abstract from https://aclanthology.org/2023.acl-long.415/
# [354/912] Fetching abstract from https://aclanthology.org/2023.acl-long.416/
# [355/912] Fetching abstract from https://aclanthology.org/2023.acl-long.417/
# [356/912] Fetching abstract from https://aclanthology.org/2023.acl-long.418/
# [357/912] Fetching abstract from https://aclanthology.org/2023.acl-long.419/
# [358/912] Fetching abstract from https://aclanthology.org/2023.acl-long.42/
# [359/912] Fetching abstract from https://aclanthology.org/2023.acl-long.420/
# [360/912] Fetching abstract from https://aclanthology.org/2023.acl-long.421/
# [361/912] Fetching abstract from https://aclanthology.org/2023.acl-long.422/
# [362/912] Fetching abstract from https://aclanthology.org/2023.acl-long.423/
# [363/912] Fetching abstract from https://aclanthology.org/2023.acl-long.424/
# [364/912] Fetching abstract from https://aclanthology.org/2023.acl-long.425/
# [365/912] Fetching abstract from https://aclanthology.org/2023.acl-long.426/
# [366/912] Fetching abstract from https://aclanthology.org/2023.acl-long.427/
# [367/912] Fetching abstract from https://aclanthology.org/2023.acl-long.428/
# [368/912] Fetching abstract from https://aclanthology.org/2023.acl-long.429/
# [369/912] Fetching abstract from https://aclanthology.org/2023.acl-long.43/
# [370/912] Fetching abstract from https://aclanthology.org/2023.acl-long.430/
# [371/912] Fetching abstract from https://aclanthology.org/2023.acl-long.431/
# [372/912] Fetching abstract from https://aclanthology.org/2023.acl-long.432/
# [373/912] Fetching abstract from https://aclanthology.org/2023.acl-long.433/
# [374/912] Fetching abstract from https://aclanthology.org/2023.acl-long.434/
# [375/912] Fetching abstract from https://aclanthology.org/2023.acl-long.435/
# [376/912] Fetching abstract from https://aclanthology.org/2023.acl-long.436/
# [377/912] Fetching abstract from https://aclanthology.org/2023.acl-long.437/
# [378/912] Fetching abstract from https://aclanthology.org/2023.acl-long.438/
# [379/912] Fetching abstract from https://aclanthology.org/2023.acl-long.439/
# [380/912] Fetching abstract from https://aclanthology.org/2023.acl-long.44/
# [381/912] Fetching abstract from https://aclanthology.org/2023.acl-long.440/
# [382/912] Fetching abstract from https://aclanthology.org/2023.acl-long.441/
# [383/912] Fetching abstract from https://aclanthology.org/2023.acl-long.442/
# [384/912] Fetching abstract from https://aclanthology.org/2023.acl-long.443/
# [385/912] Fetching abstract from https://aclanthology.org/2023.acl-long.444/
# [386/912] Fetching abstract from https://aclanthology.org/2023.acl-long.445/
# [387/912] Fetching abstract from https://aclanthology.org/2023.acl-long.446/
# [388/912] Fetching abstract from https://aclanthology.org/2023.acl-long.447/
# [389/912] Fetching abstract from https://aclanthology.org/2023.acl-long.448/
# [390/912] Fetching abstract from https://aclanthology.org/2023.acl-long.449/
# [391/912] Fetching abstract from https://aclanthology.org/2023.acl-long.45/
# [392/912] Fetching abstract from https://aclanthology.org/2023.acl-long.450/
# [393/912] Fetching abstract from https://aclanthology.org/2023.acl-long.451/
# [394/912] Fetching abstract from https://aclanthology.org/2023.acl-long.452/
# [395/912] Fetching abstract from https://aclanthology.org/2023.acl-long.453/
# [396/912] Fetching abstract from https://aclanthology.org/2023.acl-long.454/
# [397/912] Fetching abstract from https://aclanthology.org/2023.acl-long.455/
# [398/912] Fetching abstract from https://aclanthology.org/2023.acl-long.456/
# [399/912] Fetching abstract from https://aclanthology.org/2023.acl-long.457/
# [400/912] Fetching abstract from https://aclanthology.org/2023.acl-long.458/
# [401/912] Fetching abstract from https://aclanthology.org/2023.acl-long.459/
# [402/912] Fetching abstract from https://aclanthology.org/2023.acl-long.46/
# [403/912] Fetching abstract from https://aclanthology.org/2023.acl-long.460/
# [404/912] Fetching abstract from https://aclanthology.org/2023.acl-long.461/
# [405/912] Fetching abstract from https://aclanthology.org/2023.acl-long.462/
# [406/912] Fetching abstract from https://aclanthology.org/2023.acl-long.463/
# [407/912] Fetching abstract from https://aclanthology.org/2023.acl-long.464/
# [408/912] Fetching abstract from https://aclanthology.org/2023.acl-long.465/
# [409/912] Fetching abstract from https://aclanthology.org/2023.acl-long.466/
# [410/912] Fetching abstract from https://aclanthology.org/2023.acl-long.467/
# [411/912] Fetching abstract from https://aclanthology.org/2023.acl-long.468/
# [412/912] Fetching abstract from https://aclanthology.org/2023.acl-long.469/
# [413/912] Fetching abstract from https://aclanthology.org/2023.acl-long.47/
# [414/912] Fetching abstract from https://aclanthology.org/2023.acl-long.470/
# [415/912] Fetching abstract from https://aclanthology.org/2023.acl-long.471/
# [416/912] Fetching abstract from https://aclanthology.org/2023.acl-long.472/
# [417/912] Fetching abstract from https://aclanthology.org/2023.acl-long.473/
# [418/912] Fetching abstract from https://aclanthology.org/2023.acl-long.474/
# [419/912] Fetching abstract from https://aclanthology.org/2023.acl-long.475/
# [420/912] Fetching abstract from https://aclanthology.org/2023.acl-long.476/
# [421/912] Fetching abstract from https://aclanthology.org/2023.acl-long.477/
# [422/912] Fetching abstract from https://aclanthology.org/2023.acl-long.478/
# [423/912] Fetching abstract from https://aclanthology.org/2023.acl-long.479/
# [424/912] Fetching abstract from https://aclanthology.org/2023.acl-long.48/
# [425/912] Fetching abstract from https://aclanthology.org/2023.acl-long.480/
# [426/912] Fetching abstract from https://aclanthology.org/2023.acl-long.481/
# [427/912] Fetching abstract from https://aclanthology.org/2023.acl-long.482/
# [428/912] Fetching abstract from https://aclanthology.org/2023.acl-long.483/
# [429/912] Fetching abstract from https://aclanthology.org/2023.acl-long.484/
# [430/912] Fetching abstract from https://aclanthology.org/2023.acl-long.485/
# [431/912] Fetching abstract from https://aclanthology.org/2023.acl-long.486/
# [432/912] Fetching abstract from https://aclanthology.org/2023.acl-long.487/
# [433/912] Fetching abstract from https://aclanthology.org/2023.acl-long.488/
# [434/912] Fetching abstract from https://aclanthology.org/2023.acl-long.489/
# [435/912] Fetching abstract from https://aclanthology.org/2023.acl-long.49/
# [436/912] Fetching abstract from https://aclanthology.org/2023.acl-long.490/
# [437/912] Fetching abstract from https://aclanthology.org/2023.acl-long.491/
# [438/912] Fetching abstract from https://aclanthology.org/2023.acl-long.492/
# [439/912] Fetching abstract from https://aclanthology.org/2023.acl-long.493/
# [440/912] Fetching abstract from https://aclanthology.org/2023.acl-long.494/
# [441/912] Fetching abstract from https://aclanthology.org/2023.acl-long.495/
# [442/912] Fetching abstract from https://aclanthology.org/2023.acl-long.496/
# [443/912] Fetching abstract from https://aclanthology.org/2023.acl-long.497/
# [444/912] Fetching abstract from https://aclanthology.org/2023.acl-long.498/
# [445/912] Fetching abstract from https://aclanthology.org/2023.acl-long.499/
# [446/912] Fetching abstract from https://aclanthology.org/2023.acl-long.5/
# [447/912] Fetching abstract from https://aclanthology.org/2023.acl-long.50/
# [448/912] Fetching abstract from https://aclanthology.org/2023.acl-long.500/
# [449/912] Fetching abstract from https://aclanthology.org/2023.acl-long.501/
# [450/912] Fetching abstract from https://aclanthology.org/2023.acl-long.502/
# [451/912] Fetching abstract from https://aclanthology.org/2023.acl-long.503/
# [452/912] Fetching abstract from https://aclanthology.org/2023.acl-long.504/
# [453/912] Fetching abstract from https://aclanthology.org/2023.acl-long.505/
# [454/912] Fetching abstract from https://aclanthology.org/2023.acl-long.506/
# [455/912] Fetching abstract from https://aclanthology.org/2023.acl-long.507/
# [456/912] Fetching abstract from https://aclanthology.org/2023.acl-long.508/
# [457/912] Fetching abstract from https://aclanthology.org/2023.acl-long.509/
# [458/912] Fetching abstract from https://aclanthology.org/2023.acl-long.51/
# [459/912] Fetching abstract from https://aclanthology.org/2023.acl-long.510/
# [460/912] Fetching abstract from https://aclanthology.org/2023.acl-long.511/
# [461/912] Fetching abstract from https://aclanthology.org/2023.acl-long.512/
# [462/912] Fetching abstract from https://aclanthology.org/2023.acl-long.513/
# [463/912] Fetching abstract from https://aclanthology.org/2023.acl-long.514/
# [464/912] Fetching abstract from https://aclanthology.org/2023.acl-long.515/
# [465/912] Fetching abstract from https://aclanthology.org/2023.acl-long.516/
# [466/912] Fetching abstract from https://aclanthology.org/2023.acl-long.517/
# [467/912] Fetching abstract from https://aclanthology.org/2023.acl-long.518/
# [468/912] Fetching abstract from https://aclanthology.org/2023.acl-long.519/
# [469/912] Fetching abstract from https://aclanthology.org/2023.acl-long.52/
# [470/912] Fetching abstract from https://aclanthology.org/2023.acl-long.520/
# [471/912] Fetching abstract from https://aclanthology.org/2023.acl-long.521/
# [472/912] Fetching abstract from https://aclanthology.org/2023.acl-long.522/
# [473/912] Fetching abstract from https://aclanthology.org/2023.acl-long.523/
# [474/912] Fetching abstract from https://aclanthology.org/2023.acl-long.524/
# [475/912] Fetching abstract from https://aclanthology.org/2023.acl-long.525/
# [476/912] Fetching abstract from https://aclanthology.org/2023.acl-long.526/
# [477/912] Fetching abstract from https://aclanthology.org/2023.acl-long.527/
# [478/912] Fetching abstract from https://aclanthology.org/2023.acl-long.528/
# [479/912] Fetching abstract from https://aclanthology.org/2023.acl-long.529/
# [480/912] Fetching abstract from https://aclanthology.org/2023.acl-long.53/
# [481/912] Fetching abstract from https://aclanthology.org/2023.acl-long.530/
# [482/912] Fetching abstract from https://aclanthology.org/2023.acl-long.531/
# [483/912] Fetching abstract from https://aclanthology.org/2023.acl-long.532/
# [484/912] Fetching abstract from https://aclanthology.org/2023.acl-long.533/
# [485/912] Fetching abstract from https://aclanthology.org/2023.acl-long.534/
# [486/912] Fetching abstract from https://aclanthology.org/2023.acl-long.535/
# [487/912] Fetching abstract from https://aclanthology.org/2023.acl-long.536/
# [488/912] Fetching abstract from https://aclanthology.org/2023.acl-long.537/
# [489/912] Fetching abstract from https://aclanthology.org/2023.acl-long.538/
# [490/912] Fetching abstract from https://aclanthology.org/2023.acl-long.539/
# [491/912] Fetching abstract from https://aclanthology.org/2023.acl-long.54/
# [492/912] Fetching abstract from https://aclanthology.org/2023.acl-long.540/
# [493/912] Fetching abstract from https://aclanthology.org/2023.acl-long.541/
# [494/912] Fetching abstract from https://aclanthology.org/2023.acl-long.542/
# [495/912] Fetching abstract from https://aclanthology.org/2023.acl-long.543/
# [496/912] Fetching abstract from https://aclanthology.org/2023.acl-long.544/
# [497/912] Fetching abstract from https://aclanthology.org/2023.acl-long.545/
# [498/912] Fetching abstract from https://aclanthology.org/2023.acl-long.546/
# [499/912] Fetching abstract from https://aclanthology.org/2023.acl-long.547/
# [500/912] Fetching abstract from https://aclanthology.org/2023.acl-long.548/
# [501/912] Fetching abstract from https://aclanthology.org/2023.acl-long.549/
# [502/912] Fetching abstract from https://aclanthology.org/2023.acl-long.55/
# [503/912] Fetching abstract from https://aclanthology.org/2023.acl-long.550/
# [504/912] Fetching abstract from https://aclanthology.org/2023.acl-long.551/
# [505/912] Fetching abstract from https://aclanthology.org/2023.acl-long.552/
# [506/912] Fetching abstract from https://aclanthology.org/2023.acl-long.553/
# [507/912] Fetching abstract from https://aclanthology.org/2023.acl-long.554/
# [508/912] Fetching abstract from https://aclanthology.org/2023.acl-long.555/
# [509/912] Fetching abstract from https://aclanthology.org/2023.acl-long.556/
# [510/912] Fetching abstract from https://aclanthology.org/2023.acl-long.557/
# [511/912] Fetching abstract from https://aclanthology.org/2023.acl-long.558/
# [512/912] Fetching abstract from https://aclanthology.org/2023.acl-long.559/
# [513/912] Fetching abstract from https://aclanthology.org/2023.acl-long.56/
# [514/912] Fetching abstract from https://aclanthology.org/2023.acl-long.560/
# [515/912] Fetching abstract from https://aclanthology.org/2023.acl-long.561/
# [516/912] Fetching abstract from https://aclanthology.org/2023.acl-long.562/
# [517/912] Fetching abstract from https://aclanthology.org/2023.acl-long.563/
# [518/912] Fetching abstract from https://aclanthology.org/2023.acl-long.564/
# [519/912] Fetching abstract from https://aclanthology.org/2023.acl-long.565/
# [520/912] Fetching abstract from https://aclanthology.org/2023.acl-long.566/
# [521/912] Fetching abstract from https://aclanthology.org/2023.acl-long.567/
# [522/912] Fetching abstract from https://aclanthology.org/2023.acl-long.568/
# [523/912] Fetching abstract from https://aclanthology.org/2023.acl-long.569/
# [524/912] Fetching abstract from https://aclanthology.org/2023.acl-long.57/
# [525/912] Fetching abstract from https://aclanthology.org/2023.acl-long.570/
# [526/912] Fetching abstract from https://aclanthology.org/2023.acl-long.571/
# [527/912] Fetching abstract from https://aclanthology.org/2023.acl-long.572/
# [528/912] Fetching abstract from https://aclanthology.org/2023.acl-long.573/
# [529/912] Fetching abstract from https://aclanthology.org/2023.acl-long.574/
# [530/912] Fetching abstract from https://aclanthology.org/2023.acl-long.575/
# [531/912] Fetching abstract from https://aclanthology.org/2023.acl-long.576/
# [532/912] Fetching abstract from https://aclanthology.org/2023.acl-long.577/
# [533/912] Fetching abstract from https://aclanthology.org/2023.acl-long.578/
# [534/912] Fetching abstract from https://aclanthology.org/2023.acl-long.579/
# [535/912] Fetching abstract from https://aclanthology.org/2023.acl-long.58/
# [536/912] Fetching abstract from https://aclanthology.org/2023.acl-long.580/
# [537/912] Fetching abstract from https://aclanthology.org/2023.acl-long.581/
# [538/912] Fetching abstract from https://aclanthology.org/2023.acl-long.582/
# [539/912] Fetching abstract from https://aclanthology.org/2023.acl-long.583/
# [540/912] Fetching abstract from https://aclanthology.org/2023.acl-long.584/
# [541/912] Fetching abstract from https://aclanthology.org/2023.acl-long.585/
# [542/912] Fetching abstract from https://aclanthology.org/2023.acl-long.586/
# [543/912] Fetching abstract from https://aclanthology.org/2023.acl-long.587/
# [544/912] Fetching abstract from https://aclanthology.org/2023.acl-long.588/
# [545/912] Fetching abstract from https://aclanthology.org/2023.acl-long.589/
# [546/912] Fetching abstract from https://aclanthology.org/2023.acl-long.59/
# [547/912] Fetching abstract from https://aclanthology.org/2023.acl-long.590/
# [548/912] Fetching abstract from https://aclanthology.org/2023.acl-long.591/
# [549/912] Fetching abstract from https://aclanthology.org/2023.acl-long.592/
# [550/912] Fetching abstract from https://aclanthology.org/2023.acl-long.593/
# [551/912] Fetching abstract from https://aclanthology.org/2023.acl-long.594/
# [552/912] Fetching abstract from https://aclanthology.org/2023.acl-long.595/
# [553/912] Fetching abstract from https://aclanthology.org/2023.acl-long.596/
# [554/912] Fetching abstract from https://aclanthology.org/2023.acl-long.597/
# [555/912] Fetching abstract from https://aclanthology.org/2023.acl-long.598/
# [556/912] Fetching abstract from https://aclanthology.org/2023.acl-long.599/
# [557/912] Fetching abstract from https://aclanthology.org/2023.acl-long.6/
# [558/912] Fetching abstract from https://aclanthology.org/2023.acl-long.60/
# [559/912] Fetching abstract from https://aclanthology.org/2023.acl-long.600/
# [560/912] Fetching abstract from https://aclanthology.org/2023.acl-long.601/
# [561/912] Fetching abstract from https://aclanthology.org/2023.acl-long.602/
# [562/912] Fetching abstract from https://aclanthology.org/2023.acl-long.603/
# [563/912] Fetching abstract from https://aclanthology.org/2023.acl-long.604/
# [564/912] Fetching abstract from https://aclanthology.org/2023.acl-long.605/
# [565/912] Fetching abstract from https://aclanthology.org/2023.acl-long.606/
# [566/912] Fetching abstract from https://aclanthology.org/2023.acl-long.607/
# [567/912] Fetching abstract from https://aclanthology.org/2023.acl-long.608/
# [568/912] Fetching abstract from https://aclanthology.org/2023.acl-long.609/
# [569/912] Fetching abstract from https://aclanthology.org/2023.acl-long.61/
# [570/912] Fetching abstract from https://aclanthology.org/2023.acl-long.610/
# [571/912] Fetching abstract from https://aclanthology.org/2023.acl-long.611/
# [572/912] Fetching abstract from https://aclanthology.org/2023.acl-long.612/
# [573/912] Fetching abstract from https://aclanthology.org/2023.acl-long.613/
# [574/912] Fetching abstract from https://aclanthology.org/2023.acl-long.614/
# [575/912] Fetching abstract from https://aclanthology.org/2023.acl-long.615/
# [576/912] Fetching abstract from https://aclanthology.org/2023.acl-long.616/
# [577/912] Fetching abstract from https://aclanthology.org/2023.acl-long.617/
# [578/912] Fetching abstract from https://aclanthology.org/2023.acl-long.618/
# [579/912] Fetching abstract from https://aclanthology.org/2023.acl-long.619/
# [580/912] Fetching abstract from https://aclanthology.org/2023.acl-long.62/
# [581/912] Fetching abstract from https://aclanthology.org/2023.acl-long.620/
# [582/912] Fetching abstract from https://aclanthology.org/2023.acl-long.621/
# [583/912] Fetching abstract from https://aclanthology.org/2023.acl-long.622/
# [584/912] Fetching abstract from https://aclanthology.org/2023.acl-long.623/
# [585/912] Fetching abstract from https://aclanthology.org/2023.acl-long.624/
# [586/912] Fetching abstract from https://aclanthology.org/2023.acl-long.625/
# [587/912] Fetching abstract from https://aclanthology.org/2023.acl-long.626/
# [588/912] Fetching abstract from https://aclanthology.org/2023.acl-long.627/
# [589/912] Fetching abstract from https://aclanthology.org/2023.acl-long.628/
# [590/912] Fetching abstract from https://aclanthology.org/2023.acl-long.629/
# [591/912] Fetching abstract from https://aclanthology.org/2023.acl-long.63/
# [592/912] Fetching abstract from https://aclanthology.org/2023.acl-long.630/
# [593/912] Fetching abstract from https://aclanthology.org/2023.acl-long.631/
# [594/912] Fetching abstract from https://aclanthology.org/2023.acl-long.632/
# [595/912] Fetching abstract from https://aclanthology.org/2023.acl-long.633/
# [596/912] Fetching abstract from https://aclanthology.org/2023.acl-long.634/
# [597/912] Fetching abstract from https://aclanthology.org/2023.acl-long.635/
# [598/912] Fetching abstract from https://aclanthology.org/2023.acl-long.636/
# [599/912] Fetching abstract from https://aclanthology.org/2023.acl-long.637/
# [600/912] Fetching abstract from https://aclanthology.org/2023.acl-long.638/
# [601/912] Fetching abstract from https://aclanthology.org/2023.acl-long.639/
# [602/912] Fetching abstract from https://aclanthology.org/2023.acl-long.64/
# [603/912] Fetching abstract from https://aclanthology.org/2023.acl-long.640/
# [604/912] Fetching abstract from https://aclanthology.org/2023.acl-long.641/
# [605/912] Fetching abstract from https://aclanthology.org/2023.acl-long.642/
# [606/912] Fetching abstract from https://aclanthology.org/2023.acl-long.643/
# [607/912] Fetching abstract from https://aclanthology.org/2023.acl-long.644/
# [608/912] Fetching abstract from https://aclanthology.org/2023.acl-long.645/
# [609/912] Fetching abstract from https://aclanthology.org/2023.acl-long.646/
# [610/912] Fetching abstract from https://aclanthology.org/2023.acl-long.647/
# [611/912] Fetching abstract from https://aclanthology.org/2023.acl-long.648/
# [612/912] Fetching abstract from https://aclanthology.org/2023.acl-long.649/
# [613/912] Fetching abstract from https://aclanthology.org/2023.acl-long.65/
# [614/912] Fetching abstract from https://aclanthology.org/2023.acl-long.650/
# [615/912] Fetching abstract from https://aclanthology.org/2023.acl-long.651/
# [616/912] Fetching abstract from https://aclanthology.org/2023.acl-long.652/
# [617/912] Fetching abstract from https://aclanthology.org/2023.acl-long.653/
# [618/912] Fetching abstract from https://aclanthology.org/2023.acl-long.654/
# [619/912] Fetching abstract from https://aclanthology.org/2023.acl-long.655/
# [620/912] Fetching abstract from https://aclanthology.org/2023.acl-long.656/
# [621/912] Fetching abstract from https://aclanthology.org/2023.acl-long.657/
# [622/912] Fetching abstract from https://aclanthology.org/2023.acl-long.658/
# [623/912] Fetching abstract from https://aclanthology.org/2023.acl-long.659/
# [624/912] Fetching abstract from https://aclanthology.org/2023.acl-long.66/
# ...
# [705/912] Fetching abstract from https://aclanthology.org/2023.acl-long.732/
# [706/912] Fetching abstract from https://aclanthology.org/2023.acl-long.733/
# [707/912] Fetching abstract from https://aclanthology.org/2023.acl-long.734/
# [708/912] Fetching abstract from https://aclanthology.org/2023.acl-long.735/
# [709/912] Fetching abstract from https://aclanthology.org/2023.acl-long.736/
# [710/912] Fetching abstract from https://aclanthology.org/2023.acl-long.737/
# [711/912] Fetching abstract from https://aclanthology.org/2023.acl-long.738/
# [712/912] Fetching abstract from https://aclanthology.org/2023.acl-long.739/
# [713/912] Fetching abstract from https://aclanthology.org/2023.acl-long.74/
# [714/912] Fetching abstract from https://aclanthology.org/2023.acl-long.740/
# [715/912] Fetching abstract from https://aclanthology.org/2023.acl-long.741/
# [716/912] Fetching abstract from https://aclanthology.org/2023.acl-long.742/
# [717/912] Fetching abstract from https://aclanthology.org/2023.acl-long.743/
# [718/912] Fetching abstract from https://aclanthology.org/2023.acl-long.744/
# [719/912] Fetching abstract from https://aclanthology.org/2023.acl-long.745/
# [720/912] Fetching abstract from https://aclanthology.org/2023.acl-long.746/
# [721/912] Fetching abstract from https://aclanthology.org/2023.acl-long.747/
# [722/912] Fetching abstract from https://aclanthology.org/2023.acl-long.748/
# [723/912] Fetching abstract from https://aclanthology.org/2023.acl-long.749/
# [724/912] Fetching abstract from https://aclanthology.org/2023.acl-long.75/
# [725/912] Fetching abstract from https://aclanthology.org/2023.acl-long.750/
# [726/912] Fetching abstract from https://aclanthology.org/2023.acl-long.751/
# [727/912] Fetching abstract from https://aclanthology.org/2023.acl-long.752/
# [728/912] Fetching abstract from https://aclanthology.org/2023.acl-long.753/
# [729/912] Fetching abstract from https://aclanthology.org/2023.acl-long.754/
# [730/912] Fetching abstract from https://aclanthology.org/2023.acl-long.755/
# [731/912] Fetching abstract from https://aclanthology.org/2023.acl-long.756/
# [732/912] Fetching abstract from https://aclanthology.org/2023.acl-long.757/
# [733/912] Fetching abstract from https://aclanthology.org/2023.acl-long.758/
# [734/912] Fetching abstract from https://aclanthology.org/2023.acl-long.759/
# [735/912] Fetching abstract from https://aclanthology.org/2023.acl-long.76/
# [736/912] Fetching abstract from https://aclanthology.org/2023.acl-long.760/
# [737/912] Fetching abstract from https://aclanthology.org/2023.acl-long.761/
# [738/912] Fetching abstract from https://aclanthology.org/2023.acl-long.762/
# [739/912] Fetching abstract from https://aclanthology.org/2023.acl-long.763/
# [740/912] Fetching abstract from https://aclanthology.org/2023.acl-long.764/
# [741/912] Fetching abstract from https://aclanthology.org/2023.acl-long.765/
# [742/912] Fetching abstract from https://aclanthology.org/2023.acl-long.766/
# [743/912] Fetching abstract from https://aclanthology.org/2023.acl-long.767/
# [744/912] Fetching abstract from https://aclanthology.org/2023.acl-long.768/
# [745/912] Fetching abstract from https://aclanthology.org/2023.acl-long.769/
# [746/912] Fetching abstract from https://aclanthology.org/2023.acl-long.77/
# [747/912] Fetching abstract from https://aclanthology.org/2023.acl-long.770/
# [748/912] Fetching abstract from https://aclanthology.org/2023.acl-long.771/
# [749/912] Fetching abstract from https://aclanthology.org/2023.acl-long.772/
# [750/912] Fetching abstract from https://aclanthology.org/2023.acl-long.773/
# [751/912] Fetching abstract from https://aclanthology.org/2023.acl-long.774/
# [752/912] Fetching abstract from https://aclanthology.org/2023.acl-long.775/
# [753/912] Fetching abstract from https://aclanthology.org/2023.acl-long.776/
# [754/912] Fetching abstract from https://aclanthology.org/2023.acl-long.777/
# [755/912] Fetching abstract from https://aclanthology.org/2023.acl-long.778/
# [756/912] Fetching abstract from https://aclanthology.org/2023.acl-long.779/
# [757/912] Fetching abstract from https://aclanthology.org/2023.acl-long.78/
# [758/912] Fetching abstract from https://aclanthology.org/2023.acl-long.780/
# [759/912] Fetching abstract from https://aclanthology.org/2023.acl-long.781/
# [760/912] Fetching abstract from https://aclanthology.org/2023.acl-long.782/
# [761/912] Fetching abstract from https://aclanthology.org/2023.acl-long.783/
# [762/912] Fetching abstract from https://aclanthology.org/2023.acl-long.784/
# [763/912] Fetching abstract from https://aclanthology.org/2023.acl-long.785/
# [764/912] Fetching abstract from https://aclanthology.org/2023.acl-long.786/
# [765/912] Fetching abstract from https://aclanthology.org/2023.acl-long.787/
# [766/912] Fetching abstract from https://aclanthology.org/2023.acl-long.788/
# [767/912] Fetching abstract from https://aclanthology.org/2023.acl-long.789/
# [768/912] Fetching abstract from https://aclanthology.org/2023.acl-long.79/
# [769/912] Fetching abstract from https://aclanthology.org/2023.acl-long.790/
# [770/912] Fetching abstract from https://aclanthology.org/2023.acl-long.791/
# [771/912] Fetching abstract from https://aclanthology.org/2023.acl-long.792/
# [772/912] Fetching abstract from https://aclanthology.org/2023.acl-long.793/
# [773/912] Fetching abstract from https://aclanthology.org/2023.acl-long.794/
# [774/912] Fetching abstract from https://aclanthology.org/2023.acl-long.795/
# [775/912] Fetching abstract from https://aclanthology.org/2023.acl-long.796/
# [776/912] Fetching abstract from https://aclanthology.org/2023.acl-long.797/
# [777/912] Fetching abstract from https://aclanthology.org/2023.acl-long.798/
# [778/912] Fetching abstract from https://aclanthology.org/2023.acl-long.799/
# [779/912] Fetching abstract from https://aclanthology.org/2023.acl-long.8/
# [780/912] Fetching abstract from https://aclanthology.org/2023.acl-long.80/
# [781/912] Fetching abstract from https://aclanthology.org/2023.acl-long.800/
# [782/912] Fetching abstract from https://aclanthology.org/2023.acl-long.801/
# [783/912] Fetching abstract from https://aclanthology.org/2023.acl-long.802/
# [784/912] Fetching abstract from https://aclanthology.org/2023.acl-long.803/
# [785/912] Fetching abstract from https://aclanthology.org/2023.acl-long.804/
# [786/912] Fetching abstract from https://aclanthology.org/2023.acl-long.805/
# [787/912] Fetching abstract from https://aclanthology.org/2023.acl-long.806/
# [788/912] Fetching abstract from https://aclanthology.org/2023.acl-long.807/
# [789/912] Fetching abstract from https://aclanthology.org/2023.acl-long.808/
# [790/912] Fetching abstract from https://aclanthology.org/2023.acl-long.809/
# [791/912] Fetching abstract from https://aclanthology.org/2023.acl-long.81/
# [792/912] Fetching abstract from https://aclanthology.org/2023.acl-long.810/
# [793/912] Fetching abstract from https://aclanthology.org/2023.acl-long.811/
# [794/912] Fetching abstract from https://aclanthology.org/2023.acl-long.812/
# [795/912] Fetching abstract from https://aclanthology.org/2023.acl-long.813/
# [796/912] Fetching abstract from https://aclanthology.org/2023.acl-long.814/
# [797/912] Fetching abstract from https://aclanthology.org/2023.acl-long.815/
# [798/912] Fetching abstract from https://aclanthology.org/2023.acl-long.816/
# [799/912] Fetching abstract from https://aclanthology.org/2023.acl-long.817/
# [800/912] Fetching abstract from https://aclanthology.org/2023.acl-long.818/
# [801/912] Fetching abstract from https://aclanthology.org/2023.acl-long.819/
# [802/912] Fetching abstract from https://aclanthology.org/2023.acl-long.82/
# [803/912] Fetching abstract from https://aclanthology.org/2023.acl-long.820/
# [804/912] Fetching abstract from https://aclanthology.org/2023.acl-long.821/
# [805/912] Fetching abstract from https://aclanthology.org/2023.acl-long.822/
# [806/912] Fetching abstract from https://aclanthology.org/2023.acl-long.823/
# [807/912] Fetching abstract from https://aclanthology.org/2023.acl-long.824/
# [808/912] Fetching abstract from https://aclanthology.org/2023.acl-long.825/
# [809/912] Fetching abstract from https://aclanthology.org/2023.acl-long.826/
# [810/912] Fetching abstract from https://aclanthology.org/2023.acl-long.827/
# [811/912] Fetching abstract from https://aclanthology.org/2023.acl-long.828/
# [812/912] Fetching abstract from https://aclanthology.org/2023.acl-long.829/
# [813/912] Fetching abstract from https://aclanthology.org/2023.acl-long.83/
# [814/912] Fetching abstract from https://aclanthology.org/2023.acl-long.830/
# [815/912] Fetching abstract from https://aclanthology.org/2023.acl-long.831/
# [816/912] Fetching abstract from https://aclanthology.org/2023.acl-long.832/
# [817/912] Fetching abstract from https://aclanthology.org/2023.acl-long.833/
# [818/912] Fetching abstract from https://aclanthology.org/2023.acl-long.834/
# [819/912] Fetching abstract from https://aclanthology.org/2023.acl-long.835/
# [820/912] Fetching abstract from https://aclanthology.org/2023.acl-long.836/
# [821/912] Fetching abstract from https://aclanthology.org/2023.acl-long.837/
# [822/912] Fetching abstract from https://aclanthology.org/2023.acl-long.838/
# [823/912] Fetching abstract from https://aclanthology.org/2023.acl-long.839/
# [824/912] Fetching abstract from https://aclanthology.org/2023.acl-long.84/
# [825/912] Fetching abstract from https://aclanthology.org/2023.acl-long.840/
# [826/912] Fetching abstract from https://aclanthology.org/2023.acl-long.841/
# [827/912] Fetching abstract from https://aclanthology.org/2023.acl-long.842/
# [828/912] Fetching abstract from https://aclanthology.org/2023.acl-long.843/
# [829/912] Fetching abstract from https://aclanthology.org/2023.acl-long.844/
# [830/912] Fetching abstract from https://aclanthology.org/2023.acl-long.845/
# [831/912] Fetching abstract from https://aclanthology.org/2023.acl-long.846/
# [832/912] Fetching abstract from https://aclanthology.org/2023.acl-long.847/
# [833/912] Fetching abstract from https://aclanthology.org/2023.acl-long.848/
# [834/912] Fetching abstract from https://aclanthology.org/2023.acl-long.849/
# [835/912] Fetching abstract from https://aclanthology.org/2023.acl-long.85/
# [836/912] Fetching abstract from https://aclanthology.org/2023.acl-long.850/
# [837/912] Fetching abstract from https://aclanthology.org/2023.acl-long.851/
# [838/912] Fetching abstract from https://aclanthology.org/2023.acl-long.852/
# [839/912] Fetching abstract from https://aclanthology.org/2023.acl-long.853/
# [840/912] Fetching abstract from https://aclanthology.org/2023.acl-long.854/
# [841/912] Fetching abstract from https://aclanthology.org/2023.acl-long.855/
# [842/912] Fetching abstract from https://aclanthology.org/2023.acl-long.856/
# [843/912] Fetching abstract from https://aclanthology.org/2023.acl-long.857/
# [844/912] Fetching abstract from https://aclanthology.org/2023.acl-long.858/
# [845/912] Fetching abstract from https://aclanthology.org/2023.acl-long.859/
# [846/912] Fetching abstract from https://aclanthology.org/2023.acl-long.86/
# [847/912] Fetching abstract from https://aclanthology.org/2023.acl-long.860/
# [848/912] Fetching abstract from https://aclanthology.org/2023.acl-long.861/
# [849/912] Fetching abstract from https://aclanthology.org/2023.acl-long.862/
# [850/912] Fetching abstract from https://aclanthology.org/2023.acl-long.863/
# [851/912] Fetching abstract from https://aclanthology.org/2023.acl-long.864/
# [852/912] Fetching abstract from https://aclanthology.org/2023.acl-long.865/
# [853/912] Fetching abstract from https://aclanthology.org/2023.acl-long.866/
# [854/912] Fetching abstract from https://aclanthology.org/2023.acl-long.867/
# [855/912] Fetching abstract from https://aclanthology.org/2023.acl-long.868/
# [856/912] Fetching abstract from https://aclanthology.org/2023.acl-long.869/
# [857/912] Fetching abstract from https://aclanthology.org/2023.acl-long.87/
# [858/912] Fetching abstract from https://aclanthology.org/2023.acl-long.870/
# [859/912] Fetching abstract from https://aclanthology.org/2023.acl-long.871/
# [860/912] Fetching abstract from https://aclanthology.org/2023.acl-long.872/
# [861/912] Fetching abstract from https://aclanthology.org/2023.acl-long.873/
# [862/912] Fetching abstract from https://aclanthology.org/2023.acl-long.874/
# [863/912] Fetching abstract from https://aclanthology.org/2023.acl-long.875/
# [864/912] Fetching abstract from https://aclanthology.org/2023.acl-long.876/
# [865/912] Fetching abstract from https://aclanthology.org/2023.acl-long.877/
# [866/912] Fetching abstract from https://aclanthology.org/2023.acl-long.878/
# [867/912] Fetching abstract from https://aclanthology.org/2023.acl-long.879/
# [868/912] Fetching abstract from https://aclanthology.org/2023.acl-long.88/
# [869/912] Fetching abstract from https://aclanthology.org/2023.acl-long.880/
# [870/912] Fetching abstract from https://aclanthology.org/2023.acl-long.881/
# [871/912] Fetching abstract from https://aclanthology.org/2023.acl-long.882/
# [872/912] Fetching abstract from https://aclanthology.org/2023.acl-long.883/
# [873/912] Fetching abstract from https://aclanthology.org/2023.acl-long.884/
# [874/912] Fetching abstract from https://aclanthology.org/2023.acl-long.885/
# [875/912] Fetching abstract from https://aclanthology.org/2023.acl-long.886/
# [876/912] Fetching abstract from https://aclanthology.org/2023.acl-long.887/
# [877/912] Fetching abstract from https://aclanthology.org/2023.acl-long.888/
# [878/912] Fetching abstract from https://aclanthology.org/2023.acl-long.889/
# [879/912] Fetching abstract from https://aclanthology.org/2023.acl-long.89/
# [880/912] Fetching abstract from https://aclanthology.org/2023.acl-long.890/
# [881/912] Fetching abstract from https://aclanthology.org/2023.acl-long.891/
# [882/912] Fetching abstract from https://aclanthology.org/2023.acl-long.892/
# [883/912] Fetching abstract from https://aclanthology.org/2023.acl-long.893/
# [884/912] Fetching abstract from https://aclanthology.org/2023.acl-long.894/
# [885/912] Fetching abstract from https://aclanthology.org/2023.acl-long.895/
# [886/912] Fetching abstract from https://aclanthology.org/2023.acl-long.896/
# [887/912] Fetching abstract from https://aclanthology.org/2023.acl-long.897/
# [888/912] Fetching abstract from https://aclanthology.org/2023.acl-long.898/
# [889/912] Fetching abstract from https://aclanthology.org/2023.acl-long.899/
# [890/912] Fetching abstract from https://aclanthology.org/2023.acl-long.9/
# [891/912] Fetching abstract from https://aclanthology.org/2023.acl-long.90/
# [892/912] Fetching abstract from https://aclanthology.org/2023.acl-long.900/
# [893/912] Fetching abstract from https://aclanthology.org/2023.acl-long.901/
# [894/912] Fetching abstract from https://aclanthology.org/2023.acl-long.902/
# [895/912] Fetching abstract from https://aclanthology.org/2023.acl-long.903/
# [896/912] Fetching abstract from https://aclanthology.org/2023.acl-long.904/
# [897/912] Fetching abstract from https://aclanthology.org/2023.acl-long.905/
# [898/912] Fetching abstract from https://aclanthology.org/2023.acl-long.906/
# [899/912] Fetching abstract from https://aclanthology.org/2023.acl-long.907/
# [900/912] Fetching abstract from https://aclanthology.org/2023.acl-long.908/
# [901/912] Fetching abstract from https://aclanthology.org/2023.acl-long.909/
# [902/912] Fetching abstract from https://aclanthology.org/2023.acl-long.91/
# [903/912] Fetching abstract from https://aclanthology.org/2023.acl-long.910/
# [904/912] Fetching abstract from https://aclanthology.org/2023.acl-long.911/
# [905/912] Fetching abstract from https://aclanthology.org/2023.acl-long.92/
# [906/912] Fetching abstract from https://aclanthology.org/2023.acl-long.93/
# [907/912] Fetching abstract from https://aclanthology.org/2023.acl-long.94/
# [908/912] Fetching abstract from https://aclanthology.org/2023.acl-long.95/
# [909/912] Fetching abstract from https://aclanthology.org/2023.acl-long.96/
# [910/912] Fetching abstract from https://aclanthology.org/2023.acl-long.97/
# [911/912] Fetching abstract from https://aclanthology.org/2023.acl-long.98/
# [912/912] Fetching abstract from https://aclanthology.org/2023.acl-long.99/

# %%
import requests
from bs4 import BeautifulSoup
import time

VOLUME_URL = "https://aclanthology.org/volumes/2023.acl-short/"

def get_paper_links():
    response = requests.get(VOLUME_URL)
    if response.status_code != 200:
        print(f"Failed to access {VOLUME_URL}")
        return []

    soup = BeautifulSoup(response.content, 'html.parser')
    paper_links = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        if href.startswith("/2023.acl-short.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)

    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    links = get_paper_links()
    print(f"Found {len(links)} ACL 2023 short papers.")
    with open("acl_2023_short_abstracts.txt", "w", encoding="utf-8") as f:
        for i, url in enumerate(links, 1):
            print(f"[{i}/{len(links)}] Fetching abstract from {url}")
            abstract = extract_abstract(url)
            if abstract:
                f.write(f"URL: {url}\n")
                f.write(f"Abstract: {abstract}\n")
                f.write("="*80 + "\n")
            else:
                print(f"No abstract found for: {url}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# 📄 Found 165 ACL 2023 short papers.
# [1/165] Fetching abstract from https://aclanthology.org/2023.acl-short.0/
# ⚠️ No abstract found for: https://aclanthology.org/2023.acl-short.0/
# [2/165] Fetching abstract from https://aclanthology.org/2023.acl-short.1/
# [3/165] Fetching abstract from https://aclanthology.org/2023.acl-short.10/
# [4/165] Fetching abstract from https://aclanthology.org/2023.acl-short.100/
# [5/165] Fetching abstract from https://aclanthology.org/2023.acl-short.101/
# [6/165] Fetching abstract from https://aclanthology.org/2023.acl-short.102/
# [7/165] Fetching abstract from https://aclanthology.org/2023.acl-short.103/
# [8/165] Fetching abstract from https://aclanthology.org/2023.acl-short.104/
# [9/165] Fetching abstract from https://aclanthology.org/2023.acl-short.105/
# [10/165] Fetching abstract from https://aclanthology.org/2023.acl-short.106/
# [11/165] Fetching abstract from https://aclanthology.org/2023.acl-short.107/
# [12/165] Fetching abstract from https://aclanthology.org/2023.acl-short.108/
# [13/165] Fetching abstract from https://aclanthology.org/2023.acl-short.109/
# [14/165] Fetching abstract from https://aclanthology.org/2023.acl-short.11/
# [15/165] Fetching abstract from https://aclanthology.org/2023.acl-short.110/
# [16/165] Fetching abstract from https://aclanthology.org/2023.acl-short.111/
# [17/165] Fetching abstract from https://aclanthology.org/2023.acl-short.112/
# [18/165] Fetching abstract from https://aclanthology.org/2023.acl-short.113/
# [19/165] Fetching abstract from https://aclanthology.org/2023.acl-short.114/
# [20/165] Fetching abstract from https://aclanthology.org/2023.acl-short.115/
# [21/165] Fetching abstract from https://aclanthology.org/2023.acl-short.116/
# [22/165] Fetching abstract from https://aclanthology.org/2023.acl-short.117/
# [23/165] Fetching abstract from https://aclanthology.org/2023.acl-short.118/
# [24/165] Fetching abstract from https://aclanthology.org/2023.acl-short.119/
# [25/165] Fetching abstract from https://aclanthology.org/2023.acl-short.12/
# [26/165] Fetching abstract from https://aclanthology.org/2023.acl-short.120/
# [27/165] Fetching abstract from https://aclanthology.org/2023.acl-short.121/
# [28/165] Fetching abstract from https://aclanthology.org/2023.acl-short.122/
# [29/165] Fetching abstract from https://aclanthology.org/2023.acl-short.123/
# [30/165] Fetching abstract from https://aclanthology.org/2023.acl-short.124/
# [31/165] Fetching abstract from https://aclanthology.org/2023.acl-short.125/
# [32/165] Fetching abstract from https://aclanthology.org/2023.acl-short.126/
# [33/165] Fetching abstract from https://aclanthology.org/2023.acl-short.127/
# [34/165] Fetching abstract from https://aclanthology.org/2023.acl-short.128/
# [35/165] Fetching abstract from https://aclanthology.org/2023.acl-short.129/
# [36/165] Fetching abstract from https://aclanthology.org/2023.acl-short.13/
# [37/165] Fetching abstract from https://aclanthology.org/2023.acl-short.130/
# [38/165] Fetching abstract from https://aclanthology.org/2023.acl-short.131/
# [39/165] Fetching abstract from https://aclanthology.org/2023.acl-short.132/
# [40/165] Fetching abstract from https://aclanthology.org/2023.acl-short.133/
# [41/165] Fetching abstract from https://aclanthology.org/2023.acl-short.134/
# [42/165] Fetching abstract from https://aclanthology.org/2023.acl-short.135/
# [43/165] Fetching abstract from https://aclanthology.org/2023.acl-short.136/
# [44/165] Fetching abstract from https://aclanthology.org/2023.acl-short.137/
# [45/165] Fetching abstract from https://aclanthology.org/2023.acl-short.138/
# [46/165] Fetching abstract from https://aclanthology.org/2023.acl-short.139/
# [47/165] Fetching abstract from https://aclanthology.org/2023.acl-short.14/
# [48/165] Fetching abstract from https://aclanthology.org/2023.acl-short.140/
# [49/165] Fetching abstract from https://aclanthology.org/2023.acl-short.141/
# [50/165] Fetching abstract from https://aclanthology.org/2023.acl-short.142/
# [51/165] Fetching abstract from https://aclanthology.org/2023.acl-short.143/
# [52/165] Fetching abstract from https://aclanthology.org/2023.acl-short.144/
# [53/165] Fetching abstract from https://aclanthology.org/2023.acl-short.145/
# [54/165] Fetching abstract from https://aclanthology.org/2023.acl-short.146/
# [55/165] Fetching abstract from https://aclanthology.org/2023.acl-short.147/
# [56/165] Fetching abstract from https://aclanthology.org/2023.acl-short.148/
# [57/165] Fetching abstract from https://aclanthology.org/2023.acl-short.149/
# [58/165] Fetching abstract from https://aclanthology.org/2023.acl-short.15/
# [59/165] Fetching abstract from https://aclanthology.org/2023.acl-short.150/
# [60/165] Fetching abstract from https://aclanthology.org/2023.acl-short.151/
# [61/165] Fetching abstract from https://aclanthology.org/2023.acl-short.152/
# [62/165] Fetching abstract from https://aclanthology.org/2023.acl-short.153/
# [63/165] Fetching abstract from https://aclanthology.org/2023.acl-short.154/
# [64/165] Fetching abstract from https://aclanthology.org/2023.acl-short.155/
# [65/165] Fetching abstract from https://aclanthology.org/2023.acl-short.156/
# [66/165] Fetching abstract from https://aclanthology.org/2023.acl-short.157/
# [67/165] Fetching abstract from https://aclanthology.org/2023.acl-short.158/
# [68/165] Fetching abstract from https://aclanthology.org/2023.acl-short.159/
# [69/165] Fetching abstract from https://aclanthology.org/2023.acl-short.16/
# [70/165] Fetching abstract from https://aclanthology.org/2023.acl-short.160/
# [71/165] Fetching abstract from https://aclanthology.org/2023.acl-short.161/
# [72/165] Fetching abstract from https://aclanthology.org/2023.acl-short.162/
# [73/165] Fetching abstract from https://aclanthology.org/2023.acl-short.163/
# [74/165] Fetching abstract from https://aclanthology.org/2023.acl-short.164/
# [75/165] Fetching abstract from https://aclanthology.org/2023.acl-short.17/
# [76/165] Fetching abstract from https://aclanthology.org/2023.acl-short.18/
# [77/165] Fetching abstract from https://aclanthology.org/2023.acl-short.19/
# [78/165] Fetching abstract from https://aclanthology.org/2023.acl-short.2/
# [79/165] Fetching abstract from https://aclanthology.org/2023.acl-short.20/
# [80/165] Fetching abstract from https://aclanthology.org/2023.acl-short.21/
# [81/165] Fetching abstract from https://aclanthology.org/2023.acl-short.22/
# [82/165] Fetching abstract from https://aclanthology.org/2023.acl-short.23/
# [83/165] Fetching abstract from https://aclanthology.org/2023.acl-short.24/
# [84/165] Fetching abstract from https://aclanthology.org/2023.acl-short.25/
# [85/165] Fetching abstract from https://aclanthology.org/2023.acl-short.26/
# [86/165] Fetching abstract from https://aclanthology.org/2023.acl-short.27/
# [87/165] Fetching abstract from https://aclanthology.org/2023.acl-short.28/
# [88/165] Fetching abstract from https://aclanthology.org/2023.acl-short.29/
# [89/165] Fetching abstract from https://aclanthology.org/2023.acl-short.3/
# [90/165] Fetching abstract from https://aclanthology.org/2023.acl-short.30/
# [91/165] Fetching abstract from https://aclanthology.org/2023.acl-short.31/
# [92/165] Fetching abstract from https://aclanthology.org/2023.acl-short.32/
# [93/165] Fetching abstract from https://aclanthology.org/2023.acl-short.33/
# [94/165] Fetching abstract from https://aclanthology.org/2023.acl-short.34/
# [95/165] Fetching abstract from https://aclanthology.org/2023.acl-short.35/
# [96/165] Fetching abstract from https://aclanthology.org/2023.acl-short.36/
# [97/165] Fetching abstract from https://aclanthology.org/2023.acl-short.37/
# [98/165] Fetching abstract from https://aclanthology.org/2023.acl-short.38/
# [99/165] Fetching abstract from https://aclanthology.org/2023.acl-short.39/
# [100/165] Fetching abstract from https://aclanthology.org/2023.acl-short.4/
# [101/165] Fetching abstract from https://aclanthology.org/2023.acl-short.40/
# [102/165] Fetching abstract from https://aclanthology.org/2023.acl-short.41/
# [103/165] Fetching abstract from https://aclanthology.org/2023.acl-short.42/
# [104/165] Fetching abstract from https://aclanthology.org/2023.acl-short.43/
# [105/165] Fetching abstract from https://aclanthology.org/2023.acl-short.44/
# [106/165] Fetching abstract from https://aclanthology.org/2023.acl-short.45/
# [107/165] Fetching abstract from https://aclanthology.org/2023.acl-short.46/
# [108/165] Fetching abstract from https://aclanthology.org/2023.acl-short.47/
# [109/165] Fetching abstract from https://aclanthology.org/2023.acl-short.48/
# [110/165] Fetching abstract from https://aclanthology.org/2023.acl-short.49/
# [111/165] Fetching abstract from https://aclanthology.org/2023.acl-short.5/
# [112/165] Fetching abstract from https://aclanthology.org/2023.acl-short.50/
# [113/165] Fetching abstract from https://aclanthology.org/2023.acl-short.51/
# [114/165] Fetching abstract from https://aclanthology.org/2023.acl-short.52/
# [115/165] Fetching abstract from https://aclanthology.org/2023.acl-short.53/
# [116/165] Fetching abstract from https://aclanthology.org/2023.acl-short.54/
# [117/165] Fetching abstract from https://aclanthology.org/2023.acl-short.55/
# [118/165] Fetching abstract from https://aclanthology.org/2023.acl-short.56/
# [119/165] Fetching abstract from https://aclanthology.org/2023.acl-short.57/
# [120/165] Fetching abstract from https://aclanthology.org/2023.acl-short.58/
# [121/165] Fetching abstract from https://aclanthology.org/2023.acl-short.59/
# [122/165] Fetching abstract from https://aclanthology.org/2023.acl-short.6/
# [123/165] Fetching abstract from https://aclanthology.org/2023.acl-short.60/
# [124/165] Fetching abstract from https://aclanthology.org/2023.acl-short.61/
# [125/165] Fetching abstract from https://aclanthology.org/2023.acl-short.62/
# [126/165] Fetching abstract from https://aclanthology.org/2023.acl-short.63/
# [127/165] Fetching abstract from https://aclanthology.org/2023.acl-short.64/
# [128/165] Fetching abstract from https://aclanthology.org/2023.acl-short.65/
# [129/165] Fetching abstract from https://aclanthology.org/2023.acl-short.66/
# [130/165] Fetching abstract from https://aclanthology.org/2023.acl-short.67/
# [131/165] Fetching abstract from https://aclanthology.org/2023.acl-short.68/
# [132/165] Fetching abstract from https://aclanthology.org/2023.acl-short.69/
# [133/165] Fetching abstract from https://aclanthology.org/2023.acl-short.7/
# [134/165] Fetching abstract from https://aclanthology.org/2023.acl-short.70/
# [135/165] Fetching abstract from https://aclanthology.org/2023.acl-short.71/
# [136/165] Fetching abstract from https://aclanthology.org/2023.acl-short.72/
# [137/165] Fetching abstract from https://aclanthology.org/2023.acl-short.73/
# [138/165] Fetching abstract from https://aclanthology.org/2023.acl-short.74/
# [139/165] Fetching abstract from https://aclanthology.org/2023.acl-short.75/
# [140/165] Fetching abstract from https://aclanthology.org/2023.acl-short.76/
# [141/165] Fetching abstract from https://aclanthology.org/2023.acl-short.77/
# [142/165] Fetching abstract from https://aclanthology.org/2023.acl-short.78/
# [143/165] Fetching abstract from https://aclanthology.org/2023.acl-short.79/
# [144/165] Fetching abstract from https://aclanthology.org/2023.acl-short.8/
# [145/165] Fetching abstract from https://aclanthology.org/2023.acl-short.80/
# [146/165] Fetching abstract from https://aclanthology.org/2023.acl-short.81/
# [147/165] Fetching abstract from https://aclanthology.org/2023.acl-short.82/
# [148/165] Fetching abstract from https://aclanthology.org/2023.acl-short.83/
# [149/165] Fetching abstract from https://aclanthology.org/2023.acl-short.84/
# [150/165] Fetching abstract from https://aclanthology.org/2023.acl-short.85/
# [151/165] Fetching abstract from https://aclanthology.org/2023.acl-short.86/
# [152/165] Fetching abstract from https://aclanthology.org/2023.acl-short.87/
# [153/165] Fetching abstract from https://aclanthology.org/2023.acl-short.88/
# [154/165] Fetching abstract from https://aclanthology.org/2023.acl-short.89/
# [155/165] Fetching abstract from https://aclanthology.org/2023.acl-short.9/
# [156/165] Fetching abstract from https://aclanthology.org/2023.acl-short.90/
# [157/165] Fetching abstract from https://aclanthology.org/2023.acl-short.91/
# [158/165] Fetching abstract from https://aclanthology.org/2023.acl-short.92/
# [159/165] Fetching abstract from https://aclanthology.org/2023.acl-short.93/
# [160/165] Fetching abstract from https://aclanthology.org/2023.acl-short.94/
# [161/165] Fetching abstract from https://aclanthology.org/2023.acl-short.95/
# [162/165] Fetching abstract from https://aclanthology.org/2023.acl-short.96/
# [163/165] Fetching abstract from https://aclanthology.org/2023.acl-short.97/
# [164/165] Fetching abstract from https://aclanthology.org/2023.acl-short.98/
# [165/165] Fetching abstract from https://aclanthology.org/2023.acl-short.99/

# %%
import requests
from bs4 import BeautifulSoup
import time

VOLUME_URL = "https://aclanthology.org/volumes/2024.acl-long/"

def get_paper_links():
    response = requests.get(VOLUME_URL)
    if response.status_code != 200:
        print(f"Failed to access {VOLUME_URL}")
        return []

    soup = BeautifulSoup(response.content, 'html.parser')
    paper_links = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        if href.startswith("/2024.acl-long.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)

    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    links = get_paper_links()
    print(f"Found {len(links)} ACL 2024 long papers.")
    with open("acl_2024_long_abstracts.txt", "w", encoding="utf-8") as f:
        for i, url in enumerate(links, 1):
            print(f"[{i}/{len(links)}] Fetching abstract from {url}")
            abstract = extract_abstract(url)
            if abstract:
                f.write(f"URL: {url}\n")
                f.write(f"Abstract: {abstract}\n")
                f.write("="*80 + "\n")
            else:
                print(f"No abstract found for: {url}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# 📄 Found 865 ACL 2024 long papers.
# [1/865] Fetching abstract from https://aclanthology.org/2024.acl-long.0/
# ⚠️ No abstract found for: https://aclanthology.org/2024.acl-long.0/
# [2/865] Fetching abstract from https://aclanthology.org/2024.acl-long.1/
# [3/865] Fetching abstract from https://aclanthology.org/2024.acl-long.10/
# [4/865] Fetching abstract from https://aclanthology.org/2024.acl-long.100/
# [5/865] Fetching abstract from https://aclanthology.org/2024.acl-long.101/
# [6/865] Fetching abstract from https://aclanthology.org/2024.acl-long.102/
# [7/865] Fetching abstract from https://aclanthology.org/2024.acl-long.103/
# [8/865] Fetching abstract from https://aclanthology.org/2024.acl-long.104/
# [9/865] Fetching abstract from https://aclanthology.org/2024.acl-long.105/
# [10/865] Fetching abstract from https://aclanthology.org/2024.acl-long.106/
# [11/865] Fetching abstract from https://aclanthology.org/2024.acl-long.107/
# [12/865] Fetching abstract from https://aclanthology.org/2024.acl-long.108/
# [13/865] Fetching abstract from https://aclanthology.org/2024.acl-long.109/
# [14/865] Fetching abstract from https://aclanthology.org/2024.acl-long.11/
# [15/865] Fetching abstract from https://aclanthology.org/2024.acl-long.110/
# [16/865] Fetching abstract from https://aclanthology.org/2024.acl-long.111/
# [17/865] Fetching abstract from https://aclanthology.org/2024.acl-long.112/
# [18/865] Fetching abstract from https://aclanthology.org/2024.acl-long.113/
# [19/865] Fetching abstract from https://aclanthology.org/2024.acl-long.114/
# [20/865] Fetching abstract from https://aclanthology.org/2024.acl-long.115/
# [21/865] Fetching abstract from https://aclanthology.org/2024.acl-long.116/
# [22/865] Fetching abstract from https://aclanthology.org/2024.acl-long.117/
# [23/865] Fetching abstract from https://aclanthology.org/2024.acl-long.118/
# [24/865] Fetching abstract from https://aclanthology.org/2024.acl-long.119/
# [25/865] Fetching abstract from https://aclanthology.org/2024.acl-long.12/
# [26/865] Fetching abstract from https://aclanthology.org/2024.acl-long.120/
# [27/865] Fetching abstract from https://aclanthology.org/2024.acl-long.121/
# [28/865] Fetching abstract from https://aclanthology.org/2024.acl-long.122/
# [29/865] Fetching abstract from https://aclanthology.org/2024.acl-long.123/
# [30/865] Fetching abstract from https://aclanthology.org/2024.acl-long.124/
# [31/865] Fetching abstract from https://aclanthology.org/2024.acl-long.125/
# [32/865] Fetching abstract from https://aclanthology.org/2024.acl-long.126/
# [33/865] Fetching abstract from https://aclanthology.org/2024.acl-long.127/
# [34/865] Fetching abstract from https://aclanthology.org/2024.acl-long.128/
# [35/865] Fetching abstract from https://aclanthology.org/2024.acl-long.129/
# [36/865] Fetching abstract from https://aclanthology.org/2024.acl-long.13/
# [37/865] Fetching abstract from https://aclanthology.org/2024.acl-long.130/
# [38/865] Fetching abstract from https://aclanthology.org/2024.acl-long.131/
# [39/865] Fetching abstract from https://aclanthology.org/2024.acl-long.132/
# [40/865] Fetching abstract from https://aclanthology.org/2024.acl-long.133/
# [41/865] Fetching abstract from https://aclanthology.org/2024.acl-long.134/
# [42/865] Fetching abstract from https://aclanthology.org/2024.acl-long.135/
# [43/865] Fetching abstract from https://aclanthology.org/2024.acl-long.136/
# [44/865] Fetching abstract from https://aclanthology.org/2024.acl-long.137/
# [45/865] Fetching abstract from https://aclanthology.org/2024.acl-long.138/
# [46/865] Fetching abstract from https://aclanthology.org/2024.acl-long.139/
# [47/865] Fetching abstract from https://aclanthology.org/2024.acl-long.14/
# [48/865] Fetching abstract from https://aclanthology.org/2024.acl-long.140/
# [49/865] Fetching abstract from https://aclanthology.org/2024.acl-long.141/
# [50/865] Fetching abstract from https://aclanthology.org/2024.acl-long.142/
# [51/865] Fetching abstract from https://aclanthology.org/2024.acl-long.143/
# [52/865] Fetching abstract from https://aclanthology.org/2024.acl-long.144/
# [53/865] Fetching abstract from https://aclanthology.org/2024.acl-long.145/
# [54/865] Fetching abstract from https://aclanthology.org/2024.acl-long.146/
# [55/865] Fetching abstract from https://aclanthology.org/2024.acl-long.147/
# [56/865] Fetching abstract from https://aclanthology.org/2024.acl-long.148/
# [57/865] Fetching abstract from https://aclanthology.org/2024.acl-long.149/
# [58/865] Fetching abstract from https://aclanthology.org/2024.acl-long.15/
# [59/865] Fetching abstract from https://aclanthology.org/2024.acl-long.150/
# [60/865] Fetching abstract from https://aclanthology.org/2024.acl-long.151/
# [61/865] Fetching abstract from https://aclanthology.org/2024.acl-long.152/
# [62/865] Fetching abstract from https://aclanthology.org/2024.acl-long.153/
# [63/865] Fetching abstract from https://aclanthology.org/2024.acl-long.154/
# [64/865] Fetching abstract from https://aclanthology.org/2024.acl-long.155/
# [65/865] Fetching abstract from https://aclanthology.org/2024.acl-long.156/
# [66/865] Fetching abstract from https://aclanthology.org/2024.acl-long.157/
# [67/865] Fetching abstract from https://aclanthology.org/2024.acl-long.158/
# [68/865] Fetching abstract from https://aclanthology.org/2024.acl-long.159/
# [69/865] Fetching abstract from https://aclanthology.org/2024.acl-long.16/
# [70/865] Fetching abstract from https://aclanthology.org/2024.acl-long.160/
# [71/865] Fetching abstract from https://aclanthology.org/2024.acl-long.161/
# [72/865] Fetching abstract from https://aclanthology.org/2024.acl-long.162/
# [73/865] Fetching abstract from https://aclanthology.org/2024.acl-long.163/
# [74/865] Fetching abstract from https://aclanthology.org/2024.acl-long.164/
# [75/865] Fetching abstract from https://aclanthology.org/2024.acl-long.165/
# [76/865] Fetching abstract from https://aclanthology.org/2024.acl-long.166/
# [77/865] Fetching abstract from https://aclanthology.org/2024.acl-long.167/
# [78/865] Fetching abstract from https://aclanthology.org/2024.acl-long.168/
# [79/865] Fetching abstract from https://aclanthology.org/2024.acl-long.169/
# [80/865] Fetching abstract from https://aclanthology.org/2024.acl-long.17/
# [81/865] Fetching abstract from https://aclanthology.org/2024.acl-long.170/
# [82/865] Fetching abstract from https://aclanthology.org/2024.acl-long.171/
# [83/865] Fetching abstract from https://aclanthology.org/2024.acl-long.172/
# [84/865] Fetching abstract from https://aclanthology.org/2024.acl-long.173/
# [85/865] Fetching abstract from https://aclanthology.org/2024.acl-long.174/
# [86/865] Fetching abstract from https://aclanthology.org/2024.acl-long.175/
# [87/865] Fetching abstract from https://aclanthology.org/2024.acl-long.176/
# [88/865] Fetching abstract from https://aclanthology.org/2024.acl-long.177/
# [89/865] Fetching abstract from https://aclanthology.org/2024.acl-long.178/
# [90/865] Fetching abstract from https://aclanthology.org/2024.acl-long.179/
# [91/865] Fetching abstract from https://aclanthology.org/2024.acl-long.18/
# [92/865] Fetching abstract from https://aclanthology.org/2024.acl-long.180/
# [93/865] Fetching abstract from https://aclanthology.org/2024.acl-long.181/
# [94/865] Fetching abstract from https://aclanthology.org/2024.acl-long.182/
# [95/865] Fetching abstract from https://aclanthology.org/2024.acl-long.183/
# [96/865] Fetching abstract from https://aclanthology.org/2024.acl-long.184/
# [97/865] Fetching abstract from https://aclanthology.org/2024.acl-long.185/
# [98/865] Fetching abstract from https://aclanthology.org/2024.acl-long.186/
# [99/865] Fetching abstract from https://aclanthology.org/2024.acl-long.187/
# [100/865] Fetching abstract from https://aclanthology.org/2024.acl-long.188/
# [101/865] Fetching abstract from https://aclanthology.org/2024.acl-long.189/
# [102/865] Fetching abstract from https://aclanthology.org/2024.acl-long.19/
# [103/865] Fetching abstract from https://aclanthology.org/2024.acl-long.190/
# [104/865] Fetching abstract from https://aclanthology.org/2024.acl-long.191/
# [105/865] Fetching abstract from https://aclanthology.org/2024.acl-long.192/
# [106/865] Fetching abstract from https://aclanthology.org/2024.acl-long.193/
# [107/865] Fetching abstract from https://aclanthology.org/2024.acl-long.194/
# [108/865] Fetching abstract from https://aclanthology.org/2024.acl-long.195/
# [109/865] Fetching abstract from https://aclanthology.org/2024.acl-long.196/
# [110/865] Fetching abstract from https://aclanthology.org/2024.acl-long.197/
# [111/865] Fetching abstract from https://aclanthology.org/2024.acl-long.198/
# [112/865] Fetching abstract from https://aclanthology.org/2024.acl-long.199/
# [113/865] Fetching abstract from https://aclanthology.org/2024.acl-long.2/
# [114/865] Fetching abstract from https://aclanthology.org/2024.acl-long.20/
# [115/865] Fetching abstract from https://aclanthology.org/2024.acl-long.200/
# [116/865] Fetching abstract from https://aclanthology.org/2024.acl-long.201/
# [117/865] Fetching abstract from https://aclanthology.org/2024.acl-long.202/
# [118/865] Fetching abstract from https://aclanthology.org/2024.acl-long.203/
# [119/865] Fetching abstract from https://aclanthology.org/2024.acl-long.204/
# [120/865] Fetching abstract from https://aclanthology.org/2024.acl-long.205/
# [121/865] Fetching abstract from https://aclanthology.org/2024.acl-long.206/
# [122/865] Fetching abstract from https://aclanthology.org/2024.acl-long.207/
# [123/865] Fetching abstract from https://aclanthology.org/2024.acl-long.208/
# [124/865] Fetching abstract from https://aclanthology.org/2024.acl-long.209/
# [125/865] Fetching abstract from https://aclanthology.org/2024.acl-long.21/
# [126/865] Fetching abstract from https://aclanthology.org/2024.acl-long.210/
# [127/865] Fetching abstract from https://aclanthology.org/2024.acl-long.211/
# [128/865] Fetching abstract from https://aclanthology.org/2024.acl-long.212/
# [129/865] Fetching abstract from https://aclanthology.org/2024.acl-long.213/
# [130/865] Fetching abstract from https://aclanthology.org/2024.acl-long.214/
# [131/865] Fetching abstract from https://aclanthology.org/2024.acl-long.215/
# [132/865] Fetching abstract from https://aclanthology.org/2024.acl-long.216/
# [133/865] Fetching abstract from https://aclanthology.org/2024.acl-long.217/
# [134/865] Fetching abstract from https://aclanthology.org/2024.acl-long.218/
# [135/865] Fetching abstract from https://aclanthology.org/2024.acl-long.219/
# [136/865] Fetching abstract from https://aclanthology.org/2024.acl-long.22/
# [137/865] Fetching abstract from https://aclanthology.org/2024.acl-long.220/
# [138/865] Fetching abstract from https://aclanthology.org/2024.acl-long.221/
# [139/865] Fetching abstract from https://aclanthology.org/2024.acl-long.222/
# [140/865] Fetching abstract from https://aclanthology.org/2024.acl-long.223/
# [141/865] Fetching abstract from https://aclanthology.org/2024.acl-long.224/
# [142/865] Fetching abstract from https://aclanthology.org/2024.acl-long.225/
# [143/865] Fetching abstract from https://aclanthology.org/2024.acl-long.226/
# [144/865] Fetching abstract from https://aclanthology.org/2024.acl-long.227/
# [145/865] Fetching abstract from https://aclanthology.org/2024.acl-long.228/
# [146/865] Fetching abstract from https://aclanthology.org/2024.acl-long.229/
# [147/865] Fetching abstract from https://aclanthology.org/2024.acl-long.23/
# [148/865] Fetching abstract from https://aclanthology.org/2024.acl-long.230/
# [149/865] Fetching abstract from https://aclanthology.org/2024.acl-long.231/
# [150/865] Fetching abstract from https://aclanthology.org/2024.acl-long.232/
# [151/865] Fetching abstract from https://aclanthology.org/2024.acl-long.233/
# [152/865] Fetching abstract from https://aclanthology.org/2024.acl-long.234/
# [153/865] Fetching abstract from https://aclanthology.org/2024.acl-long.235/
# [154/865] Fetching abstract from https://aclanthology.org/2024.acl-long.236/
# [155/865] Fetching abstract from https://aclanthology.org/2024.acl-long.237/
# [156/865] Fetching abstract from https://aclanthology.org/2024.acl-long.238/
# [157/865] Fetching abstract from https://aclanthology.org/2024.acl-long.239/
# [158/865] Fetching abstract from https://aclanthology.org/2024.acl-long.24/
# [159/865] Fetching abstract from https://aclanthology.org/2024.acl-long.240/
# [160/865] Fetching abstract from https://aclanthology.org/2024.acl-long.241/
# [161/865] Fetching abstract from https://aclanthology.org/2024.acl-long.242/
# [162/865] Fetching abstract from https://aclanthology.org/2024.acl-long.243/
# [163/865] Fetching abstract from https://aclanthology.org/2024.acl-long.244/
# [164/865] Fetching abstract from https://aclanthology.org/2024.acl-long.245/
# [165/865] Fetching abstract from https://aclanthology.org/2024.acl-long.246/
# [166/865] Fetching abstract from https://aclanthology.org/2024.acl-long.247/
# [167/865] Fetching abstract from https://aclanthology.org/2024.acl-long.248/
# [168/865] Fetching abstract from https://aclanthology.org/2024.acl-long.249/
# [169/865] Fetching abstract from https://aclanthology.org/2024.acl-long.25/
# [170/865] Fetching abstract from https://aclanthology.org/2024.acl-long.250/
# [171/865] Fetching abstract from https://aclanthology.org/2024.acl-long.251/
# [172/865] Fetching abstract from https://aclanthology.org/2024.acl-long.252/
# [173/865] Fetching abstract from https://aclanthology.org/2024.acl-long.253/
# [174/865] Fetching abstract from https://aclanthology.org/2024.acl-long.254/
# [175/865] Fetching abstract from https://aclanthology.org/2024.acl-long.255/
# [176/865] Fetching abstract from https://aclanthology.org/2024.acl-long.256/
# [177/865] Fetching abstract from https://aclanthology.org/2024.acl-long.257/
# [178/865] Fetching abstract from https://aclanthology.org/2024.acl-long.258/
# [179/865] Fetching abstract from https://aclanthology.org/2024.acl-long.259/
# [180/865] Fetching abstract from https://aclanthology.org/2024.acl-long.26/
# [181/865] Fetching abstract from https://aclanthology.org/2024.acl-long.260/
# [182/865] Fetching abstract from https://aclanthology.org/2024.acl-long.261/
# [183/865] Fetching abstract from https://aclanthology.org/2024.acl-long.262/
# [184/865] Fetching abstract from https://aclanthology.org/2024.acl-long.263/
# [185/865] Fetching abstract from https://aclanthology.org/2024.acl-long.264/
# [186/865] Fetching abstract from https://aclanthology.org/2024.acl-long.265/
# [187/865] Fetching abstract from https://aclanthology.org/2024.acl-long.266/
# [188/865] Fetching abstract from https://aclanthology.org/2024.acl-long.267/
# [189/865] Fetching abstract from https://aclanthology.org/2024.acl-long.268/
# [190/865] Fetching abstract from https://aclanthology.org/2024.acl-long.269/
# [191/865] Fetching abstract from https://aclanthology.org/2024.acl-long.27/
# [192/865] Fetching abstract from https://aclanthology.org/2024.acl-long.270/
# [193/865] Fetching abstract from https://aclanthology.org/2024.acl-long.271/
# [194/865] Fetching abstract from https://aclanthology.org/2024.acl-long.272/
# [195/865] Fetching abstract from https://aclanthology.org/2024.acl-long.273/
# [196/865] Fetching abstract from https://aclanthology.org/2024.acl-long.274/
# [197/865] Fetching abstract from https://aclanthology.org/2024.acl-long.275/
# [198/865] Fetching abstract from https://aclanthology.org/2024.acl-long.276/
# [199/865] Fetching abstract from https://aclanthology.org/2024.acl-long.277/
# [200/865] Fetching abstract from https://aclanthology.org/2024.acl-long.278/
# [201/865] Fetching abstract from https://aclanthology.org/2024.acl-long.279/
# [202/865] Fetching abstract from https://aclanthology.org/2024.acl-long.28/
# [203/865] Fetching abstract from https://aclanthology.org/2024.acl-long.280/
# [204/865] Fetching abstract from https://aclanthology.org/2024.acl-long.281/
# [205/865] Fetching abstract from https://aclanthology.org/2024.acl-long.282/
# [206/865] Fetching abstract from https://aclanthology.org/2024.acl-long.283/
# [207/865] Fetching abstract from https://aclanthology.org/2024.acl-long.284/
# [208/865] Fetching abstract from https://aclanthology.org/2024.acl-long.285/
# [209/865] Fetching abstract from https://aclanthology.org/2024.acl-long.286/
# [210/865] Fetching abstract from https://aclanthology.org/2024.acl-long.287/
# [211/865] Fetching abstract from https://aclanthology.org/2024.acl-long.288/
# [212/865] Fetching abstract from https://aclanthology.org/2024.acl-long.289/
# [213/865] Fetching abstract from https://aclanthology.org/2024.acl-long.29/
# [214/865] Fetching abstract from https://aclanthology.org/2024.acl-long.290/
# [215/865] Fetching abstract from https://aclanthology.org/2024.acl-long.291/
# [216/865] Fetching abstract from https://aclanthology.org/2024.acl-long.292/
# [217/865] Fetching abstract from https://aclanthology.org/2024.acl-long.293/
# [218/865] Fetching abstract from https://aclanthology.org/2024.acl-long.294/
# [219/865] Fetching abstract from https://aclanthology.org/2024.acl-long.295/
# [220/865] Fetching abstract from https://aclanthology.org/2024.acl-long.296/
# [221/865] Fetching abstract from https://aclanthology.org/2024.acl-long.297/
# [222/865] Fetching abstract from https://aclanthology.org/2024.acl-long.298/
# [223/865] Fetching abstract from https://aclanthology.org/2024.acl-long.299/
# [224/865] Fetching abstract from https://aclanthology.org/2024.acl-long.3/
# [225/865] Fetching abstract from https://aclanthology.org/2024.acl-long.30/
# [226/865] Fetching abstract from https://aclanthology.org/2024.acl-long.300/
# [227/865] Fetching abstract from https://aclanthology.org/2024.acl-long.301/
# [228/865] Fetching abstract from https://aclanthology.org/2024.acl-long.302/
# [229/865] Fetching abstract from https://aclanthology.org/2024.acl-long.303/
# [230/865] Fetching abstract from https://aclanthology.org/2024.acl-long.304/
# [231/865] Fetching abstract from https://aclanthology.org/2024.acl-long.305/
# [232/865] Fetching abstract from https://aclanthology.org/2024.acl-long.306/
# [233/865] Fetching abstract from https://aclanthology.org/2024.acl-long.307/
# [234/865] Fetching abstract from https://aclanthology.org/2024.acl-long.308/
# [235/865] Fetching abstract from https://aclanthology.org/2024.acl-long.309/
# [236/865] Fetching abstract from https://aclanthology.org/2024.acl-long.31/
# [237/865] Fetching abstract from https://aclanthology.org/2024.acl-long.310/
# [238/865] Fetching abstract from https://aclanthology.org/2024.acl-long.311/
# [239/865] Fetching abstract from https://aclanthology.org/2024.acl-long.312/
# [240/865] Fetching abstract from https://aclanthology.org/2024.acl-long.313/
# [241/865] Fetching abstract from https://aclanthology.org/2024.acl-long.314/
# [242/865] Fetching abstract from https://aclanthology.org/2024.acl-long.315/
# [243/865] Fetching abstract from https://aclanthology.org/2024.acl-long.316/
# [244/865] Fetching abstract from https://aclanthology.org/2024.acl-long.317/
# [245/865] Fetching abstract from https://aclanthology.org/2024.acl-long.318/
# [246/865] Fetching abstract from https://aclanthology.org/2024.acl-long.319/
# [247/865] Fetching abstract from https://aclanthology.org/2024.acl-long.32/
# [248/865] Fetching abstract from https://aclanthology.org/2024.acl-long.320/
# [249/865] Fetching abstract from https://aclanthology.org/2024.acl-long.321/
# [250/865] Fetching abstract from https://aclanthology.org/2024.acl-long.322/
# [251/865] Fetching abstract from https://aclanthology.org/2024.acl-long.323/
# [252/865] Fetching abstract from https://aclanthology.org/2024.acl-long.324/
# [253/865] Fetching abstract from https://aclanthology.org/2024.acl-long.325/
# [254/865] Fetching abstract from https://aclanthology.org/2024.acl-long.326/
# [255/865] Fetching abstract from https://aclanthology.org/2024.acl-long.327/
# [256/865] Fetching abstract from https://aclanthology.org/2024.acl-long.328/
# [257/865] Fetching abstract from https://aclanthology.org/2024.acl-long.329/
# [258/865] Fetching abstract from https://aclanthology.org/2024.acl-long.33/
# [259/865] Fetching abstract from https://aclanthology.org/2024.acl-long.330/
# [260/865] Fetching abstract from https://aclanthology.org/2024.acl-long.331/
# [261/865] Fetching abstract from https://aclanthology.org/2024.acl-long.332/
# [262/865] Fetching abstract from https://aclanthology.org/2024.acl-long.333/
# [263/865] Fetching abstract from https://aclanthology.org/2024.acl-long.334/
# [264/865] Fetching abstract from https://aclanthology.org/2024.acl-long.335/
# [265/865] Fetching abstract from https://aclanthology.org/2024.acl-long.336/
# [266/865] Fetching abstract from https://aclanthology.org/2024.acl-long.337/
# [267/865] Fetching abstract from https://aclanthology.org/2024.acl-long.338/
# [268/865] Fetching abstract from https://aclanthology.org/2024.acl-long.339/
# [269/865] Fetching abstract from https://aclanthology.org/2024.acl-long.34/
# [270/865] Fetching abstract from https://aclanthology.org/2024.acl-long.340/
# [271/865] Fetching abstract from https://aclanthology.org/2024.acl-long.341/
# [272/865] Fetching abstract from https://aclanthology.org/2024.acl-long.342/
# [273/865] Fetching abstract from https://aclanthology.org/2024.acl-long.343/
# [274/865] Fetching abstract from https://aclanthology.org/2024.acl-long.344/
# [275/865] Fetching abstract from https://aclanthology.org/2024.acl-long.345/
# [276/865] Fetching abstract from https://aclanthology.org/2024.acl-long.346/
# [277/865] Fetching abstract from https://aclanthology.org/2024.acl-long.347/
# [278/865] Fetching abstract from https://aclanthology.org/2024.acl-long.348/
# [279/865] Fetching abstract from https://aclanthology.org/2024.acl-long.349/
# [280/865] Fetching abstract from https://aclanthology.org/2024.acl-long.35/
# [281/865] Fetching abstract from https://aclanthology.org/2024.acl-long.350/
# [282/865] Fetching abstract from https://aclanthology.org/2024.acl-long.351/
# [283/865] Fetching abstract from https://aclanthology.org/2024.acl-long.352/
# [284/865] Fetching abstract from https://aclanthology.org/2024.acl-long.353/
# [285/865] Fetching abstract from https://aclanthology.org/2024.acl-long.354/
# [286/865] Fetching abstract from https://aclanthology.org/2024.acl-long.355/
# [287/865] Fetching abstract from https://aclanthology.org/2024.acl-long.356/
# [288/865] Fetching abstract from https://aclanthology.org/2024.acl-long.357/
# [289/865] Fetching abstract from https://aclanthology.org/2024.acl-long.358/
# [290/865] Fetching abstract from https://aclanthology.org/2024.acl-long.359/
# [291/865] Fetching abstract from https://aclanthology.org/2024.acl-long.36/
# [292/865] Fetching abstract from https://aclanthology.org/2024.acl-long.360/
# [293/865] Fetching abstract from https://aclanthology.org/2024.acl-long.361/
# [294/865] Fetching abstract from https://aclanthology.org/2024.acl-long.362/
# [295/865] Fetching abstract from https://aclanthology.org/2024.acl-long.363/
# [296/865] Fetching abstract from https://aclanthology.org/2024.acl-long.364/
# [297/865] Fetching abstract from https://aclanthology.org/2024.acl-long.365/
# [298/865] Fetching abstract from https://aclanthology.org/2024.acl-long.366/
# [299/865] Fetching abstract from https://aclanthology.org/2024.acl-long.367/
# [300/865] Fetching abstract from https://aclanthology.org/2024.acl-long.368/
# [301/865] Fetching abstract from https://aclanthology.org/2024.acl-long.369/
# [302/865] Fetching abstract from https://aclanthology.org/2024.acl-long.37/
# [303/865] Fetching abstract from https://aclanthology.org/2024.acl-long.370/
# [304/865] Fetching abstract from https://aclanthology.org/2024.acl-long.371/
# [305/865] Fetching abstract from https://aclanthology.org/2024.acl-long.372/
# [306/865] Fetching abstract from https://aclanthology.org/2024.acl-long.373/
# [307/865] Fetching abstract from https://aclanthology.org/2024.acl-long.374/
# [308/865] Fetching abstract from https://aclanthology.org/2024.acl-long.375/
# [309/865] Fetching abstract from https://aclanthology.org/2024.acl-long.376/
# [310/865] Fetching abstract from https://aclanthology.org/2024.acl-long.377/
# [311/865] Fetching abstract from https://aclanthology.org/2024.acl-long.378/
# [312/865] Fetching abstract from https://aclanthology.org/2024.acl-long.379/
# [313/865] Fetching abstract from https://aclanthology.org/2024.acl-long.38/
# [314/865] Fetching abstract from https://aclanthology.org/2024.acl-long.380/
# [315/865] Fetching abstract from https://aclanthology.org/2024.acl-long.381/
# [316/865] Fetching abstract from https://aclanthology.org/2024.acl-long.382/
# [317/865] Fetching abstract from https://aclanthology.org/2024.acl-long.383/
# [318/865] Fetching abstract from https://aclanthology.org/2024.acl-long.384/
# [319/865] Fetching abstract from https://aclanthology.org/2024.acl-long.385/
# [320/865] Fetching abstract from https://aclanthology.org/2024.acl-long.386/
# [321/865] Fetching abstract from https://aclanthology.org/2024.acl-long.387/
# [322/865] Fetching abstract from https://aclanthology.org/2024.acl-long.388/
# [323/865] Fetching abstract from https://aclanthology.org/2024.acl-long.389/
# [324/865] Fetching abstract from https://aclanthology.org/2024.acl-long.39/
# [325/865] Fetching abstract from https://aclanthology.org/2024.acl-long.390/
# [326/865] Fetching abstract from https://aclanthology.org/2024.acl-long.391/
# [327/865] Fetching abstract from https://aclanthology.org/2024.acl-long.392/
# [328/865] Fetching abstract from https://aclanthology.org/2024.acl-long.393/
# [329/865] Fetching abstract from https://aclanthology.org/2024.acl-long.394/
# [330/865] Fetching abstract from https://aclanthology.org/2024.acl-long.395/
# [331/865] Fetching abstract from https://aclanthology.org/2024.acl-long.396/
# [332/865] Fetching abstract from https://aclanthology.org/2024.acl-long.397/
# [333/865] Fetching abstract from https://aclanthology.org/2024.acl-long.398/
# [334/865] Fetching abstract from https://aclanthology.org/2024.acl-long.399/
# [335/865] Fetching abstract from https://aclanthology.org/2024.acl-long.4/
# [336/865] Fetching abstract from https://aclanthology.org/2024.acl-long.40/
# [337/865] Fetching abstract from https://aclanthology.org/2024.acl-long.400/
# [338/865] Fetching abstract from https://aclanthology.org/2024.acl-long.401/
# [339/865] Fetching abstract from https://aclanthology.org/2024.acl-long.402/
# [340/865] Fetching abstract from https://aclanthology.org/2024.acl-long.403/
# [341/865] Fetching abstract from https://aclanthology.org/2024.acl-long.404/
# [342/865] Fetching abstract from https://aclanthology.org/2024.acl-long.405/
# [343/865] Fetching abstract from https://aclanthology.org/2024.acl-long.406/
# [344/865] Fetching abstract from https://aclanthology.org/2024.acl-long.407/
# [345/865] Fetching abstract from https://aclanthology.org/2024.acl-long.408/
# [346/865] Fetching abstract from https://aclanthology.org/2024.acl-long.409/
# [347/865] Fetching abstract from https://aclanthology.org/2024.acl-long.41/
# [348/865] Fetching abstract from https://aclanthology.org/2024.acl-long.410/
# [349/865] Fetching abstract from https://aclanthology.org/2024.acl-long.411/
# [350/865] Fetching abstract from https://aclanthology.org/2024.acl-long.412/
# [351/865] Fetching abstract from https://aclanthology.org/2024.acl-long.413/
# [352/865] Fetching abstract from https://aclanthology.org/2024.acl-long.414/
# [353/865] Fetching abstract from https://aclanthology.org/2024.acl-long.415/
# [354/865] Fetching abstract from https://aclanthology.org/2024.acl-long.416/
# [355/865] Fetching abstract from https://aclanthology.org/2024.acl-long.417/
# [356/865] Fetching abstract from https://aclanthology.org/2024.acl-long.418/
# [357/865] Fetching abstract from https://aclanthology.org/2024.acl-long.419/
# [358/865] Fetching abstract from https://aclanthology.org/2024.acl-long.42/
# [359/865] Fetching abstract from https://aclanthology.org/2024.acl-long.420/
# [360/865] Fetching abstract from https://aclanthology.org/2024.acl-long.421/
# [361/865] Fetching abstract from https://aclanthology.org/2024.acl-long.422/
# [362/865] Fetching abstract from https://aclanthology.org/2024.acl-long.423/
# [363/865] Fetching abstract from https://aclanthology.org/2024.acl-long.424/
# [364/865] Fetching abstract from https://aclanthology.org/2024.acl-long.425/
# [365/865] Fetching abstract from https://aclanthology.org/2024.acl-long.426/
# [366/865] Fetching abstract from https://aclanthology.org/2024.acl-long.427/
# [367/865] Fetching abstract from https://aclanthology.org/2024.acl-long.428/
# [368/865] Fetching abstract from https://aclanthology.org/2024.acl-long.429/
# [369/865] Fetching abstract from https://aclanthology.org/2024.acl-long.43/
# [370/865] Fetching abstract from https://aclanthology.org/2024.acl-long.430/
# [371/865] Fetching abstract from https://aclanthology.org/2024.acl-long.431/
# [372/865] Fetching abstract from https://aclanthology.org/2024.acl-long.432/
# [373/865] Fetching abstract from https://aclanthology.org/2024.acl-long.433/
# [374/865] Fetching abstract from https://aclanthology.org/2024.acl-long.434/
# [375/865] Fetching abstract from https://aclanthology.org/2024.acl-long.435/
# [376/865] Fetching abstract from https://aclanthology.org/2024.acl-long.436/
# [377/865] Fetching abstract from https://aclanthology.org/2024.acl-long.437/
# [378/865] Fetching abstract from https://aclanthology.org/2024.acl-long.438/
# [379/865] Fetching abstract from https://aclanthology.org/2024.acl-long.439/
# [380/865] Fetching abstract from https://aclanthology.org/2024.acl-long.44/
# [381/865] Fetching abstract from https://aclanthology.org/2024.acl-long.440/
# [382/865] Fetching abstract from https://aclanthology.org/2024.acl-long.441/
# [383/865] Fetching abstract from https://aclanthology.org/2024.acl-long.442/
# [384/865] Fetching abstract from https://aclanthology.org/2024.acl-long.443/
# [385/865] Fetching abstract from https://aclanthology.org/2024.acl-long.444/
# [386/865] Fetching abstract from https://aclanthology.org/2024.acl-long.445/
# [387/865] Fetching abstract from https://aclanthology.org/2024.acl-long.446/
# [388/865] Fetching abstract from https://aclanthology.org/2024.acl-long.447/
# [389/865] Fetching abstract from https://aclanthology.org/2024.acl-long.448/
# [390/865] Fetching abstract from https://aclanthology.org/2024.acl-long.449/
# [391/865] Fetching abstract from https://aclanthology.org/2024.acl-long.45/
# [392/865] Fetching abstract from https://aclanthology.org/2024.acl-long.450/
# [393/865] Fetching abstract from https://aclanthology.org/2024.acl-long.451/
# [394/865] Fetching abstract from https://aclanthology.org/2024.acl-long.452/
# [395/865] Fetching abstract from https://aclanthology.org/2024.acl-long.453/
# [396/865] Fetching abstract from https://aclanthology.org/2024.acl-long.454/
# [397/865] Fetching abstract from https://aclanthology.org/2024.acl-long.455/
# [398/865] Fetching abstract from https://aclanthology.org/2024.acl-long.456/
# [399/865] Fetching abstract from https://aclanthology.org/2024.acl-long.457/
# [400/865] Fetching abstract from https://aclanthology.org/2024.acl-long.458/
# [401/865] Fetching abstract from https://aclanthology.org/2024.acl-long.459/
# [402/865] Fetching abstract from https://aclanthology.org/2024.acl-long.46/
# [403/865] Fetching abstract from https://aclanthology.org/2024.acl-long.460/
# [404/865] Fetching abstract from https://aclanthology.org/2024.acl-long.461/
# [405/865] Fetching abstract from https://aclanthology.org/2024.acl-long.462/
# [406/865] Fetching abstract from https://aclanthology.org/2024.acl-long.463/
# [407/865] Fetching abstract from https://aclanthology.org/2024.acl-long.464/
# [408/865] Fetching abstract from https://aclanthology.org/2024.acl-long.465/
# [409/865] Fetching abstract from https://aclanthology.org/2024.acl-long.466/
# [410/865] Fetching abstract from https://aclanthology.org/2024.acl-long.467/
# [411/865] Fetching abstract from https://aclanthology.org/2024.acl-long.468/
# [412/865] Fetching abstract from https://aclanthology.org/2024.acl-long.469/
# [413/865] Fetching abstract from https://aclanthology.org/2024.acl-long.47/
# [414/865] Fetching abstract from https://aclanthology.org/2024.acl-long.470/
# [415/865] Fetching abstract from https://aclanthology.org/2024.acl-long.471/
# [416/865] Fetching abstract from https://aclanthology.org/2024.acl-long.472/
# [417/865] Fetching abstract from https://aclanthology.org/2024.acl-long.473/
# [418/865] Fetching abstract from https://aclanthology.org/2024.acl-long.474/
# [419/865] Fetching abstract from https://aclanthology.org/2024.acl-long.475/
# ⚠️ No abstract found for: https://aclanthology.org/2024.acl-long.475/
# [420/865] Fetching abstract from https://aclanthology.org/2024.acl-long.476/
# [421/865] Fetching abstract from https://aclanthology.org/2024.acl-long.477/
# [422/865] Fetching abstract from https://aclanthology.org/2024.acl-long.478/
# [423/865] Fetching abstract from https://aclanthology.org/2024.acl-long.479/
# [424/865] Fetching abstract from https://aclanthology.org/2024.acl-long.48/
# [425/865] Fetching abstract from https://aclanthology.org/2024.acl-long.480/
# [426/865] Fetching abstract from https://aclanthology.org/2024.acl-long.481/
# [427/865] Fetching abstract from https://aclanthology.org/2024.acl-long.482/
# [428/865] Fetching abstract from https://aclanthology.org/2024.acl-long.483/
# [429/865] Fetching abstract from https://aclanthology.org/2024.acl-long.484/
# [430/865] Fetching abstract from https://aclanthology.org/2024.acl-long.485/
# [431/865] Fetching abstract from https://aclanthology.org/2024.acl-long.486/
# [432/865] Fetching abstract from https://aclanthology.org/2024.acl-long.487/
# [433/865] Fetching abstract from https://aclanthology.org/2024.acl-long.488/
# [434/865] Fetching abstract from https://aclanthology.org/2024.acl-long.489/
# [435/865] Fetching abstract from https://aclanthology.org/2024.acl-long.49/
# [436/865] Fetching abstract from https://aclanthology.org/2024.acl-long.490/
# [437/865] Fetching abstract from https://aclanthology.org/2024.acl-long.491/
# [438/865] Fetching abstract from https://aclanthology.org/2024.acl-long.492/
# [439/865] Fetching abstract from https://aclanthology.org/2024.acl-long.493/
# [440/865] Fetching abstract from https://aclanthology.org/2024.acl-long.494/
# [441/865] Fetching abstract from https://aclanthology.org/2024.acl-long.495/
# [442/865] Fetching abstract from https://aclanthology.org/2024.acl-long.496/
# [443/865] Fetching abstract from https://aclanthology.org/2024.acl-long.497/
# [444/865] Fetching abstract from https://aclanthology.org/2024.acl-long.498/
# [445/865] Fetching abstract from https://aclanthology.org/2024.acl-long.499/
# [446/865] Fetching abstract from https://aclanthology.org/2024.acl-long.5/
# [447/865] Fetching abstract from https://aclanthology.org/2024.acl-long.50/
# [448/865] Fetching abstract from https://aclanthology.org/2024.acl-long.500/
# [449/865] Fetching abstract from https://aclanthology.org/2024.acl-long.501/
# [450/865] Fetching abstract from https://aclanthology.org/2024.acl-long.502/
# Error fetching https://aclanthology.org/2024.acl-long.502/: ('Connection broken: IncompleteRead(10 bytes read, 8760 more expected)', IncompleteRead(10 bytes read, 8760 more expected))
# ⚠️ No abstract found for: https://aclanthology.org/2024.acl-long.502/
# [451/865] Fetching abstract from https://aclanthology.org/2024.acl-long.503/
# [452/865] Fetching abstract from https://aclanthology.org/2024.acl-long.504/
# [453/865] Fetching abstract from https://aclanthology.org/2024.acl-long.505/
# [454/865] Fetching abstract from https://aclanthology.org/2024.acl-long.506/
# [455/865] Fetching abstract from https://aclanthology.org/2024.acl-long.507/
# [456/865] Fetching abstract from https://aclanthology.org/2024.acl-long.508/
# [457/865] Fetching abstract from https://aclanthology.org/2024.acl-long.509/
# [458/865] Fetching abstract from https://aclanthology.org/2024.acl-long.51/
# [459/865] Fetching abstract from https://aclanthology.org/2024.acl-long.510/
# [460/865] Fetching abstract from https://aclanthology.org/2024.acl-long.511/
# [461/865] Fetching abstract from https://aclanthology.org/2024.acl-long.512/
# [462/865] Fetching abstract from https://aclanthology.org/2024.acl-long.513/
# [463/865] Fetching abstract from https://aclanthology.org/2024.acl-long.514/
# [464/865] Fetching abstract from https://aclanthology.org/2024.acl-long.515/
# [465/865] Fetching abstract from https://aclanthology.org/2024.acl-long.516/
# [466/865] Fetching abstract from https://aclanthology.org/2024.acl-long.517/
# [467/865] Fetching abstract from https://aclanthology.org/2024.acl-long.518/
# [468/865] Fetching abstract from https://aclanthology.org/2024.acl-long.519/
# [469/865] Fetching abstract from https://aclanthology.org/2024.acl-long.52/
# [470/865] Fetching abstract from https://aclanthology.org/2024.acl-long.520/
# [471/865] Fetching abstract from https://aclanthology.org/2024.acl-long.521/
# [472/865] Fetching abstract from https://aclanthology.org/2024.acl-long.522/
# [473/865] Fetching abstract from https://aclanthology.org/2024.acl-long.523/
# [474/865] Fetching abstract from https://aclanthology.org/2024.acl-long.524/
# [475/865] Fetching abstract from https://aclanthology.org/2024.acl-long.525/
# [476/865] Fetching abstract from https://aclanthology.org/2024.acl-long.526/
# [477/865] Fetching abstract from https://aclanthology.org/2024.acl-long.527/
# [478/865] Fetching abstract from https://aclanthology.org/2024.acl-long.528/
# [479/865] Fetching abstract from https://aclanthology.org/2024.acl-long.529/
# [480/865] Fetching abstract from https://aclanthology.org/2024.acl-long.53/
# [481/865] Fetching abstract from https://aclanthology.org/2024.acl-long.530/
# [482/865] Fetching abstract from https://aclanthology.org/2024.acl-long.531/
# [483/865] Fetching abstract from https://aclanthology.org/2024.acl-long.532/
# [484/865] Fetching abstract from https://aclanthology.org/2024.acl-long.533/
# [485/865] Fetching abstract from https://aclanthology.org/2024.acl-long.534/
# [486/865] Fetching abstract from https://aclanthology.org/2024.acl-long.535/
# [487/865] Fetching abstract from https://aclanthology.org/2024.acl-long.536/
# [488/865] Fetching abstract from https://aclanthology.org/2024.acl-long.537/
# [489/865] Fetching abstract from https://aclanthology.org/2024.acl-long.538/
# [490/865] Fetching abstract from https://aclanthology.org/2024.acl-long.539/
# [491/865] Fetching abstract from https://aclanthology.org/2024.acl-long.54/
# [492/865] Fetching abstract from https://aclanthology.org/2024.acl-long.540/
# [493/865] Fetching abstract from https://aclanthology.org/2024.acl-long.541/
# [494/865] Fetching abstract from https://aclanthology.org/2024.acl-long.542/
# [495/865] Fetching abstract from https://aclanthology.org/2024.acl-long.543/
# [496/865] Fetching abstract from https://aclanthology.org/2024.acl-long.544/
# [497/865] Fetching abstract from https://aclanthology.org/2024.acl-long.545/
# [498/865] Fetching abstract from https://aclanthology.org/2024.acl-long.546/
# [499/865] Fetching abstract from https://aclanthology.org/2024.acl-long.547/
# [500/865] Fetching abstract from https://aclanthology.org/2024.acl-long.548/
# [501/865] Fetching abstract from https://aclanthology.org/2024.acl-long.549/
# [502/865] Fetching abstract from https://aclanthology.org/2024.acl-long.55/
# [503/865] Fetching abstract from https://aclanthology.org/2024.acl-long.550/
# [504/865] Fetching abstract from https://aclanthology.org/2024.acl-long.551/
# [505/865] Fetching abstract from https://aclanthology.org/2024.acl-long.552/
# [506/865] Fetching abstract from https://aclanthology.org/2024.acl-long.553/
# [507/865] Fetching abstract from https://aclanthology.org/2024.acl-long.554/
# [508/865] Fetching abstract from https://aclanthology.org/2024.acl-long.555/
# [509/865] Fetching abstract from https://aclanthology.org/2024.acl-long.556/
# [510/865] Fetching abstract from https://aclanthology.org/2024.acl-long.557/
# [511/865] Fetching abstract from https://aclanthology.org/2024.acl-long.558/
# [512/865] Fetching abstract from https://aclanthology.org/2024.acl-long.559/
# [513/865] Fetching abstract from https://aclanthology.org/2024.acl-long.56/
# [514/865] Fetching abstract from https://aclanthology.org/2024.acl-long.560/
# [515/865] Fetching abstract from https://aclanthology.org/2024.acl-long.561/
# [516/865] Fetching abstract from https://aclanthology.org/2024.acl-long.562/
# [517/865] Fetching abstract from https://aclanthology.org/2024.acl-long.563/
# [518/865] Fetching abstract from https://aclanthology.org/2024.acl-long.564/
# [519/865] Fetching abstract from https://aclanthology.org/2024.acl-long.565/
# [520/865] Fetching abstract from https://aclanthology.org/2024.acl-long.566/
# [521/865] Fetching abstract from https://aclanthology.org/2024.acl-long.567/
# [522/865] Fetching abstract from https://aclanthology.org/2024.acl-long.568/
# [523/865] Fetching abstract from https://aclanthology.org/2024.acl-long.569/
# [524/865] Fetching abstract from https://aclanthology.org/2024.acl-long.57/
# [525/865] Fetching abstract from https://aclanthology.org/2024.acl-long.570/
# [526/865] Fetching abstract from https://aclanthology.org/2024.acl-long.571/
# [527/865] Fetching abstract from https://aclanthology.org/2024.acl-long.572/
# [528/865] Fetching abstract from https://aclanthology.org/2024.acl-long.573/
# [529/865] Fetching abstract from https://aclanthology.org/2024.acl-long.574/
# [530/865] Fetching abstract from https://aclanthology.org/2024.acl-long.575/
# [531/865] Fetching abstract from https://aclanthology.org/2024.acl-long.576/
# [532/865] Fetching abstract from https://aclanthology.org/2024.acl-long.577/
# [533/865] Fetching abstract from https://aclanthology.org/2024.acl-long.578/
# [534/865] Fetching abstract from https://aclanthology.org/2024.acl-long.579/
# [535/865] Fetching abstract from https://aclanthology.org/2024.acl-long.58/
# [536/865] Fetching abstract from https://aclanthology.org/2024.acl-long.580/
# [537/865] Fetching abstract from https://aclanthology.org/2024.acl-long.581/
# [538/865] Fetching abstract from https://aclanthology.org/2024.acl-long.582/
# [539/865] Fetching abstract from https://aclanthology.org/2024.acl-long.583/
# [540/865] Fetching abstract from https://aclanthology.org/2024.acl-long.584/
# [541/865] Fetching abstract from https://aclanthology.org/2024.acl-long.585/
# [542/865] Fetching abstract from https://aclanthology.org/2024.acl-long.586/
# [543/865] Fetching abstract from https://aclanthology.org/2024.acl-long.587/
# [544/865] Fetching abstract from https://aclanthology.org/2024.acl-long.588/
# [545/865] Fetching abstract from https://aclanthology.org/2024.acl-long.589/
# [546/865] Fetching abstract from https://aclanthology.org/2024.acl-long.59/
# [547/865] Fetching abstract from https://aclanthology.org/2024.acl-long.590/
# [548/865] Fetching abstract from https://aclanthology.org/2024.acl-long.591/
# [549/865] Fetching abstract from https://aclanthology.org/2024.acl-long.592/
# [550/865] Fetching abstract from https://aclanthology.org/2024.acl-long.593/
# [551/865] Fetching abstract from https://aclanthology.org/2024.acl-long.594/
# [552/865] Fetching abstract from https://aclanthology.org/2024.acl-long.595/
# [553/865] Fetching abstract from https://aclanthology.org/2024.acl-long.596/
# [554/865] Fetching abstract from https://aclanthology.org/2024.acl-long.597/
# [555/865] Fetching abstract from https://aclanthology.org/2024.acl-long.598/
# [556/865] Fetching abstract from https://aclanthology.org/2024.acl-long.599/
# [557/865] Fetching abstract from https://aclanthology.org/2024.acl-long.6/
# [558/865] Fetching abstract from https://aclanthology.org/2024.acl-long.60/
# [559/865] Fetching abstract from https://aclanthology.org/2024.acl-long.600/
# [560/865] Fetching abstract from https://aclanthology.org/2024.acl-long.601/
# [561/865] Fetching abstract from https://aclanthology.org/2024.acl-long.602/
# [562/865] Fetching abstract from https://aclanthology.org/2024.acl-long.603/
# [563/865] Fetching abstract from https://aclanthology.org/2024.acl-long.604/
# [564/865] Fetching abstract from https://aclanthology.org/2024.acl-long.605/
# [565/865] Fetching abstract from https://aclanthology.org/2024.acl-long.606/
# [566/865] Fetching abstract from https://aclanthology.org/2024.acl-long.607/
# [567/865] Fetching abstract from https://aclanthology.org/2024.acl-long.608/
# [568/865] Fetching abstract from https://aclanthology.org/2024.acl-long.609/
# [569/865] Fetching abstract from https://aclanthology.org/2024.acl-long.61/
# [570/865] Fetching abstract from https://aclanthology.org/2024.acl-long.610/
# [571/865] Fetching abstract from https://aclanthology.org/2024.acl-long.611/
# [572/865] Fetching abstract from https://aclanthology.org/2024.acl-long.612/
# [573/865] Fetching abstract from https://aclanthology.org/2024.acl-long.613/
# [574/865] Fetching abstract from https://aclanthology.org/2024.acl-long.614/
# [575/865] Fetching abstract from https://aclanthology.org/2024.acl-long.615/
# [576/865] Fetching abstract from https://aclanthology.org/2024.acl-long.616/
# [577/865] Fetching abstract from https://aclanthology.org/2024.acl-long.617/
# [578/865] Fetching abstract from https://aclanthology.org/2024.acl-long.618/
# [579/865] Fetching abstract from https://aclanthology.org/2024.acl-long.619/
# [580/865] Fetching abstract from https://aclanthology.org/2024.acl-long.62/
# [581/865] Fetching abstract from https://aclanthology.org/2024.acl-long.620/
# [582/865] Fetching abstract from https://aclanthology.org/2024.acl-long.621/
# [583/865] Fetching abstract from https://aclanthology.org/2024.acl-long.622/
# [584/865] Fetching abstract from https://aclanthology.org/2024.acl-long.623/
# [585/865] Fetching abstract from https://aclanthology.org/2024.acl-long.624/
# [586/865] Fetching abstract from https://aclanthology.org/2024.acl-long.625/
# [587/865] Fetching abstract from https://aclanthology.org/2024.acl-long.626/
# [588/865] Fetching abstract from https://aclanthology.org/2024.acl-long.627/
# [589/865] Fetching abstract from https://aclanthology.org/2024.acl-long.628/
# [590/865] Fetching abstract from https://aclanthology.org/2024.acl-long.629/
# [591/865] Fetching abstract from https://aclanthology.org/2024.acl-long.63/
# [592/865] Fetching abstract from https://aclanthology.org/2024.acl-long.630/
# [593/865] Fetching abstract from https://aclanthology.org/2024.acl-long.631/
# [594/865] Fetching abstract from https://aclanthology.org/2024.acl-long.632/
# [595/865] Fetching abstract from https://aclanthology.org/2024.acl-long.633/
# [596/865] Fetching abstract from https://aclanthology.org/2024.acl-long.634/
# [597/865] Fetching abstract from https://aclanthology.org/2024.acl-long.635/
# [598/865] Fetching abstract from https://aclanthology.org/2024.acl-long.636/
# [599/865] Fetching abstract from https://aclanthology.org/2024.acl-long.637/
# [600/865] Fetching abstract from https://aclanthology.org/2024.acl-long.638/
# [601/865] Fetching abstract from https://aclanthology.org/2024.acl-long.639/
# [602/865] Fetching abstract from https://aclanthology.org/2024.acl-long.64/
# [603/865] Fetching abstract from https://aclanthology.org/2024.acl-long.640/
# [604/865] Fetching abstract from https://aclanthology.org/2024.acl-long.641/
# [605/865] Fetching abstract from https://aclanthology.org/2024.acl-long.642/
# [606/865] Fetching abstract from https://aclanthology.org/2024.acl-long.643/
# [607/865] Fetching abstract from https://aclanthology.org/2024.acl-long.644/
# [608/865] Fetching abstract from https://aclanthology.org/2024.acl-long.645/
# [609/865] Fetching abstract from https://aclanthology.org/2024.acl-long.646/
# [610/865] Fetching abstract from https://aclanthology.org/2024.acl-long.647/
# [611/865] Fetching abstract from https://aclanthology.org/2024.acl-long.648/
# [612/865] Fetching abstract from https://aclanthology.org/2024.acl-long.649/
# [613/865] Fetching abstract from https://aclanthology.org/2024.acl-long.65/
# [614/865] Fetching abstract from https://aclanthology.org/2024.acl-long.650/
# [615/865] Fetching abstract from https://aclanthology.org/2024.acl-long.651/
# [616/865] Fetching abstract from https://aclanthology.org/2024.acl-long.652/
# [617/865] Fetching abstract from https://aclanthology.org/2024.acl-long.653/
# [618/865] Fetching abstract from https://aclanthology.org/2024.acl-long.654/
# [619/865] Fetching abstract from https://aclanthology.org/2024.acl-long.655/
# [620/865] Fetching abstract from https://aclanthology.org/2024.acl-long.656/
# ...
# [658/865] Fetching abstract from https://aclanthology.org/2024.acl-long.690/
# [659/865] Fetching abstract from https://aclanthology.org/2024.acl-long.691/
# [660/865] Fetching abstract from https://aclanthology.org/2024.acl-long.692/
# [661/865] Fetching abstract from https://aclanthology.org/2024.acl-long.693/
# [662/865] Fetching abstract from https://aclanthology.org/2024.acl-long.694/
# [663/865] Fetching abstract from https://aclanthology.org/2024.acl-long.695/
# [664/865] Fetching abstract from https://aclanthology.org/2024.acl-long.696/
# [665/865] Fetching abstract from https://aclanthology.org/2024.acl-long.697/
# [666/865] Fetching abstract from https://aclanthology.org/2024.acl-long.698/
# [667/865] Fetching abstract from https://aclanthology.org/2024.acl-long.699/
# [668/865] Fetching abstract from https://aclanthology.org/2024.acl-long.7/
# [669/865] Fetching abstract from https://aclanthology.org/2024.acl-long.70/
# [670/865] Fetching abstract from https://aclanthology.org/2024.acl-long.700/
# [671/865] Fetching abstract from https://aclanthology.org/2024.acl-long.701/
# [672/865] Fetching abstract from https://aclanthology.org/2024.acl-long.702/
# [673/865] Fetching abstract from https://aclanthology.org/2024.acl-long.703/
# [674/865] Fetching abstract from https://aclanthology.org/2024.acl-long.704/
# [675/865] Fetching abstract from https://aclanthology.org/2024.acl-long.705/
# [676/865] Fetching abstract from https://aclanthology.org/2024.acl-long.706/
# [677/865] Fetching abstract from https://aclanthology.org/2024.acl-long.707/
# [678/865] Fetching abstract from https://aclanthology.org/2024.acl-long.708/
# [679/865] Fetching abstract from https://aclanthology.org/2024.acl-long.709/
# [680/865] Fetching abstract from https://aclanthology.org/2024.acl-long.71/
# [681/865] Fetching abstract from https://aclanthology.org/2024.acl-long.710/
# [682/865] Fetching abstract from https://aclanthology.org/2024.acl-long.711/
# [683/865] Fetching abstract from https://aclanthology.org/2024.acl-long.712/
# [684/865] Fetching abstract from https://aclanthology.org/2024.acl-long.713/
# [685/865] Fetching abstract from https://aclanthology.org/2024.acl-long.714/
# [686/865] Fetching abstract from https://aclanthology.org/2024.acl-long.715/
# [687/865] Fetching abstract from https://aclanthology.org/2024.acl-long.716/
# [688/865] Fetching abstract from https://aclanthology.org/2024.acl-long.717/
# [689/865] Fetching abstract from https://aclanthology.org/2024.acl-long.718/
# [690/865] Fetching abstract from https://aclanthology.org/2024.acl-long.719/
# [691/865] Fetching abstract from https://aclanthology.org/2024.acl-long.72/
# [692/865] Fetching abstract from https://aclanthology.org/2024.acl-long.720/
# [693/865] Fetching abstract from https://aclanthology.org/2024.acl-long.721/
# [694/865] Fetching abstract from https://aclanthology.org/2024.acl-long.722/
# [695/865] Fetching abstract from https://aclanthology.org/2024.acl-long.723/
# [696/865] Fetching abstract from https://aclanthology.org/2024.acl-long.724/
# [697/865] Fetching abstract from https://aclanthology.org/2024.acl-long.725/
# [698/865] Fetching abstract from https://aclanthology.org/2024.acl-long.726/
# [699/865] Fetching abstract from https://aclanthology.org/2024.acl-long.727/
# [700/865] Fetching abstract from https://aclanthology.org/2024.acl-long.728/
# [701/865] Fetching abstract from https://aclanthology.org/2024.acl-long.729/
# [702/865] Fetching abstract from https://aclanthology.org/2024.acl-long.73/
# [703/865] Fetching abstract from https://aclanthology.org/2024.acl-long.730/
# [704/865] Fetching abstract from https://aclanthology.org/2024.acl-long.731/
# [705/865] Fetching abstract from https://aclanthology.org/2024.acl-long.732/
# [706/865] Fetching abstract from https://aclanthology.org/2024.acl-long.733/
# [707/865] Fetching abstract from https://aclanthology.org/2024.acl-long.734/
# [708/865] Fetching abstract from https://aclanthology.org/2024.acl-long.735/
# [709/865] Fetching abstract from https://aclanthology.org/2024.acl-long.736/
# [710/865] Fetching abstract from https://aclanthology.org/2024.acl-long.737/
# [711/865] Fetching abstract from https://aclanthology.org/2024.acl-long.738/
# [712/865] Fetching abstract from https://aclanthology.org/2024.acl-long.739/
# [713/865] Fetching abstract from https://aclanthology.org/2024.acl-long.74/
# [714/865] Fetching abstract from https://aclanthology.org/2024.acl-long.740/
# [715/865] Fetching abstract from https://aclanthology.org/2024.acl-long.741/
# [716/865] Fetching abstract from https://aclanthology.org/2024.acl-long.742/
# [717/865] Fetching abstract from https://aclanthology.org/2024.acl-long.743/
# [718/865] Fetching abstract from https://aclanthology.org/2024.acl-long.744/
# [719/865] Fetching abstract from https://aclanthology.org/2024.acl-long.745/
# [720/865] Fetching abstract from https://aclanthology.org/2024.acl-long.746/
# [721/865] Fetching abstract from https://aclanthology.org/2024.acl-long.747/
# [722/865] Fetching abstract from https://aclanthology.org/2024.acl-long.748/
# [723/865] Fetching abstract from https://aclanthology.org/2024.acl-long.749/
# [724/865] Fetching abstract from https://aclanthology.org/2024.acl-long.75/
# [725/865] Fetching abstract from https://aclanthology.org/2024.acl-long.750/
# [726/865] Fetching abstract from https://aclanthology.org/2024.acl-long.751/
# [727/865] Fetching abstract from https://aclanthology.org/2024.acl-long.752/
# [728/865] Fetching abstract from https://aclanthology.org/2024.acl-long.753/
# [729/865] Fetching abstract from https://aclanthology.org/2024.acl-long.754/
# [730/865] Fetching abstract from https://aclanthology.org/2024.acl-long.755/
# [731/865] Fetching abstract from https://aclanthology.org/2024.acl-long.756/
# [732/865] Fetching abstract from https://aclanthology.org/2024.acl-long.757/
# [733/865] Fetching abstract from https://aclanthology.org/2024.acl-long.758/
# [734/865] Fetching abstract from https://aclanthology.org/2024.acl-long.759/
# [735/865] Fetching abstract from https://aclanthology.org/2024.acl-long.76/
# [736/865] Fetching abstract from https://aclanthology.org/2024.acl-long.760/
# [737/865] Fetching abstract from https://aclanthology.org/2024.acl-long.761/
# [738/865] Fetching abstract from https://aclanthology.org/2024.acl-long.762/
# [739/865] Fetching abstract from https://aclanthology.org/2024.acl-long.763/
# [740/865] Fetching abstract from https://aclanthology.org/2024.acl-long.764/
# [741/865] Fetching abstract from https://aclanthology.org/2024.acl-long.765/
# [742/865] Fetching abstract from https://aclanthology.org/2024.acl-long.766/
# [743/865] Fetching abstract from https://aclanthology.org/2024.acl-long.767/
# [744/865] Fetching abstract from https://aclanthology.org/2024.acl-long.768/
# [745/865] Fetching abstract from https://aclanthology.org/2024.acl-long.769/
# [746/865] Fetching abstract from https://aclanthology.org/2024.acl-long.77/
# [747/865] Fetching abstract from https://aclanthology.org/2024.acl-long.770/
# [748/865] Fetching abstract from https://aclanthology.org/2024.acl-long.771/
# [749/865] Fetching abstract from https://aclanthology.org/2024.acl-long.772/
# [750/865] Fetching abstract from https://aclanthology.org/2024.acl-long.773/
# [751/865] Fetching abstract from https://aclanthology.org/2024.acl-long.774/
# [752/865] Fetching abstract from https://aclanthology.org/2024.acl-long.775/
# [753/865] Fetching abstract from https://aclanthology.org/2024.acl-long.776/
# [754/865] Fetching abstract from https://aclanthology.org/2024.acl-long.777/
# [755/865] Fetching abstract from https://aclanthology.org/2024.acl-long.778/
# [756/865] Fetching abstract from https://aclanthology.org/2024.acl-long.779/
# [757/865] Fetching abstract from https://aclanthology.org/2024.acl-long.78/
# [758/865] Fetching abstract from https://aclanthology.org/2024.acl-long.780/
# [759/865] Fetching abstract from https://aclanthology.org/2024.acl-long.781/
# [760/865] Fetching abstract from https://aclanthology.org/2024.acl-long.782/
# [761/865] Fetching abstract from https://aclanthology.org/2024.acl-long.783/
# [762/865] Fetching abstract from https://aclanthology.org/2024.acl-long.784/
# [763/865] Fetching abstract from https://aclanthology.org/2024.acl-long.785/
# [764/865] Fetching abstract from https://aclanthology.org/2024.acl-long.786/
# [765/865] Fetching abstract from https://aclanthology.org/2024.acl-long.787/
# [766/865] Fetching abstract from https://aclanthology.org/2024.acl-long.788/
# [767/865] Fetching abstract from https://aclanthology.org/2024.acl-long.789/
# [768/865] Fetching abstract from https://aclanthology.org/2024.acl-long.79/
# [769/865] Fetching abstract from https://aclanthology.org/2024.acl-long.790/
# [770/865] Fetching abstract from https://aclanthology.org/2024.acl-long.791/
# [771/865] Fetching abstract from https://aclanthology.org/2024.acl-long.792/
# [772/865] Fetching abstract from https://aclanthology.org/2024.acl-long.793/
# [773/865] Fetching abstract from https://aclanthology.org/2024.acl-long.794/
# [774/865] Fetching abstract from https://aclanthology.org/2024.acl-long.795/
# [775/865] Fetching abstract from https://aclanthology.org/2024.acl-long.796/
# [776/865] Fetching abstract from https://aclanthology.org/2024.acl-long.797/
# [777/865] Fetching abstract from https://aclanthology.org/2024.acl-long.798/
# [778/865] Fetching abstract from https://aclanthology.org/2024.acl-long.799/
# [779/865] Fetching abstract from https://aclanthology.org/2024.acl-long.8/
# [780/865] Fetching abstract from https://aclanthology.org/2024.acl-long.80/
# [781/865] Fetching abstract from https://aclanthology.org/2024.acl-long.800/
# [782/865] Fetching abstract from https://aclanthology.org/2024.acl-long.801/
# [783/865] Fetching abstract from https://aclanthology.org/2024.acl-long.802/
# [784/865] Fetching abstract from https://aclanthology.org/2024.acl-long.803/
# [785/865] Fetching abstract from https://aclanthology.org/2024.acl-long.804/
# [786/865] Fetching abstract from https://aclanthology.org/2024.acl-long.805/
# [787/865] Fetching abstract from https://aclanthology.org/2024.acl-long.806/
# [788/865] Fetching abstract from https://aclanthology.org/2024.acl-long.807/
# [789/865] Fetching abstract from https://aclanthology.org/2024.acl-long.808/
# [790/865] Fetching abstract from https://aclanthology.org/2024.acl-long.809/
# [791/865] Fetching abstract from https://aclanthology.org/2024.acl-long.81/
# [792/865] Fetching abstract from https://aclanthology.org/2024.acl-long.810/
# [793/865] Fetching abstract from https://aclanthology.org/2024.acl-long.811/
# [794/865] Fetching abstract from https://aclanthology.org/2024.acl-long.812/
# [795/865] Fetching abstract from https://aclanthology.org/2024.acl-long.813/
# [796/865] Fetching abstract from https://aclanthology.org/2024.acl-long.814/
# [797/865] Fetching abstract from https://aclanthology.org/2024.acl-long.815/
# [798/865] Fetching abstract from https://aclanthology.org/2024.acl-long.816/
# [799/865] Fetching abstract from https://aclanthology.org/2024.acl-long.817/
# [800/865] Fetching abstract from https://aclanthology.org/2024.acl-long.818/
# [801/865] Fetching abstract from https://aclanthology.org/2024.acl-long.819/
# [802/865] Fetching abstract from https://aclanthology.org/2024.acl-long.82/
# [803/865] Fetching abstract from https://aclanthology.org/2024.acl-long.820/
# [804/865] Fetching abstract from https://aclanthology.org/2024.acl-long.821/
# [805/865] Fetching abstract from https://aclanthology.org/2024.acl-long.822/
# [806/865] Fetching abstract from https://aclanthology.org/2024.acl-long.823/
# [807/865] Fetching abstract from https://aclanthology.org/2024.acl-long.824/
# [808/865] Fetching abstract from https://aclanthology.org/2024.acl-long.825/
# [809/865] Fetching abstract from https://aclanthology.org/2024.acl-long.826/
# [810/865] Fetching abstract from https://aclanthology.org/2024.acl-long.827/
# [811/865] Fetching abstract from https://aclanthology.org/2024.acl-long.828/
# [812/865] Fetching abstract from https://aclanthology.org/2024.acl-long.829/
# [813/865] Fetching abstract from https://aclanthology.org/2024.acl-long.83/
# [814/865] Fetching abstract from https://aclanthology.org/2024.acl-long.830/
# [815/865] Fetching abstract from https://aclanthology.org/2024.acl-long.831/
# [816/865] Fetching abstract from https://aclanthology.org/2024.acl-long.832/
# [817/865] Fetching abstract from https://aclanthology.org/2024.acl-long.833/
# [818/865] Fetching abstract from https://aclanthology.org/2024.acl-long.834/
# [819/865] Fetching abstract from https://aclanthology.org/2024.acl-long.835/
# [820/865] Fetching abstract from https://aclanthology.org/2024.acl-long.836/
# [821/865] Fetching abstract from https://aclanthology.org/2024.acl-long.837/
# [822/865] Fetching abstract from https://aclanthology.org/2024.acl-long.838/
# [823/865] Fetching abstract from https://aclanthology.org/2024.acl-long.839/
# [824/865] Fetching abstract from https://aclanthology.org/2024.acl-long.84/
# [825/865] Fetching abstract from https://aclanthology.org/2024.acl-long.840/
# [826/865] Fetching abstract from https://aclanthology.org/2024.acl-long.841/
# [827/865] Fetching abstract from https://aclanthology.org/2024.acl-long.842/
# [828/865] Fetching abstract from https://aclanthology.org/2024.acl-long.843/
# [829/865] Fetching abstract from https://aclanthology.org/2024.acl-long.844/
# [830/865] Fetching abstract from https://aclanthology.org/2024.acl-long.845/
# [831/865] Fetching abstract from https://aclanthology.org/2024.acl-long.846/
# [832/865] Fetching abstract from https://aclanthology.org/2024.acl-long.847/
# [833/865] Fetching abstract from https://aclanthology.org/2024.acl-long.848/
# [834/865] Fetching abstract from https://aclanthology.org/2024.acl-long.849/
# [835/865] Fetching abstract from https://aclanthology.org/2024.acl-long.85/
# [836/865] Fetching abstract from https://aclanthology.org/2024.acl-long.850/
# [837/865] Fetching abstract from https://aclanthology.org/2024.acl-long.851/
# [838/865] Fetching abstract from https://aclanthology.org/2024.acl-long.852/
# [839/865] Fetching abstract from https://aclanthology.org/2024.acl-long.853/
# [840/865] Fetching abstract from https://aclanthology.org/2024.acl-long.854/
# [841/865] Fetching abstract from https://aclanthology.org/2024.acl-long.855/
# [842/865] Fetching abstract from https://aclanthology.org/2024.acl-long.856/
# [843/865] Fetching abstract from https://aclanthology.org/2024.acl-long.857/
# [844/865] Fetching abstract from https://aclanthology.org/2024.acl-long.858/
# [845/865] Fetching abstract from https://aclanthology.org/2024.acl-long.859/
# [846/865] Fetching abstract from https://aclanthology.org/2024.acl-long.86/
# [847/865] Fetching abstract from https://aclanthology.org/2024.acl-long.860/
# [848/865] Fetching abstract from https://aclanthology.org/2024.acl-long.861/
# [849/865] Fetching abstract from https://aclanthology.org/2024.acl-long.862/
# [850/865] Fetching abstract from https://aclanthology.org/2024.acl-long.863/
# [851/865] Fetching abstract from https://aclanthology.org/2024.acl-long.864/
# [852/865] Fetching abstract from https://aclanthology.org/2024.acl-long.87/
# [853/865] Fetching abstract from https://aclanthology.org/2024.acl-long.88/
# [854/865] Fetching abstract from https://aclanthology.org/2024.acl-long.89/
# [855/865] Fetching abstract from https://aclanthology.org/2024.acl-long.9/
# [856/865] Fetching abstract from https://aclanthology.org/2024.acl-long.90/
# [857/865] Fetching abstract from https://aclanthology.org/2024.acl-long.91/
# [858/865] Fetching abstract from https://aclanthology.org/2024.acl-long.92/
# [859/865] Fetching abstract from https://aclanthology.org/2024.acl-long.93/
# [860/865] Fetching abstract from https://aclanthology.org/2024.acl-long.94/
# [861/865] Fetching abstract from https://aclanthology.org/2024.acl-long.95/
# [862/865] Fetching abstract from https://aclanthology.org/2024.acl-long.96/
# [863/865] Fetching abstract from https://aclanthology.org/2024.acl-long.97/
# [864/865] Fetching abstract from https://aclanthology.org/2024.acl-long.98/
# [865/865] Fetching abstract from https://aclanthology.org/2024.acl-long.99/

# %%
import requests
from bs4 import BeautifulSoup
import time

VOLUME_URL = "https://aclanthology.org/volumes/2024.acl-short/"

def get_paper_links():
    response = requests.get(VOLUME_URL)
    if response.status_code != 200:
        print(f"Failed to access {VOLUME_URL}")
        return []

    soup = BeautifulSoup(response.content, 'html.parser')
    paper_links = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        if href.startswith("/2024.acl-short.") and href.count('.') == 2:
            full_url = "https://aclanthology.org" + href
            paper_links.append(full_url)

    return sorted(set(paper_links))

def extract_abstract(paper_url):
    try:
        response = requests.get(paper_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        abstract_div = soup.find('div', class_='card-body acl-abstract')
        if abstract_div:
            return abstract_div.text.strip()
    except Exception as e:
        print(f"Error fetching {paper_url}: {e}")
    return None

def main():
    links = get_paper_links()
    print(f"Found {len(links)} ACL 2024 short papers.")
    with open("acl_2024_short_abstracts.txt", "w", encoding="utf-8") as f:
        for i, url in enumerate(links, 1):
            print(f"[{i}/{len(links)}] Fetching abstract from {url}")
            abstract = extract_abstract(url)
            if abstract:
                f.write(f"URL: {url}\n")
                f.write(f"Abstract: {abstract}\n")
                f.write("="*80 + "\n")
            else:
                print(f"No abstract found for: {url}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# 📄 Found 78 ACL 2024 short papers.
# [1/78] Fetching abstract from https://aclanthology.org/2024.acl-short.0/
# ⚠️ No abstract found for: https://aclanthology.org/2024.acl-short.0/
# [2/78] Fetching abstract from https://aclanthology.org/2024.acl-short.1/
# [3/78] Fetching abstract from https://aclanthology.org/2024.acl-short.10/
# [4/78] Fetching abstract from https://aclanthology.org/2024.acl-short.11/
# [5/78] Fetching abstract from https://aclanthology.org/2024.acl-short.12/
# [6/78] Fetching abstract from https://aclanthology.org/2024.acl-short.13/
# [7/78] Fetching abstract from https://aclanthology.org/2024.acl-short.14/
# [8/78] Fetching abstract from https://aclanthology.org/2024.acl-short.15/
# [9/78] Fetching abstract from https://aclanthology.org/2024.acl-short.16/
# [10/78] Fetching abstract from https://aclanthology.org/2024.acl-short.17/
# [11/78] Fetching abstract from https://aclanthology.org/2024.acl-short.18/
# [12/78] Fetching abstract from https://aclanthology.org/2024.acl-short.19/
# [13/78] Fetching abstract from https://aclanthology.org/2024.acl-short.2/
# [14/78] Fetching abstract from https://aclanthology.org/2024.acl-short.20/
# [15/78] Fetching abstract from https://aclanthology.org/2024.acl-short.21/
# [16/78] Fetching abstract from https://aclanthology.org/2024.acl-short.22/
# [17/78] Fetching abstract from https://aclanthology.org/2024.acl-short.23/
# [18/78] Fetching abstract from https://aclanthology.org/2024.acl-short.24/
# [19/78] Fetching abstract from https://aclanthology.org/2024.acl-short.25/
# [20/78] Fetching abstract from https://aclanthology.org/2024.acl-short.26/
# [21/78] Fetching abstract from https://aclanthology.org/2024.acl-short.27/
# [22/78] Fetching abstract from https://aclanthology.org/2024.acl-short.28/
# [23/78] Fetching abstract from https://aclanthology.org/2024.acl-short.29/
# [24/78] Fetching abstract from https://aclanthology.org/2024.acl-short.3/
# [25/78] Fetching abstract from https://aclanthology.org/2024.acl-short.30/
# [26/78] Fetching abstract from https://aclanthology.org/2024.acl-short.31/
# [27/78] Fetching abstract from https://aclanthology.org/2024.acl-short.32/
# [28/78] Fetching abstract from https://aclanthology.org/2024.acl-short.33/
# [29/78] Fetching abstract from https://aclanthology.org/2024.acl-short.34/
# [30/78] Fetching abstract from https://aclanthology.org/2024.acl-short.35/
# [31/78] Fetching abstract from https://aclanthology.org/2024.acl-short.36/
# [32/78] Fetching abstract from https://aclanthology.org/2024.acl-short.37/
# [33/78] Fetching abstract from https://aclanthology.org/2024.acl-short.38/
# [34/78] Fetching abstract from https://aclanthology.org/2024.acl-short.39/
# [35/78] Fetching abstract from https://aclanthology.org/2024.acl-short.4/
# [36/78] Fetching abstract from https://aclanthology.org/2024.acl-short.40/
# [37/78] Fetching abstract from https://aclanthology.org/2024.acl-short.41/
# [38/78] Fetching abstract from https://aclanthology.org/2024.acl-short.42/
# [39/78] Fetching abstract from https://aclanthology.org/2024.acl-short.43/
# [40/78] Fetching abstract from https://aclanthology.org/2024.acl-short.44/
# [41/78] Fetching abstract from https://aclanthology.org/2024.acl-short.45/
# [42/78] Fetching abstract from https://aclanthology.org/2024.acl-short.46/
# [43/78] Fetching abstract from https://aclanthology.org/2024.acl-short.47/
# [44/78] Fetching abstract from https://aclanthology.org/2024.acl-short.48/
# [45/78] Fetching abstract from https://aclanthology.org/2024.acl-short.49/
# [46/78] Fetching abstract from https://aclanthology.org/2024.acl-short.5/
# [47/78] Fetching abstract from https://aclanthology.org/2024.acl-short.50/
# [48/78] Fetching abstract from https://aclanthology.org/2024.acl-short.51/
# [49/78] Fetching abstract from https://aclanthology.org/2024.acl-short.52/
# [50/78] Fetching abstract from https://aclanthology.org/2024.acl-short.53/
# [51/78] Fetching abstract from https://aclanthology.org/2024.acl-short.54/
# [52/78] Fetching abstract from https://aclanthology.org/2024.acl-short.55/
# [53/78] Fetching abstract from https://aclanthology.org/2024.acl-short.56/
# [54/78] Fetching abstract from https://aclanthology.org/2024.acl-short.57/
# [55/78] Fetching abstract from https://aclanthology.org/2024.acl-short.58/
# [56/78] Fetching abstract from https://aclanthology.org/2024.acl-short.59/
# [57/78] Fetching abstract from https://aclanthology.org/2024.acl-short.6/
# [58/78] Fetching abstract from https://aclanthology.org/2024.acl-short.60/
# [59/78] Fetching abstract from https://aclanthology.org/2024.acl-short.61/
# [60/78] Fetching abstract from https://aclanthology.org/2024.acl-short.62/
# [61/78] Fetching abstract from https://aclanthology.org/2024.acl-short.63/
# [62/78] Fetching abstract from https://aclanthology.org/2024.acl-short.64/
# [63/78] Fetching abstract from https://aclanthology.org/2024.acl-short.65/
# [64/78] Fetching abstract from https://aclanthology.org/2024.acl-short.66/
# [65/78] Fetching abstract from https://aclanthology.org/2024.acl-short.67/
# [66/78] Fetching abstract from https://aclanthology.org/2024.acl-short.68/
# [67/78] Fetching abstract from https://aclanthology.org/2024.acl-short.69/
# [68/78] Fetching abstract from https://aclanthology.org/2024.acl-short.7/
# [69/78] Fetching abstract from https://aclanthology.org/2024.acl-short.70/
# [70/78] Fetching abstract from https://aclanthology.org/2024.acl-short.71/
# [71/78] Fetching abstract from https://aclanthology.org/2024.acl-short.72/
# [72/78] Fetching abstract from https://aclanthology.org/2024.acl-short.73/
# [73/78] Fetching abstract from https://aclanthology.org/2024.acl-short.74/
# [74/78] Fetching abstract from https://aclanthology.org/2024.acl-short.75/
# [75/78] Fetching abstract from https://aclanthology.org/2024.acl-short.76/
# [76/78] Fetching abstract from https://aclanthology.org/2024.acl-short.77/
# [77/78] Fetching abstract from https://aclanthology.org/2024.acl-short.8/
# [78/78] Fetching abstract from https://aclanthology.org/2024.acl-short.9/
